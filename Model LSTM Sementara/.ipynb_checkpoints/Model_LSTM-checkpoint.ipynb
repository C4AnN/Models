# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, LSTM, Input
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
# Load data
url = 'https://raw.githubusercontent.com/C4AnN/Models/main/dataset_processing%20(2)/file_gabungan2.csv'
store_sales = pd.read_csv(url)
store_sales.head(10)
# Out:
#                                                 name     price        date  \
# 0  Lenovo Legion Y540 - i7 9750H 16GB 512ssd 1TB ...  16999000  2013-01-01
# 1  ASUS ROG G531GU-I566G2T i5 9300H|8GB|512GB SSD...  16899000  2013-01-02
# 2  ASUS ROG GU502GU-I7664B Zephyrus M i7 9750H|16...  28299000  2013-01-03
# 3             ASUS ROG Strix G531GV-I7R6S1T [Scar 3]  30999000  2013-01-04
# 4  ASUS ROG G531GT-I765G1T STRIX III i7-9750H 8GB...  16999000  2013-01-05
# 5  ASUS ROG HERO G531GU-I766H2T i7-9750H-16GB-256...  24590000  2013-01-06
# 6  ASUS ROG STRIX III G531GT-I765G4B i7-9750H|8GB...  17499000  2013-01-07
# 7  Asus ROG Zephyrus M GX502GW i7 9750 16GB 1TB S...  29199000  2013-01-08
# 8                            ASUS ROG STRIX G G731GT  18499000  2013-01-09
# 9  ASUS ROG STRIX G512LU-I766B6T i7-10750H 8GB 51...  20553000  2013-01-10
#
#    sales
# 0     13
# 1     11
# 2     14
# 3     13
# 4     10
# 5     12
# 6     10
# 7      9
# 8     12
# 9      9

# %%
store_sales['date'] = pd.to_datetime(store_sales['date'])
store_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103000 entries, 0 to 102999
# Data columns (total 4 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   name    103000 non-null  object
#  1   price   103000 non-null  int64
#  2   date    103000 non-null  datetime64[ns]
#  3   sales   103000 non-null  int64
# dtypes: datetime64[ns](1), int64(2), object(1)
# memory usage: 3.1+ MB

# %%
# Categorize data based on price
def categorize_price(price):
    if price < 8000000:
        return 'low'
    elif 8000000 <= price < 16000000:
        return 'mid'
    else:
        return 'high'

store_sales['category'] = store_sales['price'].apply(categorize_price)

# %%
# Drop unnecessary columns
store_sales = store_sales.drop(['name', 'price'], axis=1)
store_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103000 entries, 0 to 102999
# Data columns (total 3 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   date      103000 non-null  datetime64[ns]
#  1   sales     103000 non-null  int64
#  2   category  103000 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 2.4+ MB

# %%
# Function to process and predict for each category
def process_category(data, category_name):
    data = data[data['category'] == category_name].drop(['category'], axis=1)
    data['date'] = data['date'].dt.to_period("M")
    monthly_sales = data.groupby('date').sum().reset_index()
    monthly_sales['date'] = monthly_sales['date'].dt.to_timestamp()

    # Calculate sales difference
    monthly_sales['sales_diff'] = monthly_sales['sales'].diff()
    monthly_sales = monthly_sales.dropna()

    # Prepare supervised data
    supervised_data = monthly_sales.drop(['date', 'sales'], axis=1)
    for i in range(1, 13):
        col_name = 'month_' + str(i)
        supervised_data[col_name] = supervised_data['sales_diff'].shift(i)
    supervised_data = supervised_data.dropna().reset_index(drop=True)

    # Split into train and test data
    train_data = supervised_data[:-12]
    test_data = supervised_data[-12:]

    # Convert to DataFrame to retain column names
    scaler = MinMaxScaler(feature_range=(-1, 1))
    train_data_df = pd.DataFrame(train_data, columns=supervised_data.columns)
    test_data_df = pd.DataFrame(test_data, columns=supervised_data.columns)

    # Scale the data
    scaler.fit(train_data_df)
    train_data_scaled = scaler.transform(train_data_df)
    test_data_scaled = scaler.transform(test_data_df)

    X_train, y_train = train_data_scaled[:, 1:], train_data_scaled[:, 0]
    X_test, y_test = test_data_scaled[:, 1:], test_data_scaled[:, 0]

    # Reshape input to be 3D [samples, timesteps, features]
    X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
    X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

    # Build LSTM model
    model = Sequential()
    model.add(Input(shape=(X_train.shape[1], 1)))
    model.add(LSTM(50, activation='tanh'))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mse')

    # Setup callbacks
    early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
    model_checkpoint = ModelCheckpoint(f'best_model_{category_name}.keras', monitor='val_loss', save_best_only=True)

    # Train the model
    history = model.fit(X_train, y_train, epochs=100, validation_data=(X_test, y_test), callbacks=[early_stop, model_checkpoint], verbose=1)

    # Save the model
    model.save(f'best_model_{category_name}.keras')

    # Make predictions
    lstm_pre = model.predict(X_test)

    # Prepare prediction DataFrame
    sales_dates = monthly_sales['date'][-12:].reset_index(drop=True)
    predict_df = pd.DataFrame(sales_dates, columns=['date'])

    act_sales = monthly_sales['sales'][-13:].to_list()
    lstm_pre = lstm_pre.reshape(-1, 1)
    lstm_pre_test_set = np.concatenate([lstm_pre, X_test.reshape((X_test.shape[0], X_test.shape[1]))], axis=1)
    lstm_pre_test_set = scaler.inverse_transform(lstm_pre_test_set)

    result_list = []
    for index in range(0, len(lstm_pre_test_set)):
        result_list.append(lstm_pre_test_set[index][0] + act_sales[index + 1])
    lstm_pre_series = pd.Series(result_list, name="LSTM Prediction")
    predict_df = predict_df.merge(lstm_pre_series, left_index=True, right_index=True)

    # Predict next 12 months
    future_predictions = []
    last_data = supervised_data[-1:].copy()

    for _ in range(12):
        last_data_scaled = scaler.transform(last_data)
        X_last = last_data_scaled[:, 1:].reshape((1, X_train.shape[1], 1))
        next_pred = model.predict(X_last)[0, 0]

        future_pred = np.concatenate([[next_pred], last_data_scaled[0, 1:]])
        future_pred = scaler.inverse_transform([future_pred])

        future_predictions.append(future_pred[0][0] + monthly_sales['sales'].iloc[-1])

        new_row = np.append([next_pred], last_data.values[0, :-1])
        last_data = pd.DataFrame([new_row], columns=supervised_data.columns)

    future_dates = pd.date_range(start=monthly_sales['date'].iloc[-1] + pd.DateOffset(months=1), periods=12, freq='M')
    future_df = pd.DataFrame({'date': future_dates, 'LSTM Prediction': future_predictions})

    return monthly_sales, predict_df, future_df

# Process and predict for each category
low_sales, low_predict_df, low_future_df = process_category(store_sales, 'low')
mid_sales, mid_predict_df, mid_future_df = process_category(store_sales, 'mid')
high_sales, high_predict_df, high_future_df = process_category(store_sales, 'high')
# Out:
# Epoch 1/100
# 2/2 [==============================] - 3s 620ms/step - loss: 0.2443 - val_loss: 0.6130
# Epoch 2/100
# 2/2 [==============================] - 0s 62ms/step - loss: 0.2385 - val_loss: 0.6106
# Epoch 3/100
# 2/2 [==============================] - 0s 62ms/step - loss: 0.2338 - val_loss: 0.6097
# Epoch 4/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.2301 - val_loss: 0.6093
# Epoch 5/100
# 2/2 [==============================] - 0s 38ms/step - loss: 0.2273 - val_loss: 0.6094
# Epoch 6/100
# 2/2 [==============================] - 0s 65ms/step - loss: 0.2261 - val_loss: 0.6107
# Epoch 7/100
# 2/2 [==============================] - 0s 37ms/step - loss: 0.2263 - val_loss: 0.6097
# Epoch 8/100
# 2/2 [==============================] - 0s 76ms/step - loss: 0.2251 - val_loss: 0.6058
# Epoch 9/100
# 2/2 [==============================] - 0s 92ms/step - loss: 0.2236 - val_loss: 0.6009
# Epoch 10/100
# 2/2 [==============================] - 0s 94ms/step - loss: 0.2215 - val_loss: 0.5942
# Epoch 11/100
# 2/2 [==============================] - 0s 69ms/step - loss: 0.2191 - val_loss: 0.5879
# Epoch 12/100
# 2/2 [==============================] - 0s 80ms/step - loss: 0.2165 - val_loss: 0.5820
# Epoch 13/100
# 2/2 [==============================] - 0s 70ms/step - loss: 0.2146 - val_loss: 0.5764
# Epoch 14/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.2122 - val_loss: 0.5702
# Epoch 15/100
# 2/2 [==============================] - 0s 82ms/step - loss: 0.2097 - val_loss: 0.5619
# Epoch 16/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.2069 - val_loss: 0.5527
# Epoch 17/100
# 2/2 [==============================] - 0s 71ms/step - loss: 0.2045 - val_loss: 0.5436
# Epoch 18/100
# 2/2 [==============================] - 0s 68ms/step - loss: 0.2026 - val_loss: 0.5357
# Epoch 19/100
# 2/2 [==============================] - 0s 79ms/step - loss: 0.2007 - val_loss: 0.5290
# Epoch 20/100
# 2/2 [==============================] - 0s 86ms/step - loss: 0.1988 - val_loss: 0.5239
# Epoch 21/100
# 2/2 [==============================] - 0s 66ms/step - loss: 0.1961 - val_loss: 0.5192
# Epoch 22/100
# 2/2 [==============================] - 0s 102ms/step - loss: 0.1936 - val_loss: 0.5130
# Epoch 23/100
# 2/2 [==============================] - 0s 73ms/step - loss: 0.1910 - val_loss: 0.5059
# Epoch 24/100
# 2/2 [==============================] - 0s 64ms/step - loss: 0.1887 - val_loss: 0.4997
# Epoch 25/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.1869 - val_loss: 0.4945
# Epoch 26/100
# 2/2 [==============================] - 0s 90ms/step - loss: 0.1848 - val_loss: 0.4891
# Epoch 27/100
# 2/2 [==============================] - 0s 67ms/step - loss: 0.1835 - val_loss: 0.4839
# Epoch 28/100
# 2/2 [==============================] - 0s 72ms/step - loss: 0.1823 - val_loss: 0.4787
# Epoch 29/100
# 2/2 [==============================] - 0s 94ms/step - loss: 0.1811 - val_loss: 0.4726
# Epoch 30/100
# 2/2 [==============================] - 0s 78ms/step - loss: 0.1802 - val_loss: 0.4659
# Epoch 31/100
# 2/2 [==============================] - 0s 107ms/step - loss: 0.1788 - val_loss: 0.4599
# Epoch 32/100
# 2/2 [==============================] - 0s 114ms/step - loss: 0.1781 - val_loss: 0.4539
# Epoch 33/100
# 2/2 [==============================] - 0s 96ms/step - loss: 0.1770 - val_loss: 0.4483
# Epoch 34/100
# 2/2 [==============================] - 0s 94ms/step - loss: 0.1761 - val_loss: 0.4438
# Epoch 35/100
# 2/2 [==============================] - 0s 112ms/step - loss: 0.1752 - val_loss: 0.4404
# Epoch 36/100
# 2/2 [==============================] - 0s 109ms/step - loss: 0.1747 - val_loss: 0.4369
# Epoch 37/100
# 2/2 [==============================] - 0s 103ms/step - loss: 0.1741 - val_loss: 0.4350
# Epoch 38/100
# 2/2 [==============================] - 0s 110ms/step - loss: 0.1740 - val_loss: 0.4345
# Epoch 39/100
# 2/2 [==============================] - 0s 92ms/step - loss: 0.1750 - val_loss: 0.4302
# Epoch 40/100
# 2/2 [==============================] - 0s 83ms/step - loss: 0.1743 - val_loss: 0.4243
# Epoch 41/100
# 2/2 [==============================] - 0s 88ms/step - loss: 0.1730 - val_loss: 0.4205
# Epoch 42/100
# 2/2 [==============================] - 0s 101ms/step - loss: 0.1731 - val_loss: 0.4171
# Epoch 43/100
# 2/2 [==============================] - 0s 85ms/step - loss: 0.1725 - val_loss: 0.4128
# Epoch 44/100
# 2/2 [==============================] - 0s 90ms/step - loss: 0.1719 - val_loss: 0.4089
# Epoch 45/100
# 2/2 [==============================] - 0s 141ms/step - loss: 0.1726 - val_loss: 0.4068
# Epoch 46/100
# 2/2 [==============================] - 0s 283ms/step - loss: 0.1768 - val_loss: 0.4051
# Epoch 47/100
# 2/2 [==============================] - 0s 302ms/step - loss: 0.1777 - val_loss: 0.4027
# Epoch 48/100
# 2/2 [==============================] - 0s 454ms/step - loss: 0.1773 - val_loss: 0.4003
# Epoch 49/100
# 2/2 [==============================] - 1s 496ms/step - loss: 0.1743 - val_loss: 0.3987
# Epoch 50/100
# 2/2 [==============================] - 1s 499ms/step - loss: 0.1700 - val_loss: 0.3986
# Epoch 51/100
# 2/2 [==============================] - 0s 136ms/step - loss: 0.1662 - val_loss: 0.4000
# Epoch 52/100
# 2/2 [==============================] - 0s 124ms/step - loss: 0.1654 - val_loss: 0.4027
# Epoch 53/100
# 2/2 [==============================] - 0s 106ms/step - loss: 0.1659 - val_loss: 0.4047
# Epoch 54/100
# 2/2 [==============================] - 0s 170ms/step - loss: 0.1663 - val_loss: 0.4067
# Epoch 55/100
# 2/2 [==============================] - 0s 134ms/step - loss: 0.1682 - val_loss: 0.4072
# Epoch 56/100
# 2/2 [==============================] - 0s 80ms/step - loss: 0.1684 - val_loss: 0.4044
# Epoch 57/100
# 2/2 [==============================] - 0s 155ms/step - loss: 0.1679 - val_loss: 0.4010
# Epoch 58/100
# 2/2 [==============================] - 0s 164ms/step - loss: 0.1667 - val_loss: 0.3984
# Epoch 59/100
# 2/2 [==============================] - 0s 207ms/step - loss: 0.1662 - val_loss: 0.3968
# Epoch 60/100
# 2/2 [==============================] - 0s 82ms/step - loss: 0.1662 - val_loss: 0.3955
# Epoch 61/100
# 2/2 [==============================] - 0s 61ms/step - loss: 0.1657 - val_loss: 0.3945
# Epoch 62/100
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1655 - val_loss: 0.3946
# Epoch 63/100
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1651 - val_loss: 0.3949
# Epoch 64/100
# 2/2 [==============================] - 0s 62ms/step - loss: 0.1645 - val_loss: 0.3924
# Epoch 65/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.1637 - val_loss: 0.3882
# Epoch 66/100
# 2/2 [==============================] - 0s 61ms/step - loss: 0.1625 - val_loss: 0.3853
# Epoch 67/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.1613 - val_loss: 0.3833
# Epoch 68/100
# 2/2 [==============================] - 0s 70ms/step - loss: 0.1602 - val_loss: 0.3802
# Epoch 69/100
# 2/2 [==============================] - 0s 68ms/step - loss: 0.1593 - val_loss: 0.3769
# Epoch 70/100
# 2/2 [==============================] - 0s 59ms/step - loss: 0.1586 - val_loss: 0.3743
# Epoch 71/100
# 2/2 [==============================] - 0s 66ms/step - loss: 0.1582 - val_loss: 0.3714
# Epoch 72/100
# 2/2 [==============================] - 0s 64ms/step - loss: 0.1581 - val_loss: 0.3698
# Epoch 73/100
# 2/2 [==============================] - 0s 64ms/step - loss: 0.1589 - val_loss: 0.3696
# Epoch 74/100
# 2/2 [==============================] - 0s 64ms/step - loss: 0.1598 - val_loss: 0.3692
# Epoch 75/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.1606 - val_loss: 0.3690
# Epoch 76/100
# 2/2 [==============================] - 0s 67ms/step - loss: 0.1619 - val_loss: 0.3678
# Epoch 77/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.1631 - val_loss: 0.3647
# Epoch 78/100
# 2/2 [==============================] - 0s 62ms/step - loss: 0.1623 - val_loss: 0.3612
# Epoch 79/100
# 2/2 [==============================] - 0s 85ms/step - loss: 0.1607 - val_loss: 0.3578
# Epoch 80/100
# 2/2 [==============================] - 0s 64ms/step - loss: 0.1588 - val_loss: 0.3544
# Epoch 81/100
# 2/2 [==============================] - 0s 67ms/step - loss: 0.1579 - val_loss: 0.3511
# Epoch 82/100
# 2/2 [==============================] - 0s 65ms/step - loss: 0.1572 - val_loss: 0.3483
# Epoch 83/100
# 2/2 [==============================] - 0s 67ms/step - loss: 0.1572 - val_loss: 0.3480
# Epoch 84/100
# 2/2 [==============================] - 0s 62ms/step - loss: 0.1575 - val_loss: 0.3478
# Epoch 85/100
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1572 - val_loss: 0.3480
# Epoch 86/100
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1567 - val_loss: 0.3498
# Epoch 87/100
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1568 - val_loss: 0.3522
# Epoch 88/100
# 2/2 [==============================] - 0s 37ms/step - loss: 0.1570 - val_loss: 0.3548
# Epoch 89/100
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1573 - val_loss: 0.3549
# Epoch 90/100
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1566 - val_loss: 0.3530
# Epoch 91/100
# 2/2 [==============================] - 0s 44ms/step - loss: 0.1556 - val_loss: 0.3510
# Epoch 92/100
# 2/2 [==============================] - 0s 60ms/step - loss: 0.1552 - val_loss: 0.3502
# Epoch 93/100
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1543 - val_loss: 0.3479
# Epoch 94/100
# 2/2 [==============================] - 0s 67ms/step - loss: 0.1537 - val_loss: 0.3431
# Epoch 95/100
# 2/2 [==============================] - 0s 62ms/step - loss: 0.1546 - val_loss: 0.3420
# Epoch 96/100
# 2/2 [==============================] - 0s 76ms/step - loss: 0.1597 - val_loss: 0.3415
# Epoch 97/100
# 2/2 [==============================] - 0s 62ms/step - loss: 0.1606 - val_loss: 0.3382
# Epoch 98/100
# 2/2 [==============================] - 0s 62ms/step - loss: 0.1591 - val_loss: 0.3336
# Epoch 99/100
# 2/2 [==============================] - 0s 64ms/step - loss: 0.1572 - val_loss: 0.3279
# Epoch 100/100
# 2/2 [==============================] - 0s 66ms/step - loss: 0.1554 - val_loss: 0.3237
# 1/1 [==============================] - 0s 449ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 22ms/step
# Epoch 1/100
# 2/2 [==============================] - 3s 593ms/step - loss: 0.2276 - val_loss: 0.1488
# Epoch 2/100
# 2/2 [==============================] - 0s 73ms/step - loss: 0.2177 - val_loss: 0.1422
# Epoch 3/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.2101 - val_loss: 0.1366
# Epoch 4/100
# 2/2 [==============================] - 0s 67ms/step - loss: 0.2050 - val_loss: 0.1323
# Epoch 5/100
# 2/2 [==============================] - 0s 68ms/step - loss: 0.1989 - val_loss: 0.1287
# Epoch 6/100
# 2/2 [==============================] - 0s 68ms/step - loss: 0.1942 - val_loss: 0.1255
# Epoch 7/100
# 2/2 [==============================] - 0s 70ms/step - loss: 0.1899 - val_loss: 0.1232
# Epoch 8/100
# 2/2 [==============================] - 0s 70ms/step - loss: 0.1872 - val_loss: 0.1214
# Epoch 9/100
# 2/2 [==============================] - 0s 70ms/step - loss: 0.1836 - val_loss: 0.1195
# Epoch 10/100
# 2/2 [==============================] - 0s 70ms/step - loss: 0.1803 - val_loss: 0.1181
# Epoch 11/100
# 2/2 [==============================] - 0s 72ms/step - loss: 0.1781 - val_loss: 0.1167
# Epoch 12/100
# 2/2 [==============================] - 0s 66ms/step - loss: 0.1752 - val_loss: 0.1145
# Epoch 13/100
# 2/2 [==============================] - 0s 68ms/step - loss: 0.1720 - val_loss: 0.1123
# Epoch 14/100
# 2/2 [==============================] - 0s 70ms/step - loss: 0.1688 - val_loss: 0.1106
# Epoch 15/100
# 2/2 [==============================] - 0s 78ms/step - loss: 0.1660 - val_loss: 0.1096
# Epoch 16/100
# 2/2 [==============================] - 0s 70ms/step - loss: 0.1637 - val_loss: 0.1082
# Epoch 17/100
# 2/2 [==============================] - 0s 73ms/step - loss: 0.1610 - val_loss: 0.1053
# Epoch 18/100
# 2/2 [==============================] - 0s 90ms/step - loss: 0.1577 - val_loss: 0.1019
# Epoch 19/100
# 2/2 [==============================] - 0s 75ms/step - loss: 0.1542 - val_loss: 0.0990
# Epoch 20/100
# 2/2 [==============================] - 0s 65ms/step - loss: 0.1506 - val_loss: 0.0961
# Epoch 21/100
# 2/2 [==============================] - 0s 64ms/step - loss: 0.1477 - val_loss: 0.0934
# Epoch 22/100
# 2/2 [==============================] - 0s 65ms/step - loss: 0.1458 - val_loss: 0.0912
# Epoch 23/100
# 2/2 [==============================] - 0s 70ms/step - loss: 0.1443 - val_loss: 0.0891
# Epoch 24/100
# 2/2 [==============================] - 0s 67ms/step - loss: 0.1420 - val_loss: 0.0868
# Epoch 25/100
# 2/2 [==============================] - 0s 76ms/step - loss: 0.1390 - val_loss: 0.0849
# Epoch 26/100
# 2/2 [==============================] - 0s 66ms/step - loss: 0.1356 - val_loss: 0.0832
# Epoch 27/100
# 2/2 [==============================] - 0s 66ms/step - loss: 0.1325 - val_loss: 0.0816
# Epoch 28/100
# 2/2 [==============================] - 0s 75ms/step - loss: 0.1304 - val_loss: 0.0799
# Epoch 29/100
# 2/2 [==============================] - 0s 80ms/step - loss: 0.1278 - val_loss: 0.0777
# Epoch 30/100
# 2/2 [==============================] - 0s 65ms/step - loss: 0.1253 - val_loss: 0.0753
# Epoch 31/100
# 2/2 [==============================] - 0s 68ms/step - loss: 0.1220 - val_loss: 0.0731
# Epoch 32/100
# 2/2 [==============================] - 0s 80ms/step - loss: 0.1215 - val_loss: 0.0720
# Epoch 33/100
# 2/2 [==============================] - 0s 68ms/step - loss: 0.1222 - val_loss: 0.0717
# Epoch 34/100
# 2/2 [==============================] - 0s 71ms/step - loss: 0.1240 - val_loss: 0.0715
# Epoch 35/100
# 2/2 [==============================] - 0s 73ms/step - loss: 0.1247 - val_loss: 0.0704
# Epoch 36/100
# 2/2 [==============================] - 0s 67ms/step - loss: 0.1237 - val_loss: 0.0676
# Epoch 37/100
# 2/2 [==============================] - 0s 67ms/step - loss: 0.1192 - val_loss: 0.0636
# Epoch 38/100
# 2/2 [==============================] - 0s 64ms/step - loss: 0.1113 - val_loss: 0.0608
# Epoch 39/100
# 2/2 [==============================] - 0s 75ms/step - loss: 0.1036 - val_loss: 0.0606
# Epoch 40/100
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0994 - val_loss: 0.0658
# Epoch 41/100
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0986 - val_loss: 0.0752
# Epoch 42/100
# 2/2 [==============================] - 0s 44ms/step - loss: 0.1044 - val_loss: 0.0786
# Epoch 43/100
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1040 - val_loss: 0.0712
# Epoch 44/100
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0983 - val_loss: 0.0614
# Epoch 45/100
# 2/2 [==============================] - 0s 66ms/step - loss: 0.0926 - val_loss: 0.0544
# Epoch 46/100
# 2/2 [==============================] - 0s 66ms/step - loss: 0.0890 - val_loss: 0.0507
# Epoch 47/100
# 2/2 [==============================] - 0s 65ms/step - loss: 0.0882 - val_loss: 0.0495
# Epoch 48/100
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0900 - val_loss: 0.0500
# Epoch 49/100
# 2/2 [==============================] - 0s 41ms/step - loss: 0.0930 - val_loss: 0.0507
# Epoch 50/100
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0960 - val_loss: 0.0496
# Epoch 51/100
# 2/2 [==============================] - 0s 67ms/step - loss: 0.0957 - val_loss: 0.0478
# Epoch 52/100
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0938 - val_loss: 0.0468
# Epoch 53/100
# 2/2 [==============================] - 0s 67ms/step - loss: 0.0921 - val_loss: 0.0457
# Epoch 54/100
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0898 - val_loss: 0.0451
# Epoch 55/100
# 2/2 [==============================] - 0s 125ms/step - loss: 0.0876 - val_loss: 0.0442
# Epoch 56/100
# 2/2 [==============================] - 0s 111ms/step - loss: 0.0855 - val_loss: 0.0428
# Epoch 57/100
# 2/2 [==============================] - 0s 95ms/step - loss: 0.0831 - val_loss: 0.0410
# Epoch 58/100
# 2/2 [==============================] - 0s 114ms/step - loss: 0.0804 - val_loss: 0.0397
# Epoch 59/100
# 2/2 [==============================] - 0s 72ms/step - loss: 0.0787 - val_loss: 0.0410
# Epoch 60/100
# 2/2 [==============================] - 0s 67ms/step - loss: 0.0778 - val_loss: 0.0448
# Epoch 61/100
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0796 - val_loss: 0.0501
# Epoch 62/100
# 2/2 [==============================] - 0s 52ms/step - loss: 0.0818 - val_loss: 0.0528
# Epoch 63/100
# 2/2 [==============================] - 0s 55ms/step - loss: 0.0820 - val_loss: 0.0520
# Epoch 64/100
# 2/2 [==============================] - 0s 53ms/step - loss: 0.0804 - val_loss: 0.0508
# Epoch 65/100
# 2/2 [==============================] - 0s 85ms/step - loss: 0.0799 - val_loss: 0.0501
# Epoch 66/100
# 2/2 [==============================] - 0s 53ms/step - loss: 0.0790 - val_loss: 0.0486
# Epoch 67/100
# 2/2 [==============================] - 0s 76ms/step - loss: 0.0784 - val_loss: 0.0470
# Epoch 68/100
# 2/2 [==============================] - 0s 60ms/step - loss: 0.0781 - val_loss: 0.0457
# 1/1 [==============================] - 0s 434ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# Epoch 1/100
# 2/2 [==============================] - 3s 578ms/step - loss: 0.2331 - val_loss: 0.3708
# Epoch 2/100
# 2/2 [==============================] - 0s 66ms/step - loss: 0.2264 - val_loss: 0.3618
# Epoch 3/100
# 2/2 [==============================] - 0s 76ms/step - loss: 0.2203 - val_loss: 0.3535
# Epoch 4/100
# 2/2 [==============================] - 0s 66ms/step - loss: 0.2146 - val_loss: 0.3460
# Epoch 5/100
# 2/2 [==============================] - 0s 64ms/step - loss: 0.2088 - val_loss: 0.3385
# Epoch 6/100
# 2/2 [==============================] - 0s 70ms/step - loss: 0.2034 - val_loss: 0.3306
# Epoch 7/100
# 2/2 [==============================] - 0s 64ms/step - loss: 0.1986 - val_loss: 0.3229
# Epoch 8/100
# 2/2 [==============================] - 0s 66ms/step - loss: 0.1933 - val_loss: 0.3158
# Epoch 9/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.1880 - val_loss: 0.3087
# Epoch 10/100
# 2/2 [==============================] - 0s 66ms/step - loss: 0.1834 - val_loss: 0.3012
# Epoch 11/100
# 2/2 [==============================] - 0s 66ms/step - loss: 0.1806 - val_loss: 0.2953
# Epoch 12/100
# 2/2 [==============================] - 0s 67ms/step - loss: 0.1762 - val_loss: 0.2908
# Epoch 13/100
# 2/2 [==============================] - 0s 64ms/step - loss: 0.1729 - val_loss: 0.2864
# Epoch 14/100
# 2/2 [==============================] - 0s 68ms/step - loss: 0.1696 - val_loss: 0.2818
# Epoch 15/100
# 2/2 [==============================] - 0s 75ms/step - loss: 0.1660 - val_loss: 0.2770
# Epoch 16/100
# 2/2 [==============================] - 0s 65ms/step - loss: 0.1628 - val_loss: 0.2729
# Epoch 17/100
# 2/2 [==============================] - 0s 69ms/step - loss: 0.1591 - val_loss: 0.2694
# Epoch 18/100
# 2/2 [==============================] - 0s 64ms/step - loss: 0.1560 - val_loss: 0.2663
# Epoch 19/100
# 2/2 [==============================] - 0s 67ms/step - loss: 0.1528 - val_loss: 0.2637
# Epoch 20/100
# 2/2 [==============================] - 0s 76ms/step - loss: 0.1506 - val_loss: 0.2619
# Epoch 21/100
# 2/2 [==============================] - 0s 67ms/step - loss: 0.1474 - val_loss: 0.2607
# Epoch 22/100
# 2/2 [==============================] - 0s 65ms/step - loss: 0.1435 - val_loss: 0.2598
# Epoch 23/100
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1396 - val_loss: 0.2604
# Epoch 24/100
# 2/2 [==============================] - 0s 45ms/step - loss: 0.1366 - val_loss: 0.2618
# Epoch 25/100
# 2/2 [==============================] - 0s 43ms/step - loss: 0.1343 - val_loss: 0.2626
# Epoch 26/100
# 2/2 [==============================] - 0s 44ms/step - loss: 0.1331 - val_loss: 0.2626
# Epoch 27/100
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1319 - val_loss: 0.2619
# Epoch 28/100
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1307 - val_loss: 0.2616
# Epoch 29/100
# 2/2 [==============================] - 0s 51ms/step - loss: 0.1291 - val_loss: 0.2609
# Epoch 30/100
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1279 - val_loss: 0.2599
# Epoch 31/100
# 2/2 [==============================] - 0s 41ms/step - loss: 0.1266 - val_loss: 0.2600
# Epoch 32/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.1265 - val_loss: 0.2597
# Epoch 33/100
# 2/2 [==============================] - 0s 86ms/step - loss: 0.1263 - val_loss: 0.2583
# Epoch 34/100
# 2/2 [==============================] - 0s 97ms/step - loss: 0.1258 - val_loss: 0.2565
# Epoch 35/100
# 2/2 [==============================] - 0s 113ms/step - loss: 0.1263 - val_loss: 0.2554
# Epoch 36/100
# 2/2 [==============================] - 0s 125ms/step - loss: 0.1259 - val_loss: 0.2552
# Epoch 37/100
# 2/2 [==============================] - 0s 50ms/step - loss: 0.1257 - val_loss: 0.2555
# Epoch 38/100
# 2/2 [==============================] - 0s 50ms/step - loss: 0.1254 - val_loss: 0.2562
# Epoch 39/100
# 2/2 [==============================] - 0s 60ms/step - loss: 0.1242 - val_loss: 0.2574
# Epoch 40/100
# 2/2 [==============================] - 0s 64ms/step - loss: 0.1230 - val_loss: 0.2587
# Epoch 41/100
# 2/2 [==============================] - 0s 74ms/step - loss: 0.1218 - val_loss: 0.2590
# Epoch 42/100
# 2/2 [==============================] - 0s 67ms/step - loss: 0.1213 - val_loss: 0.2590
# Epoch 43/100
# 2/2 [==============================] - 0s 72ms/step - loss: 0.1207 - val_loss: 0.2595
# Epoch 44/100
# 2/2 [==============================] - 0s 65ms/step - loss: 0.1205 - val_loss: 0.2593
# Epoch 45/100
# 2/2 [==============================] - 0s 52ms/step - loss: 0.1202 - val_loss: 0.2577
# Epoch 46/100
# 2/2 [==============================] - 0s 54ms/step - loss: 0.1200 - val_loss: 0.2558
# 1/1 [==============================] - 1s 668ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step

# %%
# Plot predictions by category
plt.figure(figsize=(15, 15))

# Low category plot
plt.subplot(3, 1, 1)
plt.plot(low_sales['date'], low_sales['sales'], label='Actual Sales')
plt.plot(low_predict_df['date'], low_predict_df['LSTM Prediction'], label='Predicted Sales (Low)')
plt.plot(low_future_df['date'], low_future_df['LSTM Prediction'], label='Future Prediction (Low)', linestyle='--')
plt.title("Customer Sales Forecast - Low Category")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.legend()

# Mid category plot
plt.subplot(3, 1, 2)
plt.plot(mid_sales['date'], mid_sales['sales'], label='Actual Sales')
plt.plot(mid_predict_df['date'], mid_predict_df['LSTM Prediction'], label='Predicted Sales (Mid)')
plt.plot(mid_future_df['date'], mid_future_df['LSTM Prediction'], label='Future Prediction (Mid)', linestyle='--')
plt.title("Customer Sales Forecast - Mid Category")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.legend()

# High category plot
plt.subplot(3, 1, 3)
plt.plot(high_sales['date'], high_sales['sales'], label='Actual Sales')
plt.plot(high_predict_df['date'], high_predict_df['LSTM Prediction'], label='Predicted Sales (High)')
plt.plot(high_future_df['date'], high_future_df['LSTM Prediction'], label='Future Prediction (High)', linestyle='--')
plt.title("Customer Sales Forecast - High Category")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.legend()

plt.tight_layout()
plt.show()

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, LSTM, Dropout, Input
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# Load data
url = 'https://raw.githubusercontent.com/C4AnN/Models/GT111/dataset_processing%20(2)/file_gabungan2.csv'
store_sales = pd.read_csv(url)

store_sales['date'] = pd.to_datetime(store_sales['date'])

# Categorize data based on price
def categorize_price(price):
    if price < 8000000:
        return 'low'
    elif 8000000 <= price < 16000000:
        return 'mid'
    else:
        return 'high'

store_sales['category'] = store_sales['price'].apply(categorize_price)

# Drop unnecessary columns
store_sales = store_sales.drop(['name', 'price'], axis=1)

# Function to process and predict for each category
def process_category(data, category_name, window_size):
    data = data[data['category'] == category_name].drop(['category'], axis=1)
    data['date'] = data['date'].dt.to_period("M")
    monthly_sales = data.groupby('date').sum().reset_index()
    monthly_sales['date'] = monthly_sales['date'].dt.to_timestamp()

    # Calculate sales difference
    monthly_sales['sales_diff'] = monthly_sales['sales'].diff()
    monthly_sales = monthly_sales.dropna()

    # Prepare supervised data with a window size (6 months)
    supervised_data = monthly_sales.drop(['date', 'sales'], axis=1)
    for i in range(1, window_size + 1):
        col_name = 'month_' + str(i)
        supervised_data[col_name] = supervised_data['sales_diff'].shift(i)
    supervised_data = supervised_data.dropna().reset_index(drop=True)

    # Split into train and test data
    train_data = supervised_data[:-12]
    test_data = supervised_data[-12:]

    # Scale the data
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler.fit(train_data)
    train_data_scaled = scaler.transform(train_data)
    test_data_scaled = scaler.transform(test_data)

    X_train, y_train = train_data_scaled[:, 1:], train_data_scaled[:, 0]
    X_test, y_test = test_data_scaled[:, 1:], test_data_scaled[:, 0]

    # Reshape input to be 3D [samples, timesteps, features]
    X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
    X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

    # Build LSTM model
    model = Sequential()
    model.add(Input(shape=(X_train.shape[1], 1)))
    model.add(LSTM(200, activation='tanh', return_sequences=True))
    model.add(Dropout(0.3))
    model.add(LSTM(100, activation='tanh'))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mse')

    # Setup callbacks
    early_stop = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
    model_checkpoint = ModelCheckpoint(f'best_model_{category_name}.keras', monitor='val_loss', save_best_only=True)

    # Train the model
    history = model.fit(X_train, y_train, epochs=300, batch_size=16, validation_data=(X_test, y_test), callbacks=[early_stop, model_checkpoint], verbose=1)

    # Save the model
    model.save(f'best_model_{category_name}.keras')

    # Make predictions
    lstm_pre = model.predict(X_test)

    # Prepare prediction DataFrame
    sales_dates = monthly_sales['date'][-12:].reset_index(drop=True)
    predict_df = pd.DataFrame(sales_dates, columns=['date'])

    act_sales = monthly_sales['sales'][-13:].to_list()
    lstm_pre = lstm_pre.reshape(-1, 1)
    lstm_pre_test_set = np.concatenate([lstm_pre, X_test.reshape((X_test.shape[0], X_test.shape[1]))], axis=1)
    lstm_pre_test_set = scaler.inverse_transform(lstm_pre_test_set)

    result_list = []
    for index in range(0, len(lstm_pre_test_set)):
        result_list.append(lstm_pre_test_set[index][0] + act_sales[index + 1])
    lstm_pre_series = pd.Series(result_list, name="LSTM Prediction")
    predict_df = predict_df.merge(lstm_pre_series, left_index=True, right_index=True)

    # Predict next 12 months
    future_predictions = []
    last_data = supervised_data[-1:].copy()

    for month in range(6):
        last_data_scaled = scaler.transform(last_data)
        X_last = last_data_scaled[:, 1:].reshape((1, X_train.shape[1], 1))
        next_pred = model.predict(X_last)[0, 0]

        future_pred = np.concatenate([[next_pred], last_data_scaled[0, 1:]])
        future_pred = scaler.inverse_transform([future_pred])

        future_sales = future_pred[0][0] + monthly_sales['sales'].iloc[-1]
        future_predictions.append(future_sales)

        new_row = np.append([next_pred], last_data.values[0, :-1])
        last_data = pd.DataFrame([new_row], columns=supervised_data.columns)

        # Update the data for the next iteration to use the predicted value
        if month >= window_size - 1:
            last_data.iloc[0, 1] = next_pred

    future_dates = pd.date_range(start=monthly_sales['date'].iloc[-1] + pd.DateOffset(months=1), periods=12, freq='M')
    future_df = pd.DataFrame({'date': future_dates, 'LSTM Prediction': future_predictions})

    return monthly_sales, predict_df, future_df

# Process and predict for each category using window size of 6 months
window_size = 6

low_sales, low_predict_df, low_future_df = process_category(store_sales, 'low', window_size)
mid_sales, mid_predict_df, mid_future_df = process_category(store_sales, 'mid', window_size)
high_sales, high_predict_df, high_future_df = process_category(store_sales, 'high', window_size)

# Plot predictions by category
plt.figure(figsize=(15, 15))

# Low category plot
plt.subplot(3, 1, 1)
plt.plot(low_sales['date'], low_sales['sales'], label='Actual Sales')
plt.plot(low_predict_df['date'], low_predict_df['LSTM Prediction'], label='Predicted Sales (Low)')
plt.plot(low_future_df['date'], low_future_df['LSTM Prediction'], label='Future Prediction (Low)', linestyle='--')
plt.title("Customer Sales Forecast - Low Category (Window Size: 6)")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.legend()

# Mid category plot
plt.subplot(3, 1, 2)
plt.plot(mid_sales['date'], mid_sales['sales'], label='Actual Sales')
plt.plot(mid_predict_df['date'], mid_predict_df['LSTM Prediction'], label='Predicted Sales (Mid)')
plt.plot(mid_future_df['date'], mid_future_df['LSTM Prediction'], label='Future Prediction (Mid)', linestyle='--')
plt.title("Customer Sales Forecast - Mid Category (Window Size: 6)")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.legend()

# High category plot
plt.subplot(3, 1, 3)
plt.plot(high_sales['date'], high_sales['sales'], label='Actual Sales')
plt.plot(high_predict_df['date'], high_predict_df['LSTM Prediction'], label='Predicted Sales (High)')
plt.plot(high_future_df['date'], high_future_df['LSTM Prediction'], label='Future Prediction (High)', linestyle='--')
plt.title("Customer Sales Forecast - High Category (Window Size: 6)")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 6s 413ms/step - loss: 0.2064 - val_loss: 0.5029
# Epoch 2/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.2327 - val_loss: 0.4948
# Epoch 3/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.2242 - val_loss: 0.5004
# Epoch 4/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.2173 - val_loss: 0.5178
# Epoch 5/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.1997 - val_loss: 0.5460
# Epoch 6/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.2030 - val_loss: 0.5680
# Epoch 7/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 517ms/step - loss: 0.2026 - val_loss: 0.5722
# Epoch 8/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.2298 - val_loss: 0.5599
# Epoch 9/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.1801 - val_loss: 0.5458
# Epoch 10/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.1943 - val_loss: 0.5337
# Epoch 11/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.2034 - val_loss: 0.5399
# Epoch 12/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.1971 - val_loss: 0.5450
# Epoch 13/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.2000 - val_loss: 0.5557
# Epoch 14/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.2110 - val_loss: 0.5601
# Epoch 15/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.2084 - val_loss: 0.5659
# Epoch 16/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.2017 - val_loss: 0.5525
# Epoch 17/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.1808 - val_loss: 0.5426
# Epoch 18/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.2140 - val_loss: 0.5349
# Epoch 19/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.2157 - val_loss: 0.5363
# Epoch 20/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.1821 - val_loss: 0.5406
# Epoch 21/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.1949 - val_loss: 0.5575
# Epoch 22/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.2209 - val_loss: 0.5872
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 476ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Epoch 1/300
# C:\Users\MyPC\AppData\Local\Temp\ipykernel_7032\1786481005.py:125: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   future_dates = pd.date_range(start=monthly_sales['date'].iloc[-1] + pd.DateOffset(months=1), periods=12, freq='M')
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 274ms/step - loss: 0.2181 - val_loss: 0.1363
# Epoch 2/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.1821 - val_loss: 0.1273
# Epoch 3/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.1768 - val_loss: 0.1200
# Epoch 4/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.1905 - val_loss: 0.1133
# Epoch 5/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.1640 - val_loss: 0.1076
# Epoch 6/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.1661 - val_loss: 0.1023
# Epoch 7/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.1763 - val_loss: 0.0966
# Epoch 8/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1832 - val_loss: 0.0908
# Epoch 9/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.1518 - val_loss: 0.0850
# Epoch 10/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.1769 - val_loss: 0.0817
# Epoch 11/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.1426 - val_loss: 0.0782
# Epoch 12/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.1431 - val_loss: 0.0738
# Epoch 13/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.1572 - val_loss: 0.0741
# Epoch 14/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.1181 - val_loss: 0.0741
# Epoch 15/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.1379 - val_loss: 0.0770
# Epoch 16/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.1653 - val_loss: 0.0852
# Epoch 17/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.1338 - val_loss: 0.0819
# Epoch 18/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.1344 - val_loss: 0.0835
# Epoch 19/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1478 - val_loss: 0.0901
# Epoch 20/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.1322 - val_loss: 0.0912
# Epoch 21/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.1162 - val_loss: 0.0879
# Epoch 22/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1304 - val_loss: 0.0861
# Epoch 23/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.1088 - val_loss: 0.0859
# Epoch 24/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.1459 - val_loss: 0.0871
# Epoch 25/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1102 - val_loss: 0.0883
# Epoch 26/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1338 - val_loss: 0.0927
# Epoch 27/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1363 - val_loss: 0.0897
# Epoch 28/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1183 - val_loss: 0.0878
# Epoch 29/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1083 - val_loss: 0.0852
# Epoch 30/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1434 - val_loss: 0.0865
# Epoch 31/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.1216 - val_loss: 0.0926
# Epoch 32/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.1170 - val_loss: 0.0932
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Epoch 1/300
# C:\Users\MyPC\AppData\Local\Temp\ipykernel_7032\1786481005.py:125: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   future_dates = pd.date_range(start=monthly_sales['date'].iloc[-1] + pd.DateOffset(months=1), periods=12, freq='M')
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 324ms/step - loss: 0.2405 - val_loss: 0.3769
# Epoch 2/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.1954 - val_loss: 0.3648
# Epoch 3/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.1901 - val_loss: 0.3610
# Epoch 4/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.1843 - val_loss: 0.3531
# Epoch 5/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.1791 - val_loss: 0.3466
# Epoch 6/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.1651 - val_loss: 0.3458
# Epoch 7/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.2019 - val_loss: 0.3510
# Epoch 8/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.1907 - val_loss: 0.3530
# Epoch 9/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.1928 - val_loss: 0.3553
# Epoch 10/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.2091 - val_loss: 0.3568
# Epoch 11/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.1968 - val_loss: 0.3568
# Epoch 12/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.2099 - val_loss: 0.3595
# Epoch 13/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.1930 - val_loss: 0.3659
# Epoch 14/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1782 - val_loss: 0.3687
# Epoch 15/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.2080 - val_loss: 0.3660
# Epoch 16/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.2092 - val_loss: 0.3704
# Epoch 17/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.2008 - val_loss: 0.3712
# Epoch 18/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.1671 - val_loss: 0.3730
# Epoch 19/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.1861 - val_loss: 0.3749
# Epoch 20/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.2112 - val_loss: 0.3828
# Epoch 21/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.1638 - val_loss: 0.3820
# Epoch 22/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.2053 - val_loss: 0.3751
# Epoch 23/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.1736 - val_loss: 0.3713
# Epoch 24/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.1795 - val_loss: 0.3642
# Epoch 25/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.2038 - val_loss: 0.3605
# Epoch 26/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.1715 - val_loss: 0.3601
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# C:\Users\MyPC\AppData\Local\Temp\ipykernel_7032\1786481005.py:125: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   future_dates = pd.date_range(start=monthly_sales['date'].iloc[-1] + pd.DateOffset(months=1), periods=12, freq='M')

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, LSTM, Dropout, Input
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# Load data
url = 'https://raw.githubusercontent.com/C4AnN/Models/GT111/dataset_processing%20(2)/file_gabungan2.csv'
store_sales = pd.read_csv(url)

store_sales['date'] = pd.to_datetime(store_sales['date'])

# Categorize data based on price
def categorize_price(price):
    if price < 8000000:
        return 'low'
    elif 8000000 <= price < 16000000:
        return 'mid'
    else:
        return 'high'

store_sales['category'] = store_sales['price'].apply(categorize_price)

# Drop unnecessary columns
store_sales = store_sales.drop(['name', 'price'], axis=1)

# Function to process and predict for each category
def process_category(data, category_name, window_size):
    data = data[data['category'] == category_name].drop(['category'], axis=1)
    data['date'] = data['date'].dt.to_period("M")
    monthly_sales = data.groupby('date').sum().reset_index()
    monthly_sales['date'] = monthly_sales['date'].dt.to_timestamp()

    # Calculate sales difference
    monthly_sales['sales_diff'] = monthly_sales['sales'].diff()
    monthly_sales = monthly_sales.dropna()

    # Prepare supervised data with a window size (6 months)
    supervised_data = monthly_sales.drop(['date', 'sales'], axis=1)
    for i in range(1, window_size + 1):
        col_name = 'month_' + str(i)
        supervised_data[col_name] = supervised_data['sales_diff'].shift(i)
    supervised_data = supervised_data.dropna().reset_index(drop=True)

    # Split into train and test data
    train_data = supervised_data[:-12]
    test_data = supervised_data[-12:]

    # Scale the data
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler.fit(train_data)
    train_data_scaled = scaler.transform(train_data)
    test_data_scaled = scaler.transform(test_data)

    X_train, y_train = train_data_scaled[:, 1:], train_data_scaled[:, 0]
    X_test, y_test = test_data_scaled[:, 1:], test_data_scaled[:, 0]

    # Reshape input to be 3D [samples, timesteps, features]
    X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
    X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

    # Build LSTM model
    model = Sequential()
    model.add(Input(shape=(X_train.shape[1], 1)))
    model.add(LSTM(200, activation='tanh', return_sequences=True))
    model.add(Dropout(0.3))
    model.add(LSTM(100, activation='tanh'))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mse')

    # Setup callbacks
    early_stop = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
    model_checkpoint = ModelCheckpoint(f'best_model_{category_name}.keras', monitor='val_loss', save_best_only=True)

    # Train the model
    history = model.fit(X_train, y_train, epochs=300, batch_size=16, validation_data=(X_test, y_test), callbacks=[early_stop, model_checkpoint], verbose=1)

    # Save the model
    model.save(f'best_model_{category_name}.keras')

    # Make predictions
    lstm_pre = model.predict(X_test)

    # Prepare prediction DataFrame
    sales_dates = monthly_sales['date'][-12:].reset_index(drop=True)
    predict_df = pd.DataFrame(sales_dates, columns=['date'])

    act_sales = monthly_sales['sales'][-13:].to_list()
    lstm_pre = lstm_pre.reshape(-1, 1)
    lstm_pre_test_set = np.concatenate([lstm_pre, X_test.reshape((X_test.shape[0], X_test.shape[1]))], axis=1)
    lstm_pre_test_set = scaler.inverse_transform(lstm_pre_test_set)

    result_list = []
    for index in range(0, len(lstm_pre_test_set)):
        result_list.append(lstm_pre_test_set[index][0] + act_sales[index + 1])
    lstm_pre_series = pd.Series(result_list, name="LSTM Prediction")
    predict_df = predict_df.merge(lstm_pre_series, left_index=True, right_index=True)

    # Predict next 12 months
    future_predictions = []
    last_data = supervised_data[-1:].copy()

    for _ in range(12):
        last_data_scaled = scaler.transform(last_data)
        X_last = last_data_scaled[:, 1:].reshape((1, X_train.shape[1], 1))
        next_pred = model.predict(X_last)[0, 0]

        future_pred = np.concatenate([[next_pred], last_data_scaled[0, 1:]])
        future_pred = scaler.inverse_transform([future_pred])

        future_predictions.append(future_pred[0][0] + monthly_sales['sales'].iloc[-1])

        new_row = np.append([next_pred], last_data.values[0, :-1])
        last_data = pd.DataFrame([new_row], columns=supervised_data.columns)

    future_dates = pd.date_range(start=monthly_sales['date'].iloc[-1] + pd.DateOffset(months=1), periods=12, freq='M')
    future_df = pd.DataFrame({'date': future_dates, 'LSTM Prediction': future_predictions})

    return monthly_sales, predict_df, future_df

# Process and predict for each category using window size of 6 months
window_size = 6

low_sales, low_predict_df, low_future_df = process_category(store_sales, 'low', window_size)
mid_sales, mid_predict_df, mid_future_df = process_category(store_sales, 'mid', window_size)
high_sales, high_predict_df, high_future_df = process_category(store_sales, 'high', window_size)

# Plot predictions by category
plt.figure(figsize=(15, 15))

# Low category plot
plt.subplot(3, 1, 1)
plt.plot(low_sales['date'], low_sales['sales'], label='Actual Sales')
plt.plot(low_predict_df['date'], low_predict_df['LSTM Prediction'], label='Predicted Sales (Low)')
plt.plot(low_future_df['date'], low_future_df['LSTM Prediction'], label='Future Prediction (Low)', linestyle='--')
plt.title("Customer Sales Forecast - Low Category (Window Size: 6)")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.legend()

# Mid category plot
plt.subplot(3, 1, 2)
plt.plot(mid_sales['date'], mid_sales['sales'], label='Actual Sales')
plt.plot(mid_predict_df['date'], mid_predict_df['LSTM Prediction'], label='Predicted Sales (Mid)')
plt.plot(mid_future_df['date'], mid_future_df['LSTM Prediction'], label='Future Prediction (Mid)', linestyle='--')
plt.title("Customer Sales Forecast - Mid Category (Window Size: 6)")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.legend()

# High category plot
plt.subplot(3, 1, 3)
plt.plot(high_sales['date'], high_sales['sales'], label='Actual Sales')
plt.plot(high_predict_df['date'], high_predict_df['LSTM Prediction'], label='Predicted Sales (High)')
plt.plot(high_future_df['date'], high_future_df['LSTM Prediction'], label='Future Prediction (High)', linestyle='--')
plt.title("Customer Sales Forecast - High Category (Window Size: 6)")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 243ms/step - loss: 0.2409 - val_loss: 0.5020
# Epoch 2/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.2348 - val_loss: 0.4943
# Epoch 3/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2266 - val_loss: 0.4967
# Epoch 4/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.2609 - val_loss: 0.5033
# Epoch 5/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2177 - val_loss: 0.5190
# Epoch 6/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.2086 - val_loss: 0.5399
# Epoch 7/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.2230 - val_loss: 0.5655
# Epoch 8/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.1953 - val_loss: 0.5763
# Epoch 9/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.1893 - val_loss: 0.5857
# Epoch 10/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2125 - val_loss: 0.5817
# Epoch 11/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.1875 - val_loss: 0.5697
# Epoch 12/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.1978 - val_loss: 0.5600
# Epoch 13/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.2101 - val_loss: 0.5496
# Epoch 14/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.2271 - val_loss: 0.5353
# Epoch 15/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2070 - val_loss: 0.5241
# Epoch 16/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2056 - val_loss: 0.5208
# Epoch 17/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.2174 - val_loss: 0.5270
# Epoch 18/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1818 - val_loss: 0.5301
# Epoch 19/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.1882 - val_loss: 0.5387
# Epoch 20/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.1849 - val_loss: 0.5514
# Epoch 21/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.1713 - val_loss: 0.5661
# Epoch 22/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.1994 - val_loss: 0.5605
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Epoch 1/300
# C:\Users\MyPC\AppData\Local\Temp\ipykernel_7032\964688373.py:120: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   future_dates = pd.date_range(start=monthly_sales['date'].iloc[-1] + pd.DateOffset(months=1), periods=12, freq='M')
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 268ms/step - loss: 0.1804 - val_loss: 0.1319
# Epoch 2/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.1615 - val_loss: 0.1219
# Epoch 3/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.1766 - val_loss: 0.1149
# Epoch 4/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.1690 - val_loss: 0.1058
# Epoch 5/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.1654 - val_loss: 0.0983
# Epoch 6/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.1605 - val_loss: 0.0901
# Epoch 7/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.1512 - val_loss: 0.0836
# Epoch 8/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.1497 - val_loss: 0.0805
# Epoch 9/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.1293 - val_loss: 0.0766
# Epoch 10/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.1366 - val_loss: 0.0737
# Epoch 11/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.1279 - val_loss: 0.0736
# Epoch 12/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1511 - val_loss: 0.0765
# Epoch 13/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.1586 - val_loss: 0.0763
# Epoch 14/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.1010 - val_loss: 0.0759
# Epoch 15/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.1355 - val_loss: 0.0754
# Epoch 16/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.1285 - val_loss: 0.0782
# Epoch 17/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.1175 - val_loss: 0.0806
# Epoch 18/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.1094 - val_loss: 0.0833
# Epoch 19/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.1225 - val_loss: 0.0815
# Epoch 20/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.1337 - val_loss: 0.0825
# Epoch 21/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1190 - val_loss: 0.0836
# Epoch 22/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.1383 - val_loss: 0.0894
# Epoch 23/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.1127 - val_loss: 0.0958
# Epoch 24/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1144 - val_loss: 0.0939
# Epoch 25/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1246 - val_loss: 0.0923
# Epoch 26/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.1325 - val_loss: 0.0906
# Epoch 27/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.1186 - val_loss: 0.0911
# Epoch 28/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1166 - val_loss: 0.0944
# Epoch 29/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.1138 - val_loss: 0.0950
# Epoch 30/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1446 - val_loss: 0.0962
# Epoch 31/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.1325 - val_loss: 0.0976
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Epoch 1/300
# C:\Users\MyPC\AppData\Local\Temp\ipykernel_7032\964688373.py:120: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   future_dates = pd.date_range(start=monthly_sales['date'].iloc[-1] + pd.DateOffset(months=1), periods=12, freq='M')
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 269ms/step - loss: 0.2583 - val_loss: 0.3688
# Epoch 2/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.2211 - val_loss: 0.3627
# Epoch 3/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.2303 - val_loss: 0.3551
# Epoch 4/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.2060 - val_loss: 0.3487
# Epoch 5/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.1846 - val_loss: 0.3449
# Epoch 6/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.1747 - val_loss: 0.3406
# Epoch 7/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.1866 - val_loss: 0.3417
# Epoch 8/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.1870 - val_loss: 0.3468
# Epoch 9/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.1756 - val_loss: 0.3534
# Epoch 10/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.1919 - val_loss: 0.3599
# Epoch 11/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.1565 - val_loss: 0.3673
# Epoch 12/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.1934 - val_loss: 0.3714
# Epoch 13/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.1706 - val_loss: 0.3747
# Epoch 14/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.1908 - val_loss: 0.3762
# Epoch 15/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.2119 - val_loss: 0.3738
# Epoch 16/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.1789 - val_loss: 0.3722
# Epoch 17/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.1770 - val_loss: 0.3678
# Epoch 18/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.1936 - val_loss: 0.3691
# Epoch 19/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.2054 - val_loss: 0.3696
# Epoch 20/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.1713 - val_loss: 0.3736
# Epoch 21/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.1425 - val_loss: 0.3755
# Epoch 22/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.1634 - val_loss: 0.3726
# Epoch 23/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.1572 - val_loss: 0.3694
# Epoch 24/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.1950 - val_loss: 0.3705
# Epoch 25/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.1834 - val_loss: 0.3696
# Epoch 26/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.2005 - val_loss: 0.3675
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 445ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 394ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# C:\Users\MyPC\AppData\Local\Temp\ipykernel_7032\964688373.py:120: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   future_dates = pd.date_range(start=monthly_sales['date'].iloc[-1] + pd.DateOffset(months=1), periods=12, freq='M')
