# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# Load data
url = 'https://raw.githubusercontent.com/C4AnN/Models/main/dataset_processing%20(2)/file_gabungan2.csv'
store_sales = pd.read_csv(url)
store_sales['date'] = pd.to_datetime(store_sales['date'])

# Categorize data based on price
def categorize_price(price):
    if price < 8000000:
        return 'low'
    elif 8000000 <= price < 16000000:
        return 'mid'
    else:
        return 'high'

store_sales['category'] = store_sales['price'].apply(categorize_price)

# Drop unnecessary columns
store_sales = store_sales.drop(['name', 'price'], axis=1)

# Function to process and predict for each category
def process_category(data, category_name):
    data = data[data['category'] == category_name].drop(['category'], axis=1)
    data['date'] = data['date'].dt.to_period("M")
    monthly_sales = data.groupby('date').sum().reset_index()
    monthly_sales['date'] = monthly_sales['date'].dt.to_timestamp()

    # Calculate sales difference
    monthly_sales['sales_diff'] = monthly_sales['sales'].diff()
    monthly_sales = monthly_sales.dropna()

    # Prepare supervised data
    supervised_data = monthly_sales.drop(['date', 'sales'], axis=1)
    for i in range(1, 13):
        col_name = 'month_' + str(i)
        supervised_data[col_name] = supervised_data['sales_diff'].shift(i)
    supervised_data = supervised_data.dropna().reset_index(drop=True)

    # Split into train and test data
    train_data = supervised_data[:-12]
    test_data = supervised_data[-12:]

    # Scale the data
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler.fit(train_data)
    train_data = scaler.transform(train_data)
    test_data = scaler.transform(test_data)

    X_train, y_train = train_data[:, 1:], train_data[:, 0]
    X_test, y_test = test_data[:, 1:], test_data[:, 0]

    # Reshape input to be 3D [samples, timesteps, features]
    X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
    X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

    # Build LSTM model
    model = Sequential()
    model.add(LSTM(50, activation='sigmoid', input_shape=(X_train.shape[1], 1)))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mse')

    # Train the model
    early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
    history = model.fit(X_train, y_train, epochs=100, validation_data=(X_test, y_test), callbacks=[early_stop], verbose=1)

    # Make predictions
    lstm_pre = model.predict(X_test)

    # Prepare prediction DataFrame
    sales_dates = monthly_sales['date'][-12:].reset_index(drop=True)
    predict_df = pd.DataFrame(sales_dates, columns=['date'])

    act_sales = monthly_sales['sales'][-13:].to_list()
    lstm_pre = lstm_pre.reshape(-1, 1)
    lstm_pre_test_set = np.concatenate([lstm_pre, X_test.reshape((X_test.shape[0], X_test.shape[1]))], axis=1)
    lstm_pre_test_set = scaler.inverse_transform(lstm_pre_test_set)

    result_list = []
    for index in range(0, len(lstm_pre_test_set)):
        result_list.append(lstm_pre_test_set[index][0] + act_sales[index])
    lstm_pre_series = pd.Series(result_list, name="LSTM Prediction")
    predict_df = predict_df.merge(lstm_pre_series, left_index=True, right_index=True)

    return monthly_sales, predict_df

# Process and predict for each category
low_sales, low_predict_df = process_category(store_sales, 'low')
mid_sales, mid_predict_df = process_category(store_sales, 'mid')
high_sales, high_predict_df = process_category(store_sales, 'high')

# Plot predictions by category
plt.figure(figsize=(15, 15))

# Low category plot
plt.subplot(3, 1, 1)
plt.plot(low_sales['date'], low_sales['sales'], label='Actual Sales')
plt.plot(low_predict_df['date'], low_predict_df['LSTM Prediction'], label='Predicted Sales (Low)')
plt.title("Customer Sales Forecast - Low Category")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.legend()

# Mid category plot
plt.subplot(3, 1, 2)
plt.plot(mid_sales['date'], mid_sales['sales'], label='Actual Sales')
plt.plot(mid_predict_df['date'], mid_predict_df['LSTM Prediction'], label='Predicted Sales (Mid)')
plt.title("Customer Sales Forecast - Mid Category")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.legend()

# High category plot
plt.subplot(3, 1, 3)
plt.plot(high_sales['date'], high_sales['sales'], label='Actual Sales')
plt.plot(high_predict_df['date'], high_predict_df['LSTM Prediction'], label='Predicted Sales (High)')
plt.title("Customer Sales Forecast - High Category")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/100
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 361ms/step - loss: 0.2457 - val_loss: 0.6230
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.2436 - val_loss: 0.6205
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.2437 - val_loss: 0.6200
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.2358 - val_loss: 0.6197
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.2419 - val_loss: 0.6237
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.2392 - val_loss: 0.6251
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.2401 - val_loss: 0.6216
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.2354 - val_loss: 0.6168
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.2229 - val_loss: 0.6154
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.2451 - val_loss: 0.6177
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.2423 - val_loss: 0.6190
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.2520 - val_loss: 0.6162
# Epoch 13/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.2462 - val_loss: 0.6138
# Epoch 14/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.2516 - val_loss: 0.6124
# Epoch 15/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.2472 - val_loss: 0.6105
# Epoch 16/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.2466 - val_loss: 0.6090
# Epoch 17/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.2324 - val_loss: 0.6082
# Epoch 18/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.2398 - val_loss: 0.6073
# Epoch 19/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.2281 - val_loss: 0.6065
# Epoch 20/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.2376 - val_loss: 0.6060
# Epoch 21/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.2332 - val_loss: 0.6066
# Epoch 22/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.2337 - val_loss: 0.6083
# Epoch 23/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.2259 - val_loss: 0.6117
# Epoch 24/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.2183 - val_loss: 0.6133
# Epoch 25/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.2283 - val_loss: 0.6088
# Epoch 26/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.2240 - val_loss: 0.6063
# Epoch 27/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.2247 - val_loss: 0.6084
# Epoch 28/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.2277 - val_loss: 0.6112
# Epoch 29/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.2289 - val_loss: 0.6095
# Epoch 30/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.2271 - val_loss: 0.6039
# Epoch 31/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.2190 - val_loss: 0.6013
# Epoch 32/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.2174 - val_loss: 0.6016
# Epoch 33/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.2272 - val_loss: 0.6027
# Epoch 34/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.2252 - val_loss: 0.6058
# Epoch 35/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.2284 - val_loss: 0.6096
# Epoch 36/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.2229 - val_loss: 0.6091
# Epoch 37/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.2170 - val_loss: 0.6018
# Epoch 38/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.2191 - val_loss: 0.5958
# Epoch 39/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.2249 - val_loss: 0.5931
# Epoch 40/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.2198 - val_loss: 0.5921
# Epoch 41/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.2253 - val_loss: 0.5923
# Epoch 42/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.2192 - val_loss: 0.5933
# Epoch 43/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.2236 - val_loss: 0.5944
# Epoch 44/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.2213 - val_loss: 0.5964
# Epoch 45/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.2091 - val_loss: 0.5954
# Epoch 46/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.2068 - val_loss: 0.5896
# Epoch 47/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.2199 - val_loss: 0.5863
# Epoch 48/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.2196 - val_loss: 0.5863
# Epoch 49/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.2255 - val_loss: 0.5867
# Epoch 50/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.2318 - val_loss: 0.5852
# Epoch 51/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.2230 - val_loss: 0.5836
# Epoch 52/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.2169 - val_loss: 0.5831
# Epoch 53/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.2149 - val_loss: 0.5828
# Epoch 54/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.2169 - val_loss: 0.5830
# Epoch 55/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.2041 - val_loss: 0.5840
# Epoch 56/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.2169 - val_loss: 0.5848
# Epoch 57/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.2142 - val_loss: 0.5853
# Epoch 58/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.2089 - val_loss: 0.5853
# Epoch 59/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.2079 - val_loss: 0.5870
# Epoch 60/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.2168 - val_loss: 0.5905
# Epoch 61/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.2153 - val_loss: 0.5916
# Epoch 62/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.2127 - val_loss: 0.5906
# Epoch 63/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.2167 - val_loss: 0.5893
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step
# Epoch 1/100
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 299ms/step - loss: 0.5521 - val_loss: 0.3629
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.4078 - val_loss: 0.2615
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.3148 - val_loss: 0.1900
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.2446 - val_loss: 0.1488
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.1926 - val_loss: 0.1314
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.1953 - val_loss: 0.1311
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.2011 - val_loss: 0.1382
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.2075 - val_loss: 0.1443
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.2166 - val_loss: 0.1463
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.2182 - val_loss: 0.1408
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.2116 - val_loss: 0.1324
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.2033 - val_loss: 0.1264
# Epoch 13/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.1944 - val_loss: 0.1246
# Epoch 14/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.1747 - val_loss: 0.1248
# Epoch 15/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.1754 - val_loss: 0.1239
# Epoch 16/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.1877 - val_loss: 0.1227
# Epoch 17/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.1751 - val_loss: 0.1219
# Epoch 18/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.1879 - val_loss: 0.1213
# Epoch 19/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.1779 - val_loss: 0.1209
# Epoch 20/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.1737 - val_loss: 0.1204
# Epoch 21/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.1867 - val_loss: 0.1199
# Epoch 22/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.1859 - val_loss: 0.1189
# Epoch 23/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.1788 - val_loss: 0.1179
# Epoch 24/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.1699 - val_loss: 0.1171
# Epoch 25/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.1782 - val_loss: 0.1164
# Epoch 26/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.1773 - val_loss: 0.1157
# Epoch 27/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.1663 - val_loss: 0.1150
# Epoch 28/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.1780 - val_loss: 0.1146
# Epoch 29/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.1682 - val_loss: 0.1149
# Epoch 30/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.1786 - val_loss: 0.1161
# Epoch 31/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.1727 - val_loss: 0.1161
# Epoch 32/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.1691 - val_loss: 0.1162
# Epoch 33/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.1765 - val_loss: 0.1156
# Epoch 34/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.1783 - val_loss: 0.1135
# Epoch 35/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.1708 - val_loss: 0.1111
# Epoch 36/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.1621 - val_loss: 0.1092
# Epoch 37/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.1668 - val_loss: 0.1091
# Epoch 38/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.1579 - val_loss: 0.1102
# Epoch 39/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.1617 - val_loss: 0.1108
# Epoch 40/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.1646 - val_loss: 0.1104
# Epoch 41/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.1662 - val_loss: 0.1101
# Epoch 42/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.1590 - val_loss: 0.1085
# Epoch 43/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.1615 - val_loss: 0.1059
# Epoch 44/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.1587 - val_loss: 0.1044
# Epoch 45/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.1553 - val_loss: 0.1037
# Epoch 46/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.1559 - val_loss: 0.1034
# Epoch 47/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.1582 - val_loss: 0.1028
# Epoch 48/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.1581 - val_loss: 0.1021
# Epoch 49/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.1460 - val_loss: 0.1017
# Epoch 50/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.1545 - val_loss: 0.1011
# Epoch 51/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.1497 - val_loss: 0.1005
# Epoch 52/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.1542 - val_loss: 0.1000
# Epoch 53/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.1497 - val_loss: 0.0995
# Epoch 54/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.1508 - val_loss: 0.0995
# Epoch 55/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.1493 - val_loss: 0.1006
# Epoch 56/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.1531 - val_loss: 0.1035
# Epoch 57/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.1523 - val_loss: 0.1081
# Epoch 58/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.1506 - val_loss: 0.1137
# Epoch 59/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.1547 - val_loss: 0.1176
# Epoch 60/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.1571 - val_loss: 0.1151
# Epoch 61/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.1590 - val_loss: 0.1065
# Epoch 62/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.1337 - val_loss: 0.0977
# Epoch 63/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.1478 - val_loss: 0.0945
# Epoch 64/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.1362 - val_loss: 0.0965
# Epoch 65/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.1488 - val_loss: 0.1003
# Epoch 66/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.1484 - val_loss: 0.0993
# Epoch 67/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.1535 - val_loss: 0.0954
# Epoch 68/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.1484 - val_loss: 0.0926
# Epoch 69/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.1451 - val_loss: 0.0918
# Epoch 70/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.1425 - val_loss: 0.0928
# Epoch 71/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.1405 - val_loss: 0.0949
# Epoch 72/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.1390 - val_loss: 0.0970
# Epoch 73/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.1420 - val_loss: 0.0989
# Epoch 74/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.1449 - val_loss: 0.1005
# Epoch 75/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.1423 - val_loss: 0.0988
# Epoch 76/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.1400 - val_loss: 0.0939
# Epoch 77/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.1389 - val_loss: 0.0902
# Epoch 78/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.1336 - val_loss: 0.0884
# Epoch 79/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.1359 - val_loss: 0.0883
# Epoch 80/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.1261 - val_loss: 0.0898
# Epoch 81/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.1287 - val_loss: 0.0941
# Epoch 82/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.1443 - val_loss: 0.0971
# Epoch 83/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.1440 - val_loss: 0.0948
# Epoch 84/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.1429 - val_loss: 0.0896
# Epoch 85/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.1335 - val_loss: 0.0854
# Epoch 86/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.1311 - val_loss: 0.0870
# Epoch 87/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.1265 - val_loss: 0.0917
# Epoch 88/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.1315 - val_loss: 0.0946
# Epoch 89/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.1308 - val_loss: 0.0936
# Epoch 90/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.1274 - val_loss: 0.0888
# Epoch 91/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.1250 - val_loss: 0.0834
# Epoch 92/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.1260 - val_loss: 0.0822
# Epoch 93/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.1263 - val_loss: 0.0836
# Epoch 94/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.1287 - val_loss: 0.0848
# Epoch 95/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.1275 - val_loss: 0.0853
# Epoch 96/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.1337 - val_loss: 0.0846
# Epoch 97/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.1280 - val_loss: 0.0817
# Epoch 98/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.1265 - val_loss: 0.0795
# Epoch 99/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.1219 - val_loss: 0.0799
# Epoch 100/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.1175 - val_loss: 0.0823
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# Epoch 1/100
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 289ms/step - loss: 0.2891 - val_loss: 0.3825
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.2416 - val_loss: 0.3485
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.2124 - val_loss: 0.3305
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.2093 - val_loss: 0.3272
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.2167 - val_loss: 0.3255
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.2126 - val_loss: 0.3240
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.2121 - val_loss: 0.3225
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.2045 - val_loss: 0.3211
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.2105 - val_loss: 0.3191
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.2087 - val_loss: 0.3172
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.2084 - val_loss: 0.3157
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.2086 - val_loss: 0.3148
# Epoch 13/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.1979 - val_loss: 0.3150
# Epoch 14/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.2012 - val_loss: 0.3171
# Epoch 15/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.1966 - val_loss: 0.3165
# Epoch 16/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.1978 - val_loss: 0.3125
# Epoch 17/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.1964 - val_loss: 0.3098
# Epoch 18/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.2004 - val_loss: 0.3075
# Epoch 19/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.1929 - val_loss: 0.3040
# Epoch 20/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.1987 - val_loss: 0.3007
# Epoch 21/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.1985 - val_loss: 0.2993
# Epoch 22/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.2013 - val_loss: 0.2981
# Epoch 23/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.2027 - val_loss: 0.2969
# Epoch 24/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.2034 - val_loss: 0.2957
# Epoch 25/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.1916 - val_loss: 0.2944
# Epoch 26/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.1918 - val_loss: 0.2959
# Epoch 27/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.1935 - val_loss: 0.3033
# Epoch 28/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.1957 - val_loss: 0.3113
# Epoch 29/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.1975 - val_loss: 0.3170
# Epoch 30/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.2035 - val_loss: 0.3198
# Epoch 31/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.2051 - val_loss: 0.3146
# Epoch 32/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.1922 - val_loss: 0.3054
# Epoch 33/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.1959 - val_loss: 0.2970
# Epoch 34/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.1916 - val_loss: 0.2922
# Epoch 35/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.1879 - val_loss: 0.2881
# Epoch 36/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.1859 - val_loss: 0.2836
# Epoch 37/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.1793 - val_loss: 0.2797
# Epoch 38/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.1892 - val_loss: 0.2785
# Epoch 39/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.1829 - val_loss: 0.2793
# Epoch 40/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.1945 - val_loss: 0.2784
# Epoch 41/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.1888 - val_loss: 0.2752
# Epoch 42/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.1922 - val_loss: 0.2727
# Epoch 43/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.1857 - val_loss: 0.2727
# Epoch 44/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.1838 - val_loss: 0.2750
# Epoch 45/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.1806 - val_loss: 0.2778
# Epoch 46/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.1802 - val_loss: 0.2782
# Epoch 47/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.1798 - val_loss: 0.2755
# Epoch 48/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.1685 - val_loss: 0.2697
# Epoch 49/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.1743 - val_loss: 0.2651
# Epoch 50/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.1784 - val_loss: 0.2631
# Epoch 51/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.1702 - val_loss: 0.2619
# Epoch 52/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.1777 - val_loss: 0.2621
# Epoch 53/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.1774 - val_loss: 0.2621
# Epoch 54/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.1745 - val_loss: 0.2593
# Epoch 55/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.1740 - val_loss: 0.2571
# Epoch 56/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.1772 - val_loss: 0.2613
# Epoch 57/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.1578 - val_loss: 0.2725
# Epoch 58/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.1753 - val_loss: 0.2871
# Epoch 59/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.1820 - val_loss: 0.2931
# Epoch 60/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.1818 - val_loss: 0.2925
# Epoch 61/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.1805 - val_loss: 0.2843
# Epoch 62/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.1812 - val_loss: 0.2697
# Epoch 63/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.1764 - val_loss: 0.2589
# Epoch 64/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.1706 - val_loss: 0.2522
# Epoch 65/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.1609 - val_loss: 0.2500
# Epoch 66/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.1632 - val_loss: 0.2505
# Epoch 67/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.1598 - val_loss: 0.2487
# Epoch 68/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.1668 - val_loss: 0.2452
# Epoch 69/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.1656 - val_loss: 0.2432
# Epoch 70/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.1653 - val_loss: 0.2421
# Epoch 71/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.1588 - val_loss: 0.2420
# Epoch 72/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.1564 - val_loss: 0.2416
# Epoch 73/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.1604 - val_loss: 0.2400
# Epoch 74/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.1562 - val_loss: 0.2385
# Epoch 75/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.1630 - val_loss: 0.2366
# Epoch 76/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.1640 - val_loss: 0.2351
# Epoch 77/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.1634 - val_loss: 0.2341
# Epoch 78/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.1429 - val_loss: 0.2338
# Epoch 79/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.1602 - val_loss: 0.2344
# Epoch 80/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.1594 - val_loss: 0.2347
# Epoch 81/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.1483 - val_loss: 0.2360
# Epoch 82/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.1576 - val_loss: 0.2413
# Epoch 83/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.1556 - val_loss: 0.2486
# Epoch 84/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.1590 - val_loss: 0.2563
# Epoch 85/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.1614 - val_loss: 0.2600
# Epoch 86/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.1687 - val_loss: 0.2587
# Epoch 87/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.1603 - val_loss: 0.2513
# Epoch 88/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.1648 - val_loss: 0.2396
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# Load data
url = 'https://raw.githubusercontent.com/C4AnN/Models/main/dataset_processing%20(2)/file_gabungan2.csv'
store_sales = pd.read_csv(url)
store_sales['date'] = pd.to_datetime(store_sales['date'])

# Categorize data based on price
def categorize_price(price):
    if price < 8000000:
        return 'low'
    elif 8000000 <= price < 16000000:
        return 'mid'
    else:
        return 'high'

store_sales['category'] = store_sales['price'].apply(categorize_price)

# Drop unnecessary columns
store_sales = store_sales.drop(['name', 'price'], axis=1)

# Function to process and predict for each category
def process_category(data, category_name):
    data = data[data['category'] == category_name].drop(['category'], axis=1)
    data['date'] = data['date'].dt.to_period("M")
    monthly_sales = data.groupby('date').sum().reset_index()
    monthly_sales['date'] = monthly_sales['date'].dt.to_timestamp()

    # Calculate sales difference
    monthly_sales['sales_diff'] = monthly_sales['sales'].diff()
    monthly_sales = monthly_sales.dropna()

    # Prepare supervised data
    supervised_data = monthly_sales.drop(['date', 'sales'], axis=1)
    for i in range(1, 13):
        col_name = 'month_' + str(i)
        supervised_data[col_name] = supervised_data['sales_diff'].shift(i)
    supervised_data = supervised_data.dropna().reset_index(drop=True)

    # Split into train and test data
    train_data = supervised_data[:-12]
    test_data = supervised_data[-12:]

    # Scale the data
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler.fit(train_data)
    train_data = scaler.transform(train_data)
    test_data = scaler.transform(test_data)

    X_train, y_train = train_data[:, 1:], train_data[:, 0]
    X_test, y_test = test_data[:, 1:], test_data[:, 0]

    # Reshape input to be 3D [samples, timesteps, features]
    X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
    X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

    # Build LSTM model
    model = Sequential()
    model.add(LSTM(100, activation='softmax', input_shape=(X_train.shape[1], 1), return_sequences=True))
    model.add(LSTM(50, activation='softmax'))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mse')

    # Train the model
    early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
    history = model.fit(X_train, y_train, epochs=200, validation_data=(X_test, y_test), callbacks=[early_stop], verbose=1)

    # Make predictions
    lstm_pre = model.predict(X_test)

    # Prepare prediction DataFrame
    sales_dates = monthly_sales['date'][-12:].reset_index(drop=True)
    predict_df = pd.DataFrame(sales_dates, columns=['date'])

    act_sales = monthly_sales['sales'][-13:].to_list()
    lstm_pre = lstm_pre.reshape(-1, 1)
    lstm_pre_test_set = np.concatenate([lstm_pre, X_test.reshape((X_test.shape[0], X_test.shape[1]))], axis=1)
    lstm_pre_test_set = scaler.inverse_transform(lstm_pre_test_set)

    result_list = []
    for index in range(0, len(lstm_pre_test_set)):
        result_list.append(lstm_pre_test_set[index][0] + act_sales[index])
    lstm_pre_series = pd.Series(result_list, name="LSTM Prediction")
    predict_df = predict_df.merge(lstm_pre_series, left_index=True, right_index=True)

    return monthly_sales, predict_df

# Process and predict for each category
low_sales, low_predict_df = process_category(store_sales, 'low')
mid_sales, mid_predict_df = process_category(store_sales, 'mid')
high_sales, high_predict_df = process_category(store_sales, 'high')

# Plot predictions by category
plt.figure(figsize=(15, 15))

# Low category plot
plt.subplot(3, 1, 1)
plt.plot(low_sales['date'], low_sales['sales'], label='Actual Sales')
plt.plot(low_predict_df['date'], low_predict_df['LSTM Prediction'], label='Predicted Sales (Low)')
plt.title("Customer Sales Forecast - Low Category")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.legend()

# Mid category plot
plt.subplot(3, 1, 2)
plt.plot(mid_sales['date'], mid_sales['sales'], label='Actual Sales')
plt.plot(mid_predict_df['date'], mid_predict_df['LSTM Prediction'], label='Predicted Sales (Mid)')
plt.title("Customer Sales Forecast - Mid Category")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.legend()

# High category plot
plt.subplot(3, 1, 3)
plt.plot(high_sales['date'], high_sales['sales'], label='Actual Sales')
plt.plot(high_predict_df['date'], high_predict_df['LSTM Prediction'], label='Predicted Sales (High)')
plt.title("Customer Sales Forecast - High Category")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/200
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 5s 496ms/step - loss: 0.2574 - val_loss: 0.6291
# Epoch 2/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.2595 - val_loss: 0.6291
# Epoch 3/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.2562 - val_loss: 0.6291
# Epoch 4/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.2463 - val_loss: 0.6291
# Epoch 5/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.2515 - val_loss: 0.6290
# Epoch 6/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.2402 - val_loss: 0.6289
# Epoch 7/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.2580 - val_loss: 0.6289
# Epoch 8/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.2555 - val_loss: 0.6288
# Epoch 9/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.2541 - val_loss: 0.6287
# Epoch 10/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.2522 - val_loss: 0.6287
# Epoch 11/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.2430 - val_loss: 0.6286
# Epoch 12/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.2494 - val_loss: 0.6286
# Epoch 13/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.2399 - val_loss: 0.6285
# Epoch 14/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.2517 - val_loss: 0.6284
# Epoch 15/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.2381 - val_loss: 0.6284
# Epoch 16/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.2552 - val_loss: 0.6284
# Epoch 17/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.2567 - val_loss: 0.6283
# Epoch 18/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.2389 - val_loss: 0.6283
# Epoch 19/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.2488 - val_loss: 0.6283
# Epoch 20/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.2406 - val_loss: 0.6283
# Epoch 21/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.2526 - val_loss: 0.6282
# Epoch 22/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.2559 - val_loss: 0.6282
# Epoch 23/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.2533 - val_loss: 0.6282
# Epoch 24/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.2535 - val_loss: 0.6282
# Epoch 25/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.2527 - val_loss: 0.6282
# Epoch 26/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.2473 - val_loss: 0.6282
# Epoch 27/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.2394 - val_loss: 0.6282
# Epoch 28/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.2462 - val_loss: 0.6282
# Epoch 29/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.2540 - val_loss: 0.6283
# Epoch 30/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.2484 - val_loss: 0.6283
# Epoch 31/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.2550 - val_loss: 0.6283
# Epoch 32/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.2479 - val_loss: 0.6283
# Epoch 33/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.2446 - val_loss: 0.6283
# Epoch 34/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.2484 - val_loss: 0.6283
# Epoch 35/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.2447 - val_loss: 0.6284
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 403ms/step
# Epoch 1/200
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 446ms/step - loss: 0.2121 - val_loss: 0.1489
# Epoch 2/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.2220 - val_loss: 0.1482
# Epoch 3/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.2133 - val_loss: 0.1477
# Epoch 4/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.2156 - val_loss: 0.1473
# Epoch 5/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.2201 - val_loss: 0.1467
# Epoch 6/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.2170 - val_loss: 0.1461
# Epoch 7/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.2177 - val_loss: 0.1455
# Epoch 8/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.2090 - val_loss: 0.1449
# Epoch 9/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.2167 - val_loss: 0.1442
# Epoch 10/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.2169 - val_loss: 0.1436
# Epoch 11/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.2122 - val_loss: 0.1430
# Epoch 12/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.2093 - val_loss: 0.1425
# Epoch 13/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.2163 - val_loss: 0.1420
# Epoch 14/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.2065 - val_loss: 0.1415
# Epoch 15/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.2082 - val_loss: 0.1410
# Epoch 16/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.2010 - val_loss: 0.1405
# Epoch 17/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.2021 - val_loss: 0.1400
# Epoch 18/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.2131 - val_loss: 0.1396
# Epoch 19/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.2071 - val_loss: 0.1392
# Epoch 20/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.1953 - val_loss: 0.1388
# Epoch 21/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.2037 - val_loss: 0.1384
# Epoch 22/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.2067 - val_loss: 0.1381
# Epoch 23/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.2029 - val_loss: 0.1376
# Epoch 24/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.2063 - val_loss: 0.1372
# Epoch 25/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.2091 - val_loss: 0.1368
# Epoch 26/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.2036 - val_loss: 0.1364
# Epoch 27/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.1893 - val_loss: 0.1360
# Epoch 28/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.2028 - val_loss: 0.1357
# Epoch 29/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.1903 - val_loss: 0.1355
# Epoch 30/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.2050 - val_loss: 0.1354
# Epoch 31/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.2029 - val_loss: 0.1352
# Epoch 32/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.2000 - val_loss: 0.1350
# Epoch 33/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.2001 - val_loss: 0.1347
# Epoch 34/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.1966 - val_loss: 0.1344
# Epoch 35/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.2009 - val_loss: 0.1341
# Epoch 36/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.2064 - val_loss: 0.1338
# Epoch 37/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.2034 - val_loss: 0.1336
# Epoch 38/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.2063 - val_loss: 0.1333
# Epoch 39/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.1997 - val_loss: 0.1331
# Epoch 40/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.2040 - val_loss: 0.1328
# Epoch 41/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.1935 - val_loss: 0.1325
# Epoch 42/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.2047 - val_loss: 0.1323
# Epoch 43/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.2049 - val_loss: 0.1320
# Epoch 44/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.1966 - val_loss: 0.1318
# Epoch 45/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.2000 - val_loss: 0.1316
# Epoch 46/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.2024 - val_loss: 0.1315
# Epoch 47/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.1947 - val_loss: 0.1314
# Epoch 48/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.2020 - val_loss: 0.1312
# Epoch 49/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.1976 - val_loss: 0.1311
# Epoch 50/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.1980 - val_loss: 0.1310
# Epoch 51/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.2005 - val_loss: 0.1309
# Epoch 52/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.2026 - val_loss: 0.1308
# Epoch 53/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.2014 - val_loss: 0.1308
# Epoch 54/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.1984 - val_loss: 0.1307
# Epoch 55/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.1988 - val_loss: 0.1305
# Epoch 56/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.1988 - val_loss: 0.1304
# Epoch 57/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.1868 - val_loss: 0.1304
# Epoch 58/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.1992 - val_loss: 0.1303
# Epoch 59/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.1878 - val_loss: 0.1302
# Epoch 60/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.1988 - val_loss: 0.1302
# Epoch 61/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.1987 - val_loss: 0.1301
# Epoch 62/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.2014 - val_loss: 0.1300
# Epoch 63/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.1935 - val_loss: 0.1298
# Epoch 64/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.1983 - val_loss: 0.1297
# Epoch 65/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.1873 - val_loss: 0.1296
# Epoch 66/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.2003 - val_loss: 0.1295
# Epoch 67/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.1975 - val_loss: 0.1294
# Epoch 68/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.1876 - val_loss: 0.1293
# Epoch 69/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.1948 - val_loss: 0.1293
# Epoch 70/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.1793 - val_loss: 0.1292
# Epoch 71/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.1981 - val_loss: 0.1292
# Epoch 72/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.1971 - val_loss: 0.1291
# Epoch 73/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.1840 - val_loss: 0.1291
# Epoch 74/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.1955 - val_loss: 0.1290
# Epoch 75/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.1984 - val_loss: 0.1290
# Epoch 76/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.1975 - val_loss: 0.1289
# Epoch 77/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.1874 - val_loss: 0.1288
# Epoch 78/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.1981 - val_loss: 0.1287
# Epoch 79/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.1841 - val_loss: 0.1286
# Epoch 80/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.1977 - val_loss: 0.1286
# Epoch 81/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.1991 - val_loss: 0.1286
# Epoch 82/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.1981 - val_loss: 0.1285
# Epoch 83/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.1950 - val_loss: 0.1285
# Epoch 84/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.1973 - val_loss: 0.1285
# Epoch 85/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.1939 - val_loss: 0.1285
# Epoch 86/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.1890 - val_loss: 0.1285
# Epoch 87/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.1954 - val_loss: 0.1285
# Epoch 88/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.1920 - val_loss: 0.1286
# Epoch 89/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.1915 - val_loss: 0.1286
# Epoch 90/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 0.1910 - val_loss: 0.1286
# Epoch 91/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.1936 - val_loss: 0.1286
# Epoch 92/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.1982 - val_loss: 0.1286
# Epoch 93/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.1952 - val_loss: 0.1286
# Epoch 94/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.1948 - val_loss: 0.1286
# Epoch 95/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.1813 - val_loss: 0.1286
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 393ms/step
# Epoch 1/200
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 490ms/step - loss: 0.2535 - val_loss: 0.3988
# Epoch 2/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.2502 - val_loss: 0.3981
# Epoch 3/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.2480 - val_loss: 0.3976
# Epoch 4/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.2299 - val_loss: 0.3967
# Epoch 5/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.2441 - val_loss: 0.3958
# Epoch 6/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.2506 - val_loss: 0.3948
# Epoch 7/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.2470 - val_loss: 0.3940
# Epoch 8/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.2381 - val_loss: 0.3933
# Epoch 9/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.2431 - val_loss: 0.3924
# Epoch 10/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.2448 - val_loss: 0.3915
# Epoch 11/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.2485 - val_loss: 0.3906
# Epoch 12/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.2442 - val_loss: 0.3898
# Epoch 13/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.2417 - val_loss: 0.3890
# Epoch 14/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.2260 - val_loss: 0.3882
# Epoch 15/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.2335 - val_loss: 0.3874
# Epoch 16/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.2395 - val_loss: 0.3867
# Epoch 17/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.2424 - val_loss: 0.3860
# Epoch 18/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.2414 - val_loss: 0.3854
# Epoch 19/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.2435 - val_loss: 0.3849
# Epoch 20/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.2347 - val_loss: 0.3844
# Epoch 21/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.2424 - val_loss: 0.3838
# Epoch 22/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.2364 - val_loss: 0.3832
# Epoch 23/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.2373 - val_loss: 0.3826
# Epoch 24/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.2274 - val_loss: 0.3819
# Epoch 25/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.2325 - val_loss: 0.3815
# Epoch 26/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.2280 - val_loss: 0.3810
# Epoch 27/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.2256 - val_loss: 0.3803
# Epoch 28/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.2368 - val_loss: 0.3796
# Epoch 29/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.2350 - val_loss: 0.3789
# Epoch 30/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.2212 - val_loss: 0.3782
# Epoch 31/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.2348 - val_loss: 0.3774
# Epoch 32/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.2370 - val_loss: 0.3766
# Epoch 33/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.2271 - val_loss: 0.3759
# Epoch 34/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.2332 - val_loss: 0.3751
# Epoch 35/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.2259 - val_loss: 0.3745
# Epoch 36/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.2293 - val_loss: 0.3739
# Epoch 37/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.2353 - val_loss: 0.3734
# Epoch 38/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.2282 - val_loss: 0.3730
# Epoch 39/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.2299 - val_loss: 0.3727
# Epoch 40/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.2325 - val_loss: 0.3724
# Epoch 41/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.2258 - val_loss: 0.3720
# Epoch 42/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.2315 - val_loss: 0.3718
# Epoch 43/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.2295 - val_loss: 0.3715
# Epoch 44/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.2163 - val_loss: 0.3712
# Epoch 45/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.2341 - val_loss: 0.3710
# Epoch 46/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.2299 - val_loss: 0.3707
# Epoch 47/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.2338 - val_loss: 0.3705
# Epoch 48/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.2316 - val_loss: 0.3703
# Epoch 49/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.2258 - val_loss: 0.3700
# Epoch 50/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.2260 - val_loss: 0.3697
# Epoch 51/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.2250 - val_loss: 0.3694
# Epoch 52/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.2283 - val_loss: 0.3691
# Epoch 53/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.2226 - val_loss: 0.3688
# Epoch 54/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.2273 - val_loss: 0.3684
# Epoch 55/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.2144 - val_loss: 0.3679
# Epoch 56/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.2279 - val_loss: 0.3675
# Epoch 57/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.2314 - val_loss: 0.3671
# Epoch 58/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.2299 - val_loss: 0.3667
# Epoch 59/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.2327 - val_loss: 0.3664
# Epoch 60/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.2294 - val_loss: 0.3662
# Epoch 61/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.2190 - val_loss: 0.3659
# Epoch 62/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.2269 - val_loss: 0.3658
# Epoch 63/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.2107 - val_loss: 0.3657
# Epoch 64/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.2301 - val_loss: 0.3655
# Epoch 65/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.2320 - val_loss: 0.3653
# Epoch 66/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.2186 - val_loss: 0.3651
# Epoch 67/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.2181 - val_loss: 0.3649
# Epoch 68/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.2296 - val_loss: 0.3648
# Epoch 69/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.2166 - val_loss: 0.3646
# Epoch 70/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.2281 - val_loss: 0.3645
# Epoch 71/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.2264 - val_loss: 0.3643
# Epoch 72/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.2231 - val_loss: 0.3642
# Epoch 73/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.2272 - val_loss: 0.3639
# Epoch 74/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.2302 - val_loss: 0.3637
# Epoch 75/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.2258 - val_loss: 0.3635
# Epoch 76/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.2301 - val_loss: 0.3633
# Epoch 77/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.2237 - val_loss: 0.3632
# Epoch 78/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.2151 - val_loss: 0.3631
# Epoch 79/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.2291 - val_loss: 0.3630
# Epoch 80/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.2217 - val_loss: 0.3629
# Epoch 81/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.2290 - val_loss: 0.3628
# Epoch 82/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.2180 - val_loss: 0.3628
# Epoch 83/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.2300 - val_loss: 0.3628
# Epoch 84/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.2250 - val_loss: 0.3628
# Epoch 85/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.2230 - val_loss: 0.3628
# Epoch 86/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.2199 - val_loss: 0.3626
# Epoch 87/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.2209 - val_loss: 0.3625
# Epoch 88/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.2102 - val_loss: 0.3624
# Epoch 89/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.2222 - val_loss: 0.3622
# Epoch 90/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.2256 - val_loss: 0.3621
# Epoch 91/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.2153 - val_loss: 0.3621
# Epoch 92/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.2278 - val_loss: 0.3621
# Epoch 93/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.2281 - val_loss: 0.3620
# Epoch 94/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.2260 - val_loss: 0.3620
# Epoch 95/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.2272 - val_loss: 0.3619
# Epoch 96/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.2179 - val_loss: 0.3618
# Epoch 97/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.2295 - val_loss: 0.3618
# Epoch 98/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.2260 - val_loss: 0.3618
# Epoch 99/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.2281 - val_loss: 0.3618
# Epoch 100/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.2207 - val_loss: 0.3618
# Epoch 101/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.2290 - val_loss: 0.3618
# Epoch 102/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.2184 - val_loss: 0.3618
# Epoch 103/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.2234 - val_loss: 0.3618
# Epoch 104/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.2229 - val_loss: 0.3618
# Epoch 105/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.2194 - val_loss: 0.3617
# Epoch 106/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.2197 - val_loss: 0.3617
# Epoch 107/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.2205 - val_loss: 0.3617
# Epoch 108/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.2128 - val_loss: 0.3617
# Epoch 109/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.2266 - val_loss: 0.3616
# Epoch 110/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.2164 - val_loss: 0.3616
# Epoch 111/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.2245 - val_loss: 0.3617
# Epoch 112/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.2294 - val_loss: 0.3617
# Epoch 113/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.2304 - val_loss: 0.3617
# Epoch 114/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.2269 - val_loss: 0.3617
# Epoch 115/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.2141 - val_loss: 0.3617
# Epoch 116/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.2307 - val_loss: 0.3617
# Epoch 117/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.2157 - val_loss: 0.3616
# Epoch 118/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.2097 - val_loss: 0.3616
# Epoch 119/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.2203 - val_loss: 0.3615
# Epoch 120/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.2122 - val_loss: 0.3614
# Epoch 121/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.2290 - val_loss: 0.3613
# Epoch 122/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.2216 - val_loss: 0.3612
# Epoch 123/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.2094 - val_loss: 0.3611
# Epoch 124/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.2300 - val_loss: 0.3610
# Epoch 125/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.2261 - val_loss: 0.3609
# Epoch 126/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.2205 - val_loss: 0.3608
# Epoch 127/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.2275 - val_loss: 0.3607
# Epoch 128/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.2278 - val_loss: 0.3606
# Epoch 129/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.2253 - val_loss: 0.3606
# Epoch 130/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 0.2259 - val_loss: 0.3605
# Epoch 131/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.2161 - val_loss: 0.3605
# Epoch 132/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.2295 - val_loss: 0.3606
# Epoch 133/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.2091 - val_loss: 0.3607
# Epoch 134/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.2285 - val_loss: 0.3607
# Epoch 135/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.2184 - val_loss: 0.3607
# Epoch 136/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - loss: 0.2284 - val_loss: 0.3608
# Epoch 137/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.2269 - val_loss: 0.3608
# Epoch 138/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.1994 - val_loss: 0.3608
# Epoch 139/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.2235 - val_loss: 0.3609
# Epoch 140/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.2292 - val_loss: 0.3610
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Input
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# Load data
url = 'https://raw.githubusercontent.com/C4AnN/Models/main/dataset_processing%20(2)/file_gabungan2.csv'
store_sales = pd.read_csv(url)
store_sales['date'] = pd.to_datetime(store_sales['date'])

# Categorize data based on price
def categorize_price(price):
    if price < 8000000:
        return 'low'
    elif 8000000 <= price < 16000000:
        return 'mid'
    else:
        return 'high'

store_sales['category'] = store_sales['price'].apply(categorize_price)

# Drop unnecessary columns
store_sales = store_sales.drop(['name', 'price'], axis=1)

# Function to process and predict for each category
def process_category(data, category_name):
    data = data[data['category'] == category_name].drop(['category'], axis=1)
    data['date'] = data['date'].dt.to_period("M")
    monthly_sales = data.groupby('date').sum().reset_index()
    monthly_sales['date'] = monthly_sales['date'].dt.to_timestamp()

    # Calculate sales difference
    monthly_sales['sales_diff'] = monthly_sales['sales'].diff()
    monthly_sales = monthly_sales.dropna()

    # Prepare supervised data
    supervised_data = monthly_sales.drop(['date', 'sales'], axis=1)
    for i in range(1, 13):
        col_name = 'month_' + str(i)
        supervised_data[col_name] = supervised_data['sales_diff'].shift(i)
    supervised_data = supervised_data.dropna().reset_index(drop=True)

    # Split into train and test data
    train_data = supervised_data[:-12]
    test_data = supervised_data[-12:]

    # Scale the data
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler.fit(train_data)
    train_data = scaler.transform(train_data)
    test_data = scaler.transform(test_data)

    X_train, y_train = train_data[:, 1:], train_data[:, 0]
    X_test, y_test = test_data[:, 1:], test_data[:, 0]

    # Reshape input to be 3D [samples, timesteps, features]
    X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
    X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

    # Build LSTM model
    model = Sequential()
    model.add(Input(shape=(X_train.shape[1], 1)))
    model.add(LSTM(50, activation='tanh'))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mse')

    # Setup callbacks
    early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
    model_checkpoint = ModelCheckpoint('best_model.keras', monitor='val_loss', save_best_only=True)

    # Train the model
    history = model.fit(X_train, y_train, epochs=100, validation_data=(X_test, y_test), callbacks=[early_stop, model_checkpoint], verbose=1)

    # Make predictions
    lstm_pre = model.predict(X_test)

    # Prepare prediction DataFrame
    sales_dates = monthly_sales['date'][-12:].reset_index(drop=True)
    predict_df = pd.DataFrame(sales_dates, columns=['date'])

    act_sales = monthly_sales['sales'][-13:].to_list()
    lstm_pre = lstm_pre.reshape(-1, 1)
    lstm_pre_test_set = np.concatenate([lstm_pre, X_test.reshape((X_test.shape[0], X_test.shape[1]))], axis=1)
    lstm_pre_test_set = scaler.inverse_transform(lstm_pre_test_set)

    result_list = []
    for index in range(0, len(lstm_pre_test_set)):
        result_list.append(lstm_pre_test_set[index][0] + act_sales[index + 1])
    lstm_pre_series = pd.Series(result_list, name="LSTM Prediction")
    predict_df = predict_df.merge(lstm_pre_series, left_index=True, right_index=True)

    # Predict next 12 months
    future_predictions = []
    last_data = supervised_data[-1:].to_numpy()
    for _ in range(12):
        last_data_scaled = scaler.transform(last_data)
        X_last = last_data_scaled[:, 1:].reshape((1, X_train.shape[1], 1))
        next_pred = model.predict(X_last)[0, 0]
        future_pred = np.concatenate([[next_pred], last_data_scaled[0, 1:]])
        future_pred = scaler.inverse_transform([future_pred])
        future_predictions.append(future_pred[0][0] + act_sales[-1])
        last_data = np.concatenate([last_data, np.array([[next_pred] + last_data[0, 1:].tolist()])], axis=0)
        act_sales.append(future_predictions[-1])
        last_data = last_data[-1:]  # Only keep the latest data for the next prediction

    future_dates = pd.date_range(start=monthly_sales['date'].iloc[-1] + pd.DateOffset(months=1), periods=12, freq='M')
    future_df = pd.DataFrame({'date': future_dates, 'LSTM Prediction': future_predictions})

    return monthly_sales, predict_df, future_df

# Process and predict for each category
low_sales, low_predict_df, low_future_df = process_category(store_sales, 'low')
mid_sales, mid_predict_df, mid_future_df = process_category(store_sales, 'mid')
high_sales, high_predict_df, high_future_df = process_category(store_sales, 'high')

# Plot predictions by category
plt.figure(figsize=(15, 15))

# Low category plot
plt.subplot(3, 1, 1)
plt.plot(low_sales['date'], low_sales['sales'], label='Actual Sales')
plt.plot(low_predict_df['date'], low_predict_df['LSTM Prediction'], label='Predicted Sales (Low)')
plt.plot(low_future_df['date'], low_future_df['LSTM Prediction'], label='Future Prediction (Low)', linestyle='--')
plt.title("Customer Sales Forecast - Low Category")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.legend()

# Mid category plot
plt.subplot(3, 1, 2)
plt.plot(mid_sales['date'], mid_sales['sales'], label='Actual Sales')
plt.plot(mid_predict_df['date'], mid_predict_df['LSTM Prediction'], label='Predicted Sales (Mid)')
plt.plot(mid_future_df['date'], mid_future_df['LSTM Prediction'], label='Future Prediction (Mid)', linestyle='--')
plt.title("Customer Sales Forecast - Mid Category")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.legend()

# High category plot
plt.subplot(3, 1, 3)
plt.plot(high_sales['date'], high_sales['sales'], label='Actual Sales')
plt.plot(high_predict_df['date'], high_predict_df['LSTM Prediction'], label='Predicted Sales (High)')
plt.plot(high_future_df['date'], high_future_df['LSTM Prediction'], label='Future Prediction (High)', linestyle='--')
plt.title("Customer Sales Forecast - High Category")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 621ms/step - loss: 0.2401 - val_loss: 0.6196
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.2448 - val_loss: 0.6199
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.2491 - val_loss: 0.6201
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.2364 - val_loss: 0.6199
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.2327 - val_loss: 0.6209
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.2349 - val_loss: 0.6207
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.2388 - val_loss: 0.6170
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.2262 - val_loss: 0.6130
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 0.2277 - val_loss: 0.6096
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.2320 - val_loss: 0.6066
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.2302 - val_loss: 0.6042
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.2309 - val_loss: 0.6022
# Epoch 13/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.2289 - val_loss: 0.5990
# Epoch 14/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.2225 - val_loss: 0.5950
# Epoch 15/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.2121 - val_loss: 0.5903
# Epoch 16/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.2246 - val_loss: 0.5836
# Epoch 17/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.2167 - val_loss: 0.5777
# Epoch 18/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.2161 - val_loss: 0.5731
# Epoch 19/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.2129 - val_loss: 0.5698
# Epoch 20/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 0.2156 - val_loss: 0.5672
# Epoch 21/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.2103 - val_loss: 0.5640
# Epoch 22/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.2109 - val_loss: 0.5609
# Epoch 23/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.2041 - val_loss: 0.5594
# Epoch 24/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.2032 - val_loss: 0.5563
# Epoch 25/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.2037 - val_loss: 0.5474
# Epoch 26/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.2048 - val_loss: 0.5360
# Epoch 27/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 0.2011 - val_loss: 0.5265
# Epoch 28/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - loss: 0.1958 - val_loss: 0.5195
# Epoch 29/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.1955 - val_loss: 0.5131
# Epoch 30/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.1900 - val_loss: 0.5087
# Epoch 31/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.1943 - val_loss: 0.5062
# Epoch 32/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.1961 - val_loss: 0.5045
# Epoch 33/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.2042 - val_loss: 0.5033
# Epoch 34/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.2018 - val_loss: 0.5011
# Epoch 35/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.2018 - val_loss: 0.4978
# Epoch 36/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.1963 - val_loss: 0.4947
# Epoch 37/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.2004 - val_loss: 0.4927
# Epoch 38/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.1972 - val_loss: 0.4908
# Epoch 39/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.1882 - val_loss: 0.4894
# Epoch 40/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.1915 - val_loss: 0.4899
# Epoch 41/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.1917 - val_loss: 0.4926
# Epoch 42/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.1779 - val_loss: 0.4931
# Epoch 43/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.1799 - val_loss: 0.4908
# Epoch 44/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.1814 - val_loss: 0.4894
# Epoch 45/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.1822 - val_loss: 0.4894
# Epoch 46/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.1789 - val_loss: 0.4874
# Epoch 47/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.1726 - val_loss: 0.4809
# Epoch 48/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.1822 - val_loss: 0.4737
# Epoch 49/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.1794 - val_loss: 0.4683
# Epoch 50/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.1809 - val_loss: 0.4635
# Epoch 51/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.1803 - val_loss: 0.4594
# Epoch 52/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.1781 - val_loss: 0.4558
# Epoch 53/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.1786 - val_loss: 0.4528
# Epoch 54/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 0.1774 - val_loss: 0.4502
# Epoch 55/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.1750 - val_loss: 0.4477
# Epoch 56/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.1757 - val_loss: 0.4459
# Epoch 57/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.1730 - val_loss: 0.4451
# Epoch 58/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.1637 - val_loss: 0.4439
# Epoch 59/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 0.1707 - val_loss: 0.4430
# Epoch 60/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.1649 - val_loss: 0.4394
# Epoch 61/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - loss: 0.1733 - val_loss: 0.4326
# Epoch 62/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 0.1675 - val_loss: 0.4255
# Epoch 63/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.1682 - val_loss: 0.4179
# Epoch 64/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.1676 - val_loss: 0.4125
# Epoch 65/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.1585 - val_loss: 0.4092
# Epoch 66/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.1635 - val_loss: 0.4079
# Epoch 67/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.1602 - val_loss: 0.4066
# Epoch 68/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 0.1638 - val_loss: 0.4041
# Epoch 69/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.1642 - val_loss: 0.4023
# Epoch 70/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.1607 - val_loss: 0.4011
# Epoch 71/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 0.1680 - val_loss: 0.4002
# Epoch 72/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.1675 - val_loss: 0.3989
# Epoch 73/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.1647 - val_loss: 0.3966
# Epoch 74/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.1602 - val_loss: 0.3929
# Epoch 75/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.1637 - val_loss: 0.3887
# Epoch 76/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.1603 - val_loss: 0.3848
# Epoch 77/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - loss: 0.1609 - val_loss: 0.3828
# Epoch 78/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.1645 - val_loss: 0.3829
# Epoch 79/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.1619 - val_loss: 0.3820
# Epoch 80/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.1617 - val_loss: 0.3815
# Epoch 81/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.1638 - val_loss: 0.3835
# Epoch 82/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.1623 - val_loss: 0.3867
# Epoch 83/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.1588 - val_loss: 0.3894
# Epoch 84/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - loss: 0.1573 - val_loss: 0.3872
# Epoch 85/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.1574 - val_loss: 0.3809
# Epoch 86/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.1549 - val_loss: 0.3755
# Epoch 87/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.1586 - val_loss: 0.3694
# Epoch 88/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.1603 - val_loss: 0.3640
# Epoch 89/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.1612 - val_loss: 0.3604
# Epoch 90/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.1587 - val_loss: 0.3580
# Epoch 91/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.1571 - val_loss: 0.3555
# Epoch 92/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.1589 - val_loss: 0.3533
# Epoch 93/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 0.1518 - val_loss: 0.3519
# Epoch 94/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.1522 - val_loss: 0.3506
# Epoch 95/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.1574 - val_loss: 0.3516
# Epoch 96/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.1595 - val_loss: 0.3529
# Epoch 97/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.1537 - val_loss: 0.3469
# Epoch 98/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.1502 - val_loss: 0.3380
# Epoch 99/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.1509 - val_loss: 0.3310
# Epoch 100/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.1516 - val_loss: 0.3278
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# C:\Users\MyPC\AppData\Local\Temp\ipykernel_2208\2162656443.py:111: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   future_dates = pd.date_range(start=monthly_sales['date'].iloc[-1] + pd.DateOffset(months=1), periods=12, freq='M')
# Epoch 1/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 368ms/step - loss: 0.2548 - val_loss: 0.1642
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.2278 - val_loss: 0.1556
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.2321 - val_loss: 0.1492
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.2256 - val_loss: 0.1441
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.2196 - val_loss: 0.1397
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.2022 - val_loss: 0.1361
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.2087 - val_loss: 0.1332
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.2012 - val_loss: 0.1305
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1995 - val_loss: 0.1279
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.1940 - val_loss: 0.1257
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.1851 - val_loss: 0.1240
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.1882 - val_loss: 0.1224
# Epoch 13/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.1850 - val_loss: 0.1209
# Epoch 14/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.1746 - val_loss: 0.1202
# Epoch 15/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.1689 - val_loss: 0.1180
# Epoch 16/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.1735 - val_loss: 0.1139
# Epoch 17/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.1608 - val_loss: 0.1092
# Epoch 18/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.1630 - val_loss: 0.1047
# Epoch 19/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.1569 - val_loss: 0.1008
# Epoch 20/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.1511 - val_loss: 0.0970
# Epoch 21/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1492 - val_loss: 0.0936
# Epoch 22/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.1424 - val_loss: 0.0901
# Epoch 23/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.1371 - val_loss: 0.0865
# Epoch 24/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.1374 - val_loss: 0.0832
# Epoch 25/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.1339 - val_loss: 0.0803
# Epoch 26/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.1288 - val_loss: 0.0775
# Epoch 27/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.1246 - val_loss: 0.0751
# Epoch 28/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.1233 - val_loss: 0.0752
# Epoch 29/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.1212 - val_loss: 0.0791
# Epoch 30/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.1167 - val_loss: 0.0829
# Epoch 31/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.1171 - val_loss: 0.0825
# Epoch 32/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.1160 - val_loss: 0.0799
# Epoch 33/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.1084 - val_loss: 0.0697
# Epoch 34/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.1056 - val_loss: 0.0607
# Epoch 35/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0901 - val_loss: 0.0547
# Epoch 36/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0991 - val_loss: 0.0515
# Epoch 37/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - loss: 0.1001 - val_loss: 0.0491
# Epoch 38/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0969 - val_loss: 0.0462
# Epoch 39/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0968 - val_loss: 0.0434
# Epoch 40/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 0.0876 - val_loss: 0.0416
# Epoch 41/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0911 - val_loss: 0.0410
# Epoch 42/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0903 - val_loss: 0.0400
# Epoch 43/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.0836 - val_loss: 0.0396
# Epoch 44/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0840 - val_loss: 0.0434
# Epoch 45/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0802 - val_loss: 0.0527
# Epoch 46/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0836 - val_loss: 0.0710
# Epoch 47/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0938 - val_loss: 0.0917
# Epoch 48/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.1083 - val_loss: 0.0987
# Epoch 49/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.1126 - val_loss: 0.0908
# Epoch 50/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0929 - val_loss: 0.0648
# Epoch 51/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0891 - val_loss: 0.0484
# Epoch 52/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0812 - val_loss: 0.0474
# Epoch 53/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0843 - val_loss: 0.0506
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# C:\Users\MyPC\AppData\Local\Temp\ipykernel_2208\2162656443.py:111: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   future_dates = pd.date_range(start=monthly_sales['date'].iloc[-1] + pd.DateOffset(months=1), periods=12, freq='M')
# Epoch 1/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 400ms/step - loss: 0.2258 - val_loss: 0.3622
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.2172 - val_loss: 0.3531
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.2127 - val_loss: 0.3445
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.2150 - val_loss: 0.3370
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.2063 - val_loss: 0.3300
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.1884 - val_loss: 0.3244
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.1951 - val_loss: 0.3203
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.1884 - val_loss: 0.3168
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.1904 - val_loss: 0.3130
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.1849 - val_loss: 0.3090
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1783 - val_loss: 0.3048
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.1766 - val_loss: 0.2999
# Epoch 13/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.1754 - val_loss: 0.2947
# Epoch 14/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.1699 - val_loss: 0.2897
# Epoch 15/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.1752 - val_loss: 0.2852
# Epoch 16/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.1693 - val_loss: 0.2810
# Epoch 17/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.1658 - val_loss: 0.2766
# Epoch 18/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.1572 - val_loss: 0.2728
# Epoch 19/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.1589 - val_loss: 0.2694
# Epoch 20/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.1577 - val_loss: 0.2659
# Epoch 21/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.1487 - val_loss: 0.2626
# Epoch 22/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.1415 - val_loss: 0.2598
# Epoch 23/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.1434 - val_loss: 0.2581
# Epoch 24/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.1430 - val_loss: 0.2577
# Epoch 25/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.1426 - val_loss: 0.2580
# Epoch 26/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.1397 - val_loss: 0.2583
# Epoch 27/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.1310 - val_loss: 0.2584
# Epoch 28/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.1384 - val_loss: 0.2588
# Epoch 29/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.1362 - val_loss: 0.2587
# Epoch 30/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.1305 - val_loss: 0.2587
# Epoch 31/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.1337 - val_loss: 0.2593
# Epoch 32/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.1328 - val_loss: 0.2599
# Epoch 33/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.1318 - val_loss: 0.2601
# Epoch 34/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.1250 - val_loss: 0.2592
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# C:\Users\MyPC\AppData\Local\Temp\ipykernel_2208\2162656443.py:111: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   future_dates = pd.date_range(start=monthly_sales['date'].iloc[-1] + pd.DateOffset(months=1), periods=12, freq='M')

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Input
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# Load data
url = 'https://raw.githubusercontent.com/C4AnN/Models/main/dataset_processing%20(2)/file_gabungan2.csv'
store_sales = pd.read_csv(url)
store_sales['date'] = pd.to_datetime(store_sales['date'])

# Categorize data based on price
def categorize_price(price):
    if price < 8000000:
        return 'low'
    elif 8000000 <= price < 16000000:
        return 'mid'
    else:
        return 'high'

store_sales['category'] = store_sales['price'].apply(categorize_price)

# Drop unnecessary columns
store_sales = store_sales.drop(['name', 'price'], axis=1)

# Function to process and predict for each category
def process_category(data, category_name):
    data = data[data['category'] == category_name].drop(['category'], axis=1)
    data['date'] = data['date'].dt.to_period("M")
    monthly_sales = data.groupby('date').sum().reset_index()
    monthly_sales['date'] = monthly_sales['date'].dt.to_timestamp()

    # Calculate sales difference
    monthly_sales['sales_diff'] = monthly_sales['sales'].diff()
    monthly_sales = monthly_sales.dropna()

    # Prepare supervised data
    supervised_data = monthly_sales.drop(['date', 'sales'], axis=1)
    for i in range(1, 13):
        col_name = 'month_' + str(i)
        supervised_data[col_name] = supervised_data['sales_diff'].shift(i)
    supervised_data = supervised_data.dropna().reset_index(drop=True)

    # Split into train and test data
    train_data = supervised_data[:-12]
    test_data = supervised_data[-12:]

    # Scale the data
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler.fit(train_data)
    train_data = scaler.transform(train_data)
    test_data = scaler.transform(test_data)

    X_train, y_train = train_data[:, 1:], train_data[:, 0]
    X_test, y_test = test_data[:, 1:], test_data[:, 0]

    # Reshape input to be 3D [samples, timesteps, features]
    X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
    X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

    # Build LSTM model
    model = Sequential()
    model.add(Input(shape=(X_train.shape[1], 1)))
    model.add(LSTM(50, activation='tanh'))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mse')

    # Setup callbacks
    early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
    model_checkpoint = ModelCheckpoint('best_model.keras', monitor='val_loss', save_best_only=True)

    # Train the model
    history = model.fit(X_train, y_train, epochs=100, validation_data=(X_test, y_test), callbacks=[early_stop, model_checkpoint], verbose=1)

    # Make predictions
    lstm_pre = model.predict(X_test)

    # Prepare prediction DataFrame
    sales_dates = monthly_sales['date'][-12:].reset_index(drop=True)
    predict_df = pd.DataFrame(sales_dates, columns=['date'])

    act_sales = monthly_sales['sales'][-13:].to_list()
    lstm_pre = lstm_pre.reshape(-1, 1)
    lstm_pre_test_set = np.concatenate([lstm_pre, X_test.reshape((X_test.shape[0], X_test.shape[1]))], axis=1)
    lstm_pre_test_set = scaler.inverse_transform(lstm_pre_test_set)

    result_list = []
    for index in range(0, len(lstm_pre_test_set)):
        result_list.append(lstm_pre_test_set[index][0] + act_sales[index + 1])
    lstm_pre_series = pd.Series(result_list, name="LSTM Prediction")
    predict_df = predict_df.merge(lstm_pre_series, left_index=True, right_index=True)

    # Predict next 12 months
    future_predictions = []
    last_data = supervised_data[-1:].to_numpy()
    for _ in range(12):
        last_data_scaled = scaler.transform(last_data)
        X_last = last_data_scaled[:, 1:].reshape((1, X_train.shape[1], 1))
        next_pred = model.predict(X_last)[0, 0]
        future_pred = np.concatenate([[next_pred], last_data_scaled[0, 1:]])
        future_pred = scaler.inverse_transform([future_pred])
        future_predictions.append(future_pred[0][0] + act_sales[-1])
        last_data = np.concatenate([last_data[:, 0:1] + future_predictions[-1], last_data[:, 1:]], axis=1)
        act_sales.append(future_predictions[-1])
        last_data = last_data[-1:]  # Only keep the latest data for the next prediction

    future_dates = pd.date_range(start=monthly_sales['date'].iloc[-1] + pd.DateOffset(months=1), periods=12, freq='M')
    future_df = pd.DataFrame({'date': future_dates, 'LSTM Prediction': future_predictions})

    return monthly_sales, predict_df, future_df

# Process and predict for each category
low_sales, low_predict_df, low_future_df = process_category(store_sales, 'low')
mid_sales, mid_predict_df, mid_future_df = process_category(store_sales, 'mid')
high_sales, high_predict_df, high_future_df = process_category(store_sales, 'high')

# Plot predictions by category
plt.figure(figsize=(15, 15))

# Low category plot
plt.subplot(3, 1, 1)
plt.plot(low_sales['date'], low_sales['sales'], label='Actual Sales')
plt.plot(low_predict_df['date'], low_predict_df['LSTM Prediction'], label='Predicted Sales (Low)')
plt.plot(low_future_df['date'], low_future_df['LSTM Prediction'], label='Future Prediction (Low)', linestyle='--')
plt.title("Customer Sales Forecast - Low Category")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.legend()

# Mid category plot
plt.subplot(3, 1, 2)
plt.plot(mid_sales['date'], mid_sales['sales'], label='Actual Sales')
plt.plot(mid_predict_df['date'], mid_predict_df['LSTM Prediction'], label='Predicted Sales (Mid)')
plt.plot(mid_future_df['date'], mid_future_df['LSTM Prediction'], label='Future Prediction (Mid)', linestyle='--')
plt.title("Customer Sales Forecast - Mid Category")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.legend()

# High category plot
plt.subplot(3, 1, 3)
plt.plot(high_sales['date'], high_sales['sales'], label='Actual Sales')
plt.plot(high_predict_df['date'], high_predict_df['LSTM Prediction'], label='Predicted Sales (High)')
plt.plot(high_future_df['date'], high_future_df['LSTM Prediction'], label='Future Prediction (High)', linestyle='--')
plt.title("Customer Sales Forecast - High Category")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 459ms/step - loss: 0.2472 - val_loss: 0.6275
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.2376 - val_loss: 0.6217
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.2450 - val_loss: 0.6162
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.2394 - val_loss: 0.6112
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.2376 - val_loss: 0.6069
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.2388 - val_loss: 0.6035
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.2322 - val_loss: 0.6011
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.2353 - val_loss: 0.5994
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.2203 - val_loss: 0.5974
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.2185 - val_loss: 0.5958
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.2231 - val_loss: 0.5943
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.2174 - val_loss: 0.5908
# Epoch 13/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.2175 - val_loss: 0.5858
# Epoch 14/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.2237 - val_loss: 0.5809
# Epoch 15/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - loss: 0.2212 - val_loss: 0.5764
# Epoch 16/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.2179 - val_loss: 0.5722
# Epoch 17/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.2109 - val_loss: 0.5679
# Epoch 18/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.2068 - val_loss: 0.5625
# Epoch 19/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.2102 - val_loss: 0.5554
# Epoch 20/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.2077 - val_loss: 0.5483
# Epoch 21/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.2052 - val_loss: 0.5423
# Epoch 22/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.2060 - val_loss: 0.5364
# Epoch 23/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.2039 - val_loss: 0.5303
# Epoch 24/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.1976 - val_loss: 0.5238
# Epoch 25/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.2054 - val_loss: 0.5179
# Epoch 26/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.1976 - val_loss: 0.5133
# Epoch 27/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.2025 - val_loss: 0.5095
# Epoch 28/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.1960 - val_loss: 0.5057
# Epoch 29/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.1997 - val_loss: 0.5019
# Epoch 30/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.2026 - val_loss: 0.4984
# Epoch 31/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1942 - val_loss: 0.4958
# Epoch 32/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.1954 - val_loss: 0.4944
# Epoch 33/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.1911 - val_loss: 0.4936
# Epoch 34/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 0.1852 - val_loss: 0.4927
# Epoch 35/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.1869 - val_loss: 0.4916
# Epoch 36/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.1873 - val_loss: 0.4895
# Epoch 37/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.1842 - val_loss: 0.4838
# Epoch 38/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.1835 - val_loss: 0.4777
# Epoch 39/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.1794 - val_loss: 0.4729
# Epoch 40/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.1802 - val_loss: 0.4696
# Epoch 41/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.1803 - val_loss: 0.4669
# Epoch 42/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.1789 - val_loss: 0.4630
# Epoch 43/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.1767 - val_loss: 0.4587
# Epoch 44/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.1788 - val_loss: 0.4521
# Epoch 45/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.1787 - val_loss: 0.4451
# Epoch 46/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.1760 - val_loss: 0.4389
# Epoch 47/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.1777 - val_loss: 0.4332
# Epoch 48/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - loss: 0.1783 - val_loss: 0.4275
# Epoch 49/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - loss: 0.1759 - val_loss: 0.4220
# Epoch 50/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.1733 - val_loss: 0.4169
# Epoch 51/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.1741 - val_loss: 0.4132
# Epoch 52/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.1693 - val_loss: 0.4111
# Epoch 53/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.1699 - val_loss: 0.4097
# Epoch 54/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.1729 - val_loss: 0.4109
# Epoch 55/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.1733 - val_loss: 0.4147
# Epoch 56/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.1690 - val_loss: 0.4195
# Epoch 57/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.1720 - val_loss: 0.4257
# Epoch 58/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.1722 - val_loss: 0.4326
# Epoch 59/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.1686 - val_loss: 0.4393
# Epoch 60/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.1716 - val_loss: 0.4419
# Epoch 61/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.1755 - val_loss: 0.4390
# Epoch 62/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.1768 - val_loss: 0.4351
# Epoch 63/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.1641 - val_loss: 0.4250
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# C:\Users\MyPC\AppData\Local\Temp\ipykernel_2208\659797705.py:111: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   future_dates = pd.date_range(start=monthly_sales['date'].iloc[-1] + pd.DateOffset(months=1), periods=12, freq='M')
# Epoch 1/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 389ms/step - loss: 0.2095 - val_loss: 0.1404
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.2133 - val_loss: 0.1349
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - loss: 0.1971 - val_loss: 0.1291
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.2000 - val_loss: 0.1240
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.1925 - val_loss: 0.1199
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.1883 - val_loss: 0.1170
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.1844 - val_loss: 0.1153
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.1778 - val_loss: 0.1144
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.1752 - val_loss: 0.1138
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 0.1770 - val_loss: 0.1126
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.1665 - val_loss: 0.1099
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.1638 - val_loss: 0.1072
# Epoch 13/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.1612 - val_loss: 0.1055
# Epoch 14/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.1623 - val_loss: 0.1040
# Epoch 15/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.1558 - val_loss: 0.1020
# Epoch 16/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.1413 - val_loss: 0.0983
# Epoch 17/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.1491 - val_loss: 0.0940
# Epoch 18/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.1469 - val_loss: 0.0903
# Epoch 19/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.1378 - val_loss: 0.0869
# Epoch 20/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.1332 - val_loss: 0.0837
# Epoch 21/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.1295 - val_loss: 0.0805
# Epoch 22/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.1315 - val_loss: 0.0775
# Epoch 23/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.1290 - val_loss: 0.0747
# Epoch 24/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.1256 - val_loss: 0.0721
# Epoch 25/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.1162 - val_loss: 0.0693
# Epoch 26/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.1178 - val_loss: 0.0668
# Epoch 27/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.1152 - val_loss: 0.0652
# Epoch 28/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.1111 - val_loss: 0.0641
# Epoch 29/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.1077 - val_loss: 0.0624
# Epoch 30/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.1049 - val_loss: 0.0592
# Epoch 31/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.1033 - val_loss: 0.0561
# Epoch 32/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.1033 - val_loss: 0.0538
# Epoch 33/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1008 - val_loss: 0.0518
# Epoch 34/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0965 - val_loss: 0.0504
# Epoch 35/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0938 - val_loss: 0.0520
# Epoch 36/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0931 - val_loss: 0.0578
# Epoch 37/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0891 - val_loss: 0.0649
# Epoch 38/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0955 - val_loss: 0.0704
# Epoch 39/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0970 - val_loss: 0.0689
# Epoch 40/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0951 - val_loss: 0.0630
# Epoch 41/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0890 - val_loss: 0.0575
# Epoch 42/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0776 - val_loss: 0.0502
# Epoch 43/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 0.0824 - val_loss: 0.0460
# Epoch 44/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0770 - val_loss: 0.0460
# Epoch 45/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0818 - val_loss: 0.0488
# Epoch 46/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0942 - val_loss: 0.0518
# Epoch 47/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0955 - val_loss: 0.0514
# Epoch 48/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0981 - val_loss: 0.0485
# Epoch 49/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0895 - val_loss: 0.0424
# Epoch 50/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0824 - val_loss: 0.0397
# Epoch 51/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0771 - val_loss: 0.0490
# Epoch 52/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0754 - val_loss: 0.0653
# Epoch 53/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0854 - val_loss: 0.0836
# Epoch 54/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0987 - val_loss: 0.0902
# Epoch 55/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.1002 - val_loss: 0.0745
# Epoch 56/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0909 - val_loss: 0.0569
# Epoch 57/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0789 - val_loss: 0.0493
# Epoch 58/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0687 - val_loss: 0.0469
# Epoch 59/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0695 - val_loss: 0.0476
# Epoch 60/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0779 - val_loss: 0.0499
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# C:\Users\MyPC\AppData\Local\Temp\ipykernel_2208\659797705.py:111: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   future_dates = pd.date_range(start=monthly_sales['date'].iloc[-1] + pd.DateOffset(months=1), periods=12, freq='M')
# Epoch 1/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 402ms/step - loss: 0.2193 - val_loss: 0.3596
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.2197 - val_loss: 0.3505
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.2137 - val_loss: 0.3422
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.2098 - val_loss: 0.3342
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.2000 - val_loss: 0.3262
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.1985 - val_loss: 0.3184
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.1901 - val_loss: 0.3115
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.1899 - val_loss: 0.3051
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.1751 - val_loss: 0.2993
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.1816 - val_loss: 0.2937
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.1774 - val_loss: 0.2879
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.1771 - val_loss: 0.2825
# Epoch 13/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.1651 - val_loss: 0.2772
# Epoch 14/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.1644 - val_loss: 0.2719
# Epoch 15/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - loss: 0.1571 - val_loss: 0.2673
# Epoch 16/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.1624 - val_loss: 0.2628
# Epoch 17/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.1574 - val_loss: 0.2588
# Epoch 18/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.1546 - val_loss: 0.2551
# Epoch 19/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.1497 - val_loss: 0.2517
# Epoch 20/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.1409 - val_loss: 0.2488
# Epoch 21/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1422 - val_loss: 0.2467
# Epoch 22/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.1377 - val_loss: 0.2453
# Epoch 23/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.1351 - val_loss: 0.2437
# Epoch 24/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.1300 - val_loss: 0.2421
# Epoch 25/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.1223 - val_loss: 0.2414
# Epoch 26/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.1291 - val_loss: 0.2413
# Epoch 27/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.1233 - val_loss: 0.2413
# Epoch 28/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.1238 - val_loss: 0.2422
# Epoch 29/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.1276 - val_loss: 0.2441
# Epoch 30/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.1147 - val_loss: 0.2466
# Epoch 31/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.1178 - val_loss: 0.2499
# Epoch 32/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.1127 - val_loss: 0.2512
# Epoch 33/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.1190 - val_loss: 0.2500
# Epoch 34/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.1184 - val_loss: 0.2479
# Epoch 35/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.1178 - val_loss: 0.2476
# Epoch 36/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.1218 - val_loss: 0.2488
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# C:\Users\MyPC\AppData\Local\Temp\ipykernel_2208\659797705.py:111: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   future_dates = pd.date_range(start=monthly_sales['date'].iloc[-1] + pd.DateOffset(months=1), periods=12, freq='M')

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# Load data
url = 'https://raw.githubusercontent.com/C4AnN/Models/main/dataset_processing%20(2)/file_gabungan2.csv'
store_sales = pd.read_csv(url)
store_sales['date'] = pd.to_datetime(store_sales['date'])

# Drop unnecessary columns
store_sales = store_sales.drop(['name', 'price'], axis=1)

# Aggregate monthly sales
store_sales['date'] = store_sales['date'].dt.to_period("M")
monthly_sales = store_sales.groupby('date').sum().reset_index()
monthly_sales['date'] = monthly_sales['date'].dt.to_timestamp()

# Calculate sales difference
monthly_sales['sales_diff'] = monthly_sales['sales'].diff()
monthly_sales = monthly_sales.dropna()

# Prepare supervised data
supervised_data = monthly_sales.drop(['date', 'sales'], axis=1)
for i in range(1, 13):
    col_name = 'month_' + str(i)
    supervised_data[col_name] = supervised_data['sales_diff'].shift(i)
supervised_data = supervised_data.dropna().reset_index(drop=True)

# Split into train and test data
train_data = supervised_data[:-12]
test_data = supervised_data[-12:]

# Scale the data
scaler = MinMaxScaler(feature_range=(-1, 1))
scaler.fit(train_data)
train_data = scaler.transform(train_data)
test_data = scaler.transform(test_data)

X_train, y_train = train_data[:, 1:], train_data[:, 0]
X_test, y_test = test_data[:, 1:], test_data[:, 0]

# Reshape input to be 3D [samples, timesteps, features]
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# Build LSTM model
model = Sequential()
model.add(LSTM(50, activation='relu', input_shape=(X_train.shape[1], 1)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# Train the model
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
history = model.fit(X_train, y_train, epochs=100, validation_data=(X_test, y_test), callbacks=[early_stop], verbose=1)

# Make predictions
lstm_pre = model.predict(X_test)

# Prepare prediction DataFrame
sales_dates = monthly_sales['date'][-12:].reset_index(drop=True)
predict_df = pd.DataFrame(sales_dates, columns=['date'])

act_sales = monthly_sales['sales'][-13:].to_list()
lstm_pre = lstm_pre.reshape(-1, 1)
lstm_pre_test_set = np.concatenate([lstm_pre, X_test.reshape((X_test.shape[0], X_test.shape[1]))], axis=1)
lstm_pre_test_set = scaler.inverse_transform(lstm_pre_test_set)

result_list = []
for index in range(0, len(lstm_pre_test_set)):
    result_list.append(lstm_pre_test_set[index][0] + act_sales[index])
lstm_pre_series = pd.Series(result_list, name="LSTM Prediction")
predict_df = predict_df.merge(lstm_pre_series, left_index=True, right_index=True)

# Plot predictions
plt.figure(figsize=(15, 5))
plt.plot(monthly_sales['date'], monthly_sales['sales'], label='Actual Sales')
plt.plot(predict_df['date'], predict_df['LSTM Prediction'], label='Predicted Sales')
plt.title("Customer Sales Forecast - Full Dataset")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.legend()
plt.show()

# Calculate metrics
lstm_mse = mean_squared_error(monthly_sales['sales'][-12:], predict_df['LSTM Prediction'])
lstm_mae = mean_absolute_error(monthly_sales['sales'][-12:], predict_df['LSTM Prediction'])
lstm_r2 = r2_score(monthly_sales['sales'][-12:], predict_df['LSTM Prediction'])

print("LSTM MSE: ", lstm_mse)
print("LSTM MAE: ", lstm_mae)
print("LSTM R2: ", lstm_r2)
# Out:
# Epoch 1/100
# C:\Users\MyPC\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 286ms/step - loss: 0.2983 - val_loss: 0.3390
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.3078 - val_loss: 0.3383
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.3039 - val_loss: 0.3376
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.2964 - val_loss: 0.3369
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.3033 - val_loss: 0.3362
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.3013 - val_loss: 0.3355
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.3058 - val_loss: 0.3349
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.2972 - val_loss: 0.3343
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.3017 - val_loss: 0.3338
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.2865 - val_loss: 0.3334
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.2922 - val_loss: 0.3330
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.2943 - val_loss: 0.3328
# Epoch 13/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.2902 - val_loss: 0.3325
# Epoch 14/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.2933 - val_loss: 0.3322
# Epoch 15/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.2903 - val_loss: 0.3320
# Epoch 16/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.2849 - val_loss: 0.3318
# Epoch 17/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.2982 - val_loss: 0.3316
# Epoch 18/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.2963 - val_loss: 0.3313
# Epoch 19/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.2941 - val_loss: 0.3310
# Epoch 20/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.2998 - val_loss: 0.3306
# Epoch 21/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.2958 - val_loss: 0.3303
# Epoch 22/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.3000 - val_loss: 0.3299
# Epoch 23/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.3000 - val_loss: 0.3295
# Epoch 24/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.2965 - val_loss: 0.3292
# Epoch 25/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.2996 - val_loss: 0.3289
# Epoch 26/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.2968 - val_loss: 0.3285
# Epoch 27/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.2974 - val_loss: 0.3282
# Epoch 28/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.2887 - val_loss: 0.3279
# Epoch 29/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.2896 - val_loss: 0.3275
# Epoch 30/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.2995 - val_loss: 0.3272
# Epoch 31/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.2898 - val_loss: 0.3269
# Epoch 32/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.2763 - val_loss: 0.3266
# Epoch 33/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.2917 - val_loss: 0.3263
# Epoch 34/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.2877 - val_loss: 0.3260
# Epoch 35/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.2880 - val_loss: 0.3258
# Epoch 36/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.2873 - val_loss: 0.3256
# Epoch 37/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.2851 - val_loss: 0.3254
# Epoch 38/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.2931 - val_loss: 0.3252
# Epoch 39/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.2888 - val_loss: 0.3249
# Epoch 40/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.2921 - val_loss: 0.3247
# Epoch 41/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.2825 - val_loss: 0.3245
# Epoch 42/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.2775 - val_loss: 0.3243
# Epoch 43/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.2885 - val_loss: 0.3240
# Epoch 44/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.2966 - val_loss: 0.3238
# Epoch 45/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.2935 - val_loss: 0.3237
# Epoch 46/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.2763 - val_loss: 0.3235
# Epoch 47/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.2825 - val_loss: 0.3234
# Epoch 48/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.2815 - val_loss: 0.3232
# Epoch 49/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.2889 - val_loss: 0.3231
# Epoch 50/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.2905 - val_loss: 0.3230
# Epoch 51/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.2907 - val_loss: 0.3228
# Epoch 52/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.2731 - val_loss: 0.3227
# Epoch 53/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.2799 - val_loss: 0.3226
# Epoch 54/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.2827 - val_loss: 0.3225
# Epoch 55/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.2905 - val_loss: 0.3225
# Epoch 56/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.2843 - val_loss: 0.3225
# Epoch 57/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.2902 - val_loss: 0.3224
# Epoch 58/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.2845 - val_loss: 0.3223
# Epoch 59/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.2886 - val_loss: 0.3221
# Epoch 60/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.2892 - val_loss: 0.3219
# Epoch 61/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.2832 - val_loss: 0.3218
# Epoch 62/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.2747 - val_loss: 0.3217
# Epoch 63/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.2885 - val_loss: 0.3216
# Epoch 64/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.2818 - val_loss: 0.3214
# Epoch 65/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.2710 - val_loss: 0.3213
# Epoch 66/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.2897 - val_loss: 0.3212
# Epoch 67/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.2795 - val_loss: 0.3210
# Epoch 68/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.2844 - val_loss: 0.3209
# Epoch 69/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.2886 - val_loss: 0.3208
# Epoch 70/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.2829 - val_loss: 0.3206
# Epoch 71/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.2762 - val_loss: 0.3205
# Epoch 72/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.2771 - val_loss: 0.3204
# Epoch 73/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.2826 - val_loss: 0.3203
# Epoch 74/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.2781 - val_loss: 0.3202
# Epoch 75/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.2846 - val_loss: 0.3201
# Epoch 76/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.2907 - val_loss: 0.3200
# Epoch 77/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.2788 - val_loss: 0.3200
# Epoch 78/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.2895 - val_loss: 0.3199
# Epoch 79/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.2742 - val_loss: 0.3198
# Epoch 80/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.2880 - val_loss: 0.3197
# Epoch 81/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.2698 - val_loss: 0.3196
# Epoch 82/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.2880 - val_loss: 0.3195
# Epoch 83/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.2920 - val_loss: 0.3194
# Epoch 84/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.2832 - val_loss: 0.3193
# Epoch 85/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.2916 - val_loss: 0.3192
# Epoch 86/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.2777 - val_loss: 0.3191
# Epoch 87/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.2889 - val_loss: 0.3190
# Epoch 88/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.2833 - val_loss: 0.3189
# Epoch 89/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.2754 - val_loss: 0.3188
# Epoch 90/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.2777 - val_loss: 0.3187
# Epoch 91/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.2893 - val_loss: 0.3186
# Epoch 92/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.2867 - val_loss: 0.3186
# Epoch 93/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.2775 - val_loss: 0.3185
# Epoch 94/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.2912 - val_loss: 0.3185
# Epoch 95/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.2748 - val_loss: 0.3184
# Epoch 96/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.2861 - val_loss: 0.3183
# Epoch 97/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.2903 - val_loss: 0.3182
# Epoch 98/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.2779 - val_loss: 0.3181
# Epoch 99/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.2786 - val_loss: 0.3181
# Epoch 100/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.2836 - val_loss: 0.3180
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# LSTM MSE:  71069559.93508518
# LSTM MAE:  7073.670332000281
# LSTM R2:  0.5341011444232817
