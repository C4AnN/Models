# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Input
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
# Out:
# Epoch 1/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 472ms/step - loss: 0.3324 - val_loss: 0.3550
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.3088 - val_loss: 0.3448
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.3053 - val_loss: 0.3357
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - loss: 0.2939 - val_loss: 0.3264
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.2940 - val_loss: 0.3173
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.2909 - val_loss: 0.3086
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.2810 - val_loss: 0.3003
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.2623 - val_loss: 0.2917
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.2614 - val_loss: 0.2826
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.2482 - val_loss: 0.2734
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.2508 - val_loss: 0.2643
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.2347 - val_loss: 0.2552
# Epoch 13/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.2330 - val_loss: 0.2465
# Epoch 14/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.2243 - val_loss: 0.2385
# Epoch 15/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.2132 - val_loss: 0.2312
# Epoch 16/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.2073 - val_loss: 0.2244
# Epoch 17/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.2058 - val_loss: 0.2180
# Epoch 18/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.2002 - val_loss: 0.2129
# Epoch 19/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.1888 - val_loss: 0.2092
# Epoch 20/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.1904 - val_loss: 0.2061
# Epoch 21/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.1850 - val_loss: 0.2027
# Epoch 22/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.1718 - val_loss: 0.1937
# Epoch 23/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.1773 - val_loss: 0.1814
# Epoch 24/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.1658 - val_loss: 0.1722
# Epoch 25/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.1481 - val_loss: 0.1628
# Epoch 26/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 0.1519 - val_loss: 0.1550
# Epoch 27/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.1480 - val_loss: 0.1504
# Epoch 28/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.1450 - val_loss: 0.1482
# Epoch 29/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.1463 - val_loss: 0.1481
# Epoch 30/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.1438 - val_loss: 0.1484
# Epoch 31/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.1365 - val_loss: 0.1448
# Epoch 32/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.1287 - val_loss: 0.1396
# Epoch 33/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.1242 - val_loss: 0.1359
# Epoch 34/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.1251 - val_loss: 0.1308
# Epoch 35/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.1208 - val_loss: 0.1290
# Epoch 36/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.1205 - val_loss: 0.1293
# Epoch 37/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.1222 - val_loss: 0.1311
# Epoch 38/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.1226 - val_loss: 0.1323
# Epoch 39/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.1242 - val_loss: 0.1329
# Epoch 40/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1199 - val_loss: 0.1315
# Epoch 41/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.1232 - val_loss: 0.1275
# Epoch 42/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.1206 - val_loss: 0.1234
# Epoch 43/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.1124 - val_loss: 0.1187
# Epoch 44/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.1055 - val_loss: 0.1124
# Epoch 45/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.1062 - val_loss: 0.1076
# Epoch 46/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 0.1054 - val_loss: 0.1072
# Epoch 47/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1107 - val_loss: 0.1082
# Epoch 48/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.1148 - val_loss: 0.1068
# Epoch 49/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.1131 - val_loss: 0.1053
# Epoch 50/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.1104 - val_loss: 0.1044
# Epoch 51/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.1048 - val_loss: 0.1039
# Epoch 52/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - loss: 0.0970 - val_loss: 0.1053
# Epoch 53/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.1020 - val_loss: 0.1070
# Epoch 54/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.1014 - val_loss: 0.1068
# Epoch 55/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0999 - val_loss: 0.1073
# Epoch 56/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0997 - val_loss: 0.1059
# Epoch 57/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0973 - val_loss: 0.1034
# Epoch 58/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0990 - val_loss: 0.1012
# Epoch 59/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0992 - val_loss: 0.0989
# Epoch 60/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0961 - val_loss: 0.0982
# Epoch 61/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0975 - val_loss: 0.1004
# Epoch 62/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.1043 - val_loss: 0.1020
# Epoch 63/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.1062 - val_loss: 0.1005
# Epoch 64/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.1054 - val_loss: 0.0971
# Epoch 65/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0989 - val_loss: 0.0925
# Epoch 66/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0979 - val_loss: 0.0912
# Epoch 67/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0915 - val_loss: 0.0934
# Epoch 68/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0866 - val_loss: 0.0990
# Epoch 69/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0926 - val_loss: 0.1074
# Epoch 70/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0982 - val_loss: 0.1077
# Epoch 71/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - loss: 0.0975 - val_loss: 0.1004
# Epoch 72/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0909 - val_loss: 0.0943
# Epoch 73/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0888 - val_loss: 0.0897
# Epoch 74/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0865 - val_loss: 0.0862
# Epoch 75/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0823 - val_loss: 0.0848
# Epoch 76/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0831 - val_loss: 0.0844
# Epoch 77/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0837 - val_loss: 0.0847
# Epoch 78/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0844 - val_loss: 0.0856
# Epoch 79/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0838 - val_loss: 0.0866
# Epoch 80/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0805 - val_loss: 0.0848
# Epoch 81/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0823 - val_loss: 0.0817
# Epoch 82/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0809 - val_loss: 0.0795
# Epoch 83/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0774 - val_loss: 0.0773
# Epoch 84/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0805 - val_loss: 0.0767
# Epoch 85/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0765 - val_loss: 0.0758
# Epoch 86/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0788 - val_loss: 0.0758
# Epoch 87/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0765 - val_loss: 0.0788
# Epoch 88/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0740 - val_loss: 0.0840
# Epoch 89/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0767 - val_loss: 0.0890
# Epoch 90/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0819 - val_loss: 0.0908
# Epoch 91/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0807 - val_loss: 0.0887
# Epoch 92/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0828 - val_loss: 0.0854
# Epoch 93/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0823 - val_loss: 0.0826
# Epoch 94/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0767 - val_loss: 0.0778
# Epoch 95/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0732 - val_loss: 0.0716
# Epoch 96/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0713 - val_loss: 0.0679
# Epoch 97/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0689 - val_loss: 0.0686
# Epoch 98/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0737 - val_loss: 0.0747
# Epoch 99/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0766 - val_loss: 0.0812
# Epoch 100/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0800 - val_loss: 0.0831
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step

# %%
# Load data
url = 'https://raw.githubusercontent.com/C4AnN/Models/main/dataset_processing%20(2)/file_gabungan2.csv'
store_sales = pd.read_csv(url)
store_sales['date'] = pd.to_datetime(store_sales['date'])

# Drop unnecessary columns
store_sales = store_sales.drop(['name', 'price'], axis=1)

# %%
# Function to process and predict sales data
def process_sales_data(data):
    data['date'] = data['date'].dt.to_period("M")
    monthly_sales = data.groupby('date').sum().reset_index()
    monthly_sales['date'] = monthly_sales['date'].dt.to_timestamp()

    # Calculate sales difference
    monthly_sales['sales_diff'] = monthly_sales['sales'].diff()
    monthly_sales = monthly_sales.dropna()

    # Prepare supervised data
    supervised_data = monthly_sales.drop(['date', 'sales'], axis=1)
    for i in range(1, 13):
        col_name = 'month_' + str(i)
        supervised_data[col_name] = supervised_data['sales_diff'].shift(i)
    supervised_data = supervised_data.dropna().reset_index(drop=True)

    # Split into train and test data
    train_data = supervised_data[:-12]
    test_data = supervised_data[-12:]

    # Convert to DataFrame to retain column names
    scaler = MinMaxScaler(feature_range=(-1, 1))
    train_data_df = pd.DataFrame(train_data, columns=supervised_data.columns)
    test_data_df = pd.DataFrame(test_data, columns=supervised_data.columns)
    
    # Scale the data
    scaler.fit(train_data_df)
    train_data_scaled = scaler.transform(train_data_df)
    test_data_scaled = scaler.transform(test_data_df)

    X_train, y_train = train_data_scaled[:, 1:], train_data_scaled[:, 0]
    X_test, y_test = test_data_scaled[:, 1:], test_data_scaled[:, 0]

    # Reshape input to be 3D [samples, timesteps, features]
    X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
    X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

    # Build LSTM model
    model = Sequential()
    model.add(Input(shape=(X_train.shape[1], 1)))
    model.add(LSTM(50, activation='tanh'))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mse')

    # Setup callbacks
    early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
    model_checkpoint = ModelCheckpoint('best_model.keras', monitor='val_loss', save_best_only=True)

    # Train the model
    history = model.fit(X_train, y_train, epochs=100, validation_data=(X_test, y_test), callbacks=[early_stop, model_checkpoint], verbose=1)

    # Make predictions
    lstm_pre = model.predict(X_test)

    # Prepare prediction DataFrame
    sales_dates = monthly_sales['date'][-12:].reset_index(drop=True)
    predict_df = pd.DataFrame(sales_dates, columns=['date'])

    act_sales = monthly_sales['sales'][-13:].to_list()
    lstm_pre = lstm_pre.reshape(-1, 1)
    lstm_pre_test_set = np.concatenate([lstm_pre, X_test.reshape((X_test.shape[0], X_test.shape[1]))], axis=1)
    lstm_pre_test_set = scaler.inverse_transform(lstm_pre_test_set)

    result_list = []
    for index in range(0, len(lstm_pre_test_set)):
        result_list.append(lstm_pre_test_set[index][0] + act_sales[index + 1])
    lstm_pre_series = pd.Series(result_list, name="LSTM Prediction")
    predict_df = predict_df.merge(lstm_pre_series, left_index=True, right_index=True)

    # Predict next 12 months
    future_predictions = []
    last_data = supervised_data[-1:].to_numpy()
    for _ in range(12):
        last_data_scaled = scaler.transform(pd.DataFrame(last_data, columns=supervised_data.columns))
        X_last = last_data_scaled[:, 1:].reshape((1, X_train.shape[1], 1))
        next_pred = model.predict(X_last)[0, 0]
        future_pred = np.concatenate([[next_pred], last_data_scaled[0, 1:]])
        future_pred = scaler.inverse_transform([future_pred])
        future_predictions.append(future_pred[0][0] + act_sales[-1])
        last_data = np.concatenate([last_data[:, 0:1] + future_predictions[-1], last_data[:, 1:]], axis=1)
        act_sales.append(future_predictions[-1])
        last_data = last_data[-1:]  # Only keep the latest data for the next prediction

    future_dates = pd.date_range(start=monthly_sales['date'].iloc[-1] + pd.DateOffset(months=1), periods=12, freq='ME')
    future_df = pd.DataFrame({'date': future_dates, 'LSTM Prediction': future_predictions})

    return monthly_sales, predict_df, future_df

# Process and predict sales data for all categories combined
all_sales, all_predict_df, all_future_df = process_sales_data(store_sales)

# %%
# Plot predictions
plt.figure(figsize=(15, 5))

plt.plot(all_sales['date'], all_sales['sales'], label='Actual Sales')
plt.plot(all_predict_df['date'], all_predict_df['LSTM Prediction'], label='Predicted Sales')
plt.plot(all_future_df['date'], all_future_df['LSTM Prediction'], label='Future Prediction', linestyle='--')
plt.title("Customer Sales Forecast - All Categories Combined")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.legend()

plt.tight_layout()
plt.show()
