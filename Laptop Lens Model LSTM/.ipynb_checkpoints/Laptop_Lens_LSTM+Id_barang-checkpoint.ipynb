# %% [markdown]
# ## **MODEL LSTM**

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from tensorflow.keras.models import Sequential, model_from_json
from tensorflow.keras.layers import Dense, LSTM, Dropout, Input
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam

# Load data
url = 'https://raw.githubusercontent.com/C4AnN/Models/main/Laptop%20Lens%20Model%20LSTM/file_gabungan2%2Bid.csv'
store_sales = pd.read_csv(url)
store_sales['date'] = pd.to_datetime(store_sales['date'])

# Categorize data based on price
def categorize_price(price):
    if price <= 8000000:
        return 'low'
    elif 8000000 < price <= 16000000:
        return 'mid'
    else:
        return 'high'

store_sales['category'] = store_sales['price'].apply(categorize_price)

# Drop unnecessary columns
store_sales = store_sales.drop(['id_barang','name', 'price'], axis=1)

# Function to process and predict for each category
def process_category(data, category_name, window_size):
    data = data[data['category'] == category_name].drop(['category'], axis=1)
    data['date'] = data['date'].dt.to_period("M")
    monthly_sales = data.groupby('date').sum().reset_index()
    monthly_sales['date'] = monthly_sales['date'].dt.to_timestamp()

    # Calculate sales difference
    monthly_sales['sales_diff'] = monthly_sales['sales'].diff()
    monthly_sales = monthly_sales.dropna()

    # Prepare supervised data with a window size
    supervised_data = monthly_sales.drop(['date', 'sales'], axis=1)
    for i in range(1, window_size + 1):
        col_name = 'month_' + str(i)
        supervised_data[col_name] = supervised_data['sales_diff'].shift(i)
    supervised_data = supervised_data.dropna().reset_index(drop=True)

    # Split into train and test data
    train_data = supervised_data[:-24]
    test_data = supervised_data[-12:]

    # Scale the data
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler.fit(train_data)
    train_data_scaled = scaler.transform(train_data)
    test_data_scaled = scaler.transform(test_data)

    X_train, y_train = train_data_scaled[:, 1:], train_data_scaled[:, 0]
    X_test, y_test = test_data_scaled[:, 1:], test_data_scaled[:, 0]

    # Reshape input to be 3D [samples, timesteps, features]
    X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
    X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

    # Build LSTM model
    model = Sequential()
    model.add(Input(shape=(X_train.shape[1], 1)))
    model.add(LSTM(200, activation='tanh', return_sequences=True))
    model.add(Dropout(0.3))
    model.add(LSTM(100, activation='tanh'))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mse')

    # Setup callbacks
    early_stop = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

    # Train the model
    history = model.fit(X_train, y_train, epochs=100, batch_size=16, validation_data=(X_test, y_test), callbacks=[early_stop], verbose=1)

    # Save the model architecture to JSON and weights to HDF5
    model_json = model.to_json()
    with open(f'best_model_{category_name}.json', 'w') as json_file:
        json_file.write(model_json)
    model.save_weights(f'best_model_weights_{category_name}.h5')

    # Make predictions
    lstm_pre = model.predict(X_test)

    # Prepare prediction DataFrame
    sales_dates = monthly_sales['date'][-12:].reset_index(drop=True)
    predict_df = pd.DataFrame(sales_dates, columns=['date'])

    act_sales = monthly_sales['sales'][-13:].to_list()
    lstm_pre = lstm_pre.reshape(-1, 1)
    lstm_pre_test_set = np.concatenate([lstm_pre, X_test.reshape((X_test.shape[0], X_test.shape[1]))], axis=1)
    lstm_pre_test_set = scaler.inverse_transform(lstm_pre_test_set)

    result_list = []
    for index in range(0, len(lstm_pre_test_set)):
        result_list.append(lstm_pre_test_set[index][0] + act_sales[index + 1])
    lstm_pre_series = pd.Series(result_list, name="LSTM Prediction")
    predict_df = predict_df.merge(lstm_pre_series, left_index=True, right_index=True)

    # Predict next 12 months
    future_predictions = []
    last_data = supervised_data[-1:].copy()

    for _ in range(12):
        last_data_scaled = scaler.transform(last_data)
        X_last = last_data_scaled[:, 1:].reshape((1, X_train.shape[1], 1))
        next_pred = model.predict(X_last)[0, 0]

        future_pred = np.concatenate([[next_pred], last_data_scaled[0, 1:]])
        future_pred = scaler.inverse_transform([future_pred])

        future_predictions.append(future_pred[0][0] + monthly_sales['sales'].iloc[-1])

        new_row = np.append([next_pred], last_data.values[0, :-1])
        last_data = pd.DataFrame([new_row], columns=supervised_data.columns)

    future_dates = pd.date_range(start=monthly_sales['date'].iloc[-1] + pd.DateOffset(months=1), periods=12, freq='M')
    future_df = pd.DataFrame({'date': future_dates, 'LSTM Prediction': future_predictions})

    return monthly_sales, predict_df, future_df, model

# Process and predict for each category using window size of 12 months
window_size = 12  # Increase window size to consider more historical data

low_sales, low_predict_df, low_future_df, low_model = process_category(store_sales, 'low', window_size)
mid_sales, mid_predict_df, mid_future_df, mid_model = process_category(store_sales, 'mid', window_size)
high_sales, high_predict_df, high_future_df, high_model = process_category(store_sales, 'high', window_size)

# Save all models' architectures and weights
models = {'low': low_model, 'mid': mid_model, 'high': high_model}
for category, model in models.items():
    model_json = model.to_json()
    with open(f'best_model_{category}.json', 'w') as json_file:
        json_file.write(model_json)
    model.save_weights(f'best_model_weights_{category}.h5')
# Out:
# Epoch 1/100
# 2/2 [==============================] - 4s 874ms/step - loss: 0.3161 - val_loss: 0.6252
# Epoch 2/100
# 2/2 [==============================] - 0s 56ms/step - loss: 0.2976 - val_loss: 0.6110
# Epoch 3/100
# 2/2 [==============================] - 0s 56ms/step - loss: 0.2935 - val_loss: 0.5973
# Epoch 4/100
# 2/2 [==============================] - 0s 91ms/step - loss: 0.2862 - val_loss: 0.5841
# Epoch 5/100
# 2/2 [==============================] - 0s 91ms/step - loss: 0.2726 - val_loss: 0.5737
# Epoch 6/100
# 2/2 [==============================] - 0s 93ms/step - loss: 0.2617 - val_loss: 0.5717
# Epoch 7/100
# 2/2 [==============================] - 0s 97ms/step - loss: 0.2544 - val_loss: 0.5816
# Epoch 8/100
# 2/2 [==============================] - 0s 85ms/step - loss: 0.2570 - val_loss: 0.5837
# Epoch 9/100
# 2/2 [==============================] - 0s 85ms/step - loss: 0.2515 - val_loss: 0.5380
# Epoch 10/100
# 2/2 [==============================] - 0s 94ms/step - loss: 0.2402 - val_loss: 0.4965
# Epoch 11/100
# 2/2 [==============================] - 0s 94ms/step - loss: 0.2340 - val_loss: 0.4771
# Epoch 12/100
# 2/2 [==============================] - 0s 98ms/step - loss: 0.2337 - val_loss: 0.4628
# Epoch 13/100
# 2/2 [==============================] - 0s 89ms/step - loss: 0.2302 - val_loss: 0.4545
# Epoch 14/100
# 2/2 [==============================] - 0s 88ms/step - loss: 0.2309 - val_loss: 0.4471
# Epoch 15/100
# 2/2 [==============================] - 0s 88ms/step - loss: 0.2315 - val_loss: 0.4342
# Epoch 16/100
# 2/2 [==============================] - 0s 87ms/step - loss: 0.2307 - val_loss: 0.4286
# Epoch 17/100
# 2/2 [==============================] - 0s 91ms/step - loss: 0.2277 - val_loss: 0.4263
# Epoch 18/100
# 2/2 [==============================] - 0s 94ms/step - loss: 0.2242 - val_loss: 0.4192
# Epoch 19/100
# 2/2 [==============================] - 0s 96ms/step - loss: 0.2199 - val_loss: 0.4193
# Epoch 20/100
# 2/2 [==============================] - 0s 90ms/step - loss: 0.2210 - val_loss: 0.4190
# Epoch 21/100
# 2/2 [==============================] - 0s 89ms/step - loss: 0.2223 - val_loss: 0.4269
# Epoch 22/100
# 2/2 [==============================] - 0s 98ms/step - loss: 0.2263 - val_loss: 0.4420
# Epoch 23/100
# 2/2 [==============================] - 0s 88ms/step - loss: 0.2257 - val_loss: 0.4710
# Epoch 24/100
# 2/2 [==============================] - 0s 90ms/step - loss: 0.2249 - val_loss: 0.4822
# Epoch 25/100
# 2/2 [==============================] - 0s 92ms/step - loss: 0.2209 - val_loss: 0.4610
# Epoch 26/100
# 2/2 [==============================] - 0s 91ms/step - loss: 0.2203 - val_loss: 0.4379
# Epoch 27/100
# 2/2 [==============================] - 0s 83ms/step - loss: 0.2183 - val_loss: 0.4233
# Epoch 28/100
# 2/2 [==============================] - 0s 56ms/step - loss: 0.2194 - val_loss: 0.4116
# Epoch 29/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.2135 - val_loss: 0.4071
# Epoch 30/100
# 2/2 [==============================] - 0s 54ms/step - loss: 0.2133 - val_loss: 0.4016
# Epoch 31/100
# 2/2 [==============================] - 0s 57ms/step - loss: 0.2105 - val_loss: 0.3945
# Epoch 32/100
# 2/2 [==============================] - 0s 58ms/step - loss: 0.2046 - val_loss: 0.3893
# Epoch 33/100
# 2/2 [==============================] - 0s 61ms/step - loss: 0.2089 - val_loss: 0.3841
# Epoch 34/100
# 2/2 [==============================] - 0s 66ms/step - loss: 0.2073 - val_loss: 0.3730
# Epoch 35/100
# 2/2 [==============================] - 0s 56ms/step - loss: 0.2085 - val_loss: 0.3634
# Epoch 36/100
# 2/2 [==============================] - 0s 57ms/step - loss: 0.2083 - val_loss: 0.3623
# Epoch 37/100
# 2/2 [==============================] - 0s 55ms/step - loss: 0.1973 - val_loss: 0.3720
# Epoch 38/100
# 2/2 [==============================] - 0s 56ms/step - loss: 0.1974 - val_loss: 0.3848
# Epoch 39/100
# 2/2 [==============================] - 0s 53ms/step - loss: 0.2028 - val_loss: 0.3834
# Epoch 40/100
# 2/2 [==============================] - 0s 53ms/step - loss: 0.2000 - val_loss: 0.3803
# Epoch 41/100
# 2/2 [==============================] - 0s 53ms/step - loss: 0.2003 - val_loss: 0.3747
# Epoch 42/100
# 2/2 [==============================] - 0s 60ms/step - loss: 0.1966 - val_loss: 0.3744
# Epoch 43/100
# 2/2 [==============================] - 0s 55ms/step - loss: 0.1985 - val_loss: 0.3709
# Epoch 44/100
# 2/2 [==============================] - 0s 54ms/step - loss: 0.2009 - val_loss: 0.3663
# Epoch 45/100
# 2/2 [==============================] - 0s 60ms/step - loss: 0.1952 - val_loss: 0.3693
# Epoch 46/100
# 2/2 [==============================] - 0s 57ms/step - loss: 0.1854 - val_loss: 0.3674
# Epoch 47/100
# 2/2 [==============================] - 0s 59ms/step - loss: 0.1888 - val_loss: 0.3578
# Epoch 48/100
# 2/2 [==============================] - 0s 62ms/step - loss: 0.1848 - val_loss: 0.3382
# Epoch 49/100
# 2/2 [==============================] - 0s 55ms/step - loss: 0.1776 - val_loss: 0.3280
# Epoch 50/100
# 2/2 [==============================] - 0s 56ms/step - loss: 0.1805 - val_loss: 0.3218
# Epoch 51/100
# 2/2 [==============================] - 0s 59ms/step - loss: 0.1721 - val_loss: 0.3215
# Epoch 52/100
# 2/2 [==============================] - 0s 53ms/step - loss: 0.1778 - val_loss: 0.3296
# Epoch 53/100
# 2/2 [==============================] - 0s 55ms/step - loss: 0.1734 - val_loss: 0.3377
# Epoch 54/100
# 2/2 [==============================] - 0s 55ms/step - loss: 0.1751 - val_loss: 0.3318
# Epoch 55/100
# 2/2 [==============================] - 0s 59ms/step - loss: 0.1779 - val_loss: 0.3391
# Epoch 56/100
# 2/2 [==============================] - 0s 60ms/step - loss: 0.1924 - val_loss: 0.3565
# Epoch 57/100
# 2/2 [==============================] - 0s 56ms/step - loss: 0.1623 - val_loss: 0.3837
# Epoch 58/100
# 2/2 [==============================] - 0s 60ms/step - loss: 0.1798 - val_loss: 0.4126
# Epoch 59/100
# 2/2 [==============================] - 0s 55ms/step - loss: 0.1589 - val_loss: 0.4064
# Epoch 60/100
# 2/2 [==============================] - 0s 55ms/step - loss: 0.1603 - val_loss: 0.3997
# Epoch 61/100
# 2/2 [==============================] - 0s 55ms/step - loss: 0.1651 - val_loss: 0.3854
# Epoch 62/100
# 2/2 [==============================] - 0s 55ms/step - loss: 0.1635 - val_loss: 0.3786
# Epoch 63/100
# 2/2 [==============================] - 0s 53ms/step - loss: 0.1527 - val_loss: 0.3689
# Epoch 64/100
# 2/2 [==============================] - 0s 55ms/step - loss: 0.1415 - val_loss: 0.3616
# Epoch 65/100
# 2/2 [==============================] - 0s 55ms/step - loss: 0.1536 - val_loss: 0.3593
# Epoch 66/100
# 2/2 [==============================] - 0s 53ms/step - loss: 0.1415 - val_loss: 0.3419
# Epoch 67/100
# 2/2 [==============================] - 0s 56ms/step - loss: 0.1452 - val_loss: 0.3586
# Epoch 68/100
# 2/2 [==============================] - 0s 53ms/step - loss: 0.1486 - val_loss: 0.3901
# Epoch 69/100
# 2/2 [==============================] - 0s 53ms/step - loss: 0.1327 - val_loss: 0.4045
# Epoch 70/100
# 2/2 [==============================] - 0s 55ms/step - loss: 0.1239 - val_loss: 0.4302
# Epoch 71/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.1408 - val_loss: 0.4521
# 1/1 [==============================] - 1s 762ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# Epoch 1/100
# 2/2 [==============================] - 6s 2s/step - loss: 0.2119 - val_loss: 0.1117
# Epoch 2/100
# 2/2 [==============================] - 0s 59ms/step - loss: 0.1845 - val_loss: 0.0993
# Epoch 3/100
# 2/2 [==============================] - 0s 57ms/step - loss: 0.1680 - val_loss: 0.1029
# Epoch 4/100
# 2/2 [==============================] - 0s 64ms/step - loss: 0.1460 - val_loss: 0.0881
# Epoch 5/100
# 2/2 [==============================] - 0s 58ms/step - loss: 0.1302 - val_loss: 0.0733
# Epoch 6/100
# 2/2 [==============================] - 0s 58ms/step - loss: 0.1201 - val_loss: 0.0636
# Epoch 7/100
# 2/2 [==============================] - 0s 57ms/step - loss: 0.1112 - val_loss: 0.0552
# Epoch 8/100
# 2/2 [==============================] - 0s 59ms/step - loss: 0.1000 - val_loss: 0.0475
# Epoch 9/100
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0946 - val_loss: 0.0530
# Epoch 10/100
# 2/2 [==============================] - 0s 66ms/step - loss: 0.1059 - val_loss: 0.0492
# Epoch 11/100
# 2/2 [==============================] - 0s 55ms/step - loss: 0.0973 - val_loss: 0.0482
# Epoch 12/100
# 2/2 [==============================] - 0s 54ms/step - loss: 0.0965 - val_loss: 0.0488
# Epoch 13/100
# 2/2 [==============================] - 0s 57ms/step - loss: 0.0901 - val_loss: 0.0499
# Epoch 14/100
# 2/2 [==============================] - 0s 58ms/step - loss: 0.0932 - val_loss: 0.0471
# Epoch 15/100
# 2/2 [==============================] - 0s 59ms/step - loss: 0.0863 - val_loss: 0.0516
# Epoch 16/100
# 2/2 [==============================] - 0s 61ms/step - loss: 0.0902 - val_loss: 0.0498
# Epoch 17/100
# 2/2 [==============================] - 0s 58ms/step - loss: 0.0903 - val_loss: 0.0390
# Epoch 18/100
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0853 - val_loss: 0.0417
# Epoch 19/100
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0840 - val_loss: 0.0467
# Epoch 20/100
# 2/2 [==============================] - 0s 60ms/step - loss: 0.0878 - val_loss: 0.0522
# Epoch 21/100
# 2/2 [==============================] - 0s 74ms/step - loss: 0.0883 - val_loss: 0.0530
# Epoch 22/100
# 2/2 [==============================] - 0s 58ms/step - loss: 0.0820 - val_loss: 0.0651
# Epoch 23/100
# 2/2 [==============================] - 0s 58ms/step - loss: 0.0870 - val_loss: 0.0725
# Epoch 24/100
# 2/2 [==============================] - 0s 57ms/step - loss: 0.0829 - val_loss: 0.0655
# Epoch 25/100
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0772 - val_loss: 0.0566
# Epoch 26/100
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0779 - val_loss: 0.0615
# Epoch 27/100
# 2/2 [==============================] - 0s 58ms/step - loss: 0.0901 - val_loss: 0.0621
# Epoch 28/100
# 2/2 [==============================] - 0s 57ms/step - loss: 0.0905 - val_loss: 0.0554
# Epoch 29/100
# 2/2 [==============================] - 0s 54ms/step - loss: 0.0818 - val_loss: 0.0604
# Epoch 30/100
# 2/2 [==============================] - 0s 55ms/step - loss: 0.0787 - val_loss: 0.0699
# Epoch 31/100
# 2/2 [==============================] - 0s 59ms/step - loss: 0.0797 - val_loss: 0.0509
# Epoch 32/100
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0740 - val_loss: 0.0542
# Epoch 33/100
# 2/2 [==============================] - 0s 57ms/step - loss: 0.0800 - val_loss: 0.0626
# Epoch 34/100
# 2/2 [==============================] - 0s 57ms/step - loss: 0.0761 - val_loss: 0.0763
# Epoch 35/100
# 2/2 [==============================] - 0s 58ms/step - loss: 0.0809 - val_loss: 0.0594
# Epoch 36/100
# 2/2 [==============================] - 0s 61ms/step - loss: 0.0761 - val_loss: 0.0515
# Epoch 37/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0841 - val_loss: 0.0473
# 1/1 [==============================] - 1s 765ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# Epoch 1/100
# 2/2 [==============================] - 5s 1s/step - loss: 0.2530 - val_loss: 0.4953
# Epoch 2/100
# 2/2 [==============================] - 0s 88ms/step - loss: 0.2379 - val_loss: 0.4841
# Epoch 3/100
# 2/2 [==============================] - 0s 102ms/step - loss: 0.2302 - val_loss: 0.4646
# Epoch 4/100
# 2/2 [==============================] - 0s 106ms/step - loss: 0.2171 - val_loss: 0.4339
# Epoch 5/100
# 2/2 [==============================] - 0s 105ms/step - loss: 0.2000 - val_loss: 0.3919
# Epoch 6/100
# 2/2 [==============================] - 0s 112ms/step - loss: 0.1863 - val_loss: 0.3626
# Epoch 7/100
# 2/2 [==============================] - 0s 108ms/step - loss: 0.1839 - val_loss: 0.3706
# Epoch 8/100
# 2/2 [==============================] - 0s 91ms/step - loss: 0.1731 - val_loss: 0.4028
# Epoch 9/100
# 2/2 [==============================] - 0s 115ms/step - loss: 0.1539 - val_loss: 0.4691
# Epoch 10/100
# 2/2 [==============================] - 0s 90ms/step - loss: 0.1805 - val_loss: 0.5092
# Epoch 11/100
# 2/2 [==============================] - 0s 61ms/step - loss: 0.1767 - val_loss: 0.4659
# Epoch 12/100
# 2/2 [==============================] - 0s 57ms/step - loss: 0.1590 - val_loss: 0.4346
# Epoch 13/100
# 2/2 [==============================] - 0s 58ms/step - loss: 0.1570 - val_loss: 0.4255
# Epoch 14/100
# 2/2 [==============================] - 0s 56ms/step - loss: 0.1587 - val_loss: 0.4314
# Epoch 15/100
# 2/2 [==============================] - 0s 60ms/step - loss: 0.1587 - val_loss: 0.4242
# Epoch 16/100
# 2/2 [==============================] - 0s 60ms/step - loss: 0.1595 - val_loss: 0.4087
# Epoch 17/100
# 2/2 [==============================] - 0s 59ms/step - loss: 0.1545 - val_loss: 0.3949
# Epoch 18/100
# 2/2 [==============================] - 0s 57ms/step - loss: 0.1559 - val_loss: 0.3850
# Epoch 19/100
# 2/2 [==============================] - 0s 57ms/step - loss: 0.1554 - val_loss: 0.3897
# Epoch 20/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.1517 - val_loss: 0.3970
# Epoch 21/100
# 2/2 [==============================] - 0s 55ms/step - loss: 0.1496 - val_loss: 0.4071
# Epoch 22/100
# 2/2 [==============================] - 0s 56ms/step - loss: 0.1516 - val_loss: 0.4165
# Epoch 23/100
# 2/2 [==============================] - 0s 58ms/step - loss: 0.1455 - val_loss: 0.4180
# Epoch 24/100
# 2/2 [==============================] - 0s 70ms/step - loss: 0.1462 - val_loss: 0.4114
# Epoch 25/100
# 2/2 [==============================] - 0s 57ms/step - loss: 0.1531 - val_loss: 0.4105
# Epoch 26/100
# 2/2 [==============================] - 0s 62ms/step - loss: 0.1541 - val_loss: 0.4320
# 1/1 [==============================] - 1s 772ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step

# %% [markdown]
# ## **VISUALISASI DATA**

# %%
# Plot predictions by category
plt.figure(figsize=(15, 15))

# Low category plot
plt.subplot(3, 1, 1)
plt.plot(low_sales['date'], low_sales['sales'], label='Actual Sales')
plt.plot(low_predict_df['date'], low_predict_df['LSTM Prediction'], label='Predicted Sales (Low)')
plt.title("Customer Sales Forecast - Low Category (Window Size: 12)")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.legend()

# Mid category plot
plt.subplot(3, 1, 2)
plt.plot(mid_sales['date'], mid_sales['sales'], label='Actual Sales')
plt.plot(mid_predict_df['date'], mid_predict_df['LSTM Prediction'], label='Predicted Sales (Mid)')
plt.title("Customer Sales Forecast - Mid Category (Window Size: 12)")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.legend()

# High category plot
plt.subplot(3, 1, 3)
plt.plot(high_sales['date'], high_sales['sales'], label='Actual Sales')
plt.plot(high_predict_df['date'], high_predict_df['LSTM Prediction'], label='Predicted Sales (High)')
plt.title("Customer Sales Forecast - High Category (Window Size: 12)")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## **LOAD DATA JSON**

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import model_from_json

# Load models from JSON and weights from HDF5
def load_model_from_json(json_path, weights_path):
    with open(json_path, 'r') as json_file:
        model_json = json_file.read()
    model = model_from_json(model_json)
    model.load_weights(weights_path)
    return model

loaded_model_low = load_model_from_json('best_model_low.json', 'best_model_weights_low.h5')
loaded_model_mid = load_model_from_json('best_model_mid.json', 'best_model_weights_mid.h5')
loaded_model_high = load_model_from_json('best_model_high.json', 'best_model_weights_high.h5')

# Load new data from CSV file
new_data_url = 'https://raw.githubusercontent.com/C4AnN/Models/main/Laptop%20Lens%20Model%20LSTM/file_gabungan2%2Bid.csv'
new_data = pd.read_csv(new_data_url)

# Ensure 'date' column is in datetime format
new_data['date'] = pd.to_datetime(new_data['date'])

# Function to categorize price
def categorize_price(price):
    if price <= 8000000:
        return 'low'
    elif 8000000 < price <= 16000000:
        return 'mid'
    else:
        return 'high'

# Apply categorization
new_data['category'] = new_data['price'].apply(categorize_price)

# Function to make prediction for next month
def predict_next_month_sales(data, model, window_size=12):
    data['date'] = pd.to_datetime(data['date'])
    monthly_sales = data.resample('M', on='date').sum()

    # Extract sales data for the previous 11 months
    previous_11_months_sales = monthly_sales['sales'].iloc[-window_size-1:-1].values
    latest_month_sales = monthly_sales['sales'].iloc[-1]

    # Prepare input data for prediction
    input_data = np.array(previous_11_months_sales).reshape((1, window_size, 1))

    # Scale the input data
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler.fit(input_data.reshape(-1, 1))
    input_data_scaled = scaler.transform(input_data.reshape(-1, 1)).reshape((1, window_size, 1))

    # Make prediction
    predicted_sales_scaled = model.predict(input_data_scaled)

    # Inverse transform to get actual sales value
    predicted_sales_actual = scaler.inverse_transform(predicted_sales_scaled.reshape(-1, 1))

    return predicted_sales_actual[0][0]

# Filter data for each category
new_data_low = new_data[new_data['category'] == 'low'].copy()
new_data_mid = new_data[new_data['category'] == 'mid'].copy()
new_data_high = new_data[new_data['category'] == 'high'].copy()

# Predict sales for next month for each category
predicted_sales_low = predict_next_month_sales(new_data_low, loaded_model_low)
predicted_sales_mid = predict_next_month_sales(new_data_mid, loaded_model_mid)
predicted_sales_high = predict_next_month_sales(new_data_high, loaded_model_high)

# Output predictions
print("Prediksi penjualan untuk bulan berikutnya (Low Category):", predicted_sales_low, "units")
print("Prediksi penjualan untuk bulan berikutnya (Mid Category):", predicted_sales_mid, "units")
print("Prediksi penjualan untuk bulan berikutnya (High Category):", predicted_sales_high, "units")

# Prepare data for plotting
def prepare_plot_data(data, predicted_sales, category_name):
    data['date'] = pd.to_datetime(data['date'])
    monthly_sales = data.resample('M', on='date').sum()
    last_date = monthly_sales.index[-1]
    next_month_date = last_date + pd.DateOffset(months=1)

    # Create a DataFrame for plotting
    plot_data = monthly_sales['sales'].copy()
    plot_data[next_month_date] = predicted_sales

    return plot_data

# Prepare data for each category
plot_data_low = prepare_plot_data(new_data_low, predicted_sales_low, 'low')
plot_data_mid = prepare_plot_data(new_data_mid, predicted_sales_mid, 'mid')
plot_data_high = prepare_plot_data(new_data_high, predicted_sales_high, 'high')

# Plot the data
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 8))

# Plot for low category
plt.subplot(3, 1, 1)
plot_data_low.plot(marker='o', color='blue', title=f'Sales Prediction for Low Category: {predicted_sales_low:.2f} units')
plt.axvline(plot_data_low.index[-2], color='red', linestyle='--', label='Prediction Start')
plt.legend()
plt.xlabel('Date')
plt.ylabel('Sales')

# Plot for mid category
plt.subplot(3, 1, 2)
plot_data_mid.plot(marker='o', color='green', title=f'Sales Prediction for Mid Category: {predicted_sales_mid:.2f} units')
plt.axvline(plot_data_mid.index[-2], color='red', linestyle='--', label='Prediction Start')
plt.legend()
plt.xlabel('Date')
plt.ylabel('Sales')

# Plot for high category
plt.subplot(3, 1, 3)
plot_data_high.plot(marker='o', color='orange', title=f'Sales Prediction for High Category: {predicted_sales_high:.2f} units')
plt.axvline(plot_data_high.index[-2], color='red', linestyle='--', label='Prediction Start')
plt.legend()
plt.xlabel('Date')
plt.ylabel('Sales')

plt.tight_layout()
plt.show()
# Out:
# 1/1 [==============================] - 1s 746ms/step
# 1/1 [==============================] - 1s 725ms/step
# 1/1 [==============================] - 1s 765ms/step
# Prediksi penjualan untuk bulan berikutnya (Low Category): 16416.941 units
# Prediksi penjualan untuk bulan berikutnya (Mid Category): 24768.729 units
# Prediksi penjualan untuk bulan berikutnya (High Category): 20122.56 units
