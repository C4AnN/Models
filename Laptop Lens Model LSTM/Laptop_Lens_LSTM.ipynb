# %% [markdown]
# ## **MODEL LSTM**

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from tensorflow.keras.models import Sequential, model_from_json
from tensorflow.keras.layers import Dense, LSTM, Dropout, Input
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam

# Load data
url = 'https://raw.githubusercontent.com/C4AnN/Models/main/Aku%20Yakin%20Ini%20Terakhir/Dataset/file_gabungan2.csv'
store_sales = pd.read_csv(url)
store_sales['date'] = pd.to_datetime(store_sales['date'])

# Categorize data based on price
def categorize_price(price):
    if price <= 8000000:
        return 'low'
    elif 8000000 < price <= 16000000:
        return 'mid'
    else:
        return 'high'

store_sales['category'] = store_sales['price'].apply(categorize_price)

# Drop unnecessary columns
store_sales = store_sales.drop(['name', 'price'], axis=1)

# Function to process and predict for each category
def process_category(data, category_name, window_size):
    data = data[data['category'] == category_name].drop(['category'], axis=1)
    data['date'] = data['date'].dt.to_period("M")
    monthly_sales = data.groupby('date').sum().reset_index()
    monthly_sales['date'] = monthly_sales['date'].dt.to_timestamp()

    # Calculate sales difference
    monthly_sales['sales_diff'] = monthly_sales['sales'].diff()
    monthly_sales = monthly_sales.dropna()

    # Prepare supervised data with a window size
    supervised_data = monthly_sales.drop(['date', 'sales'], axis=1)
    for i in range(1, window_size + 1):
        col_name = 'month_' + str(i)
        supervised_data[col_name] = supervised_data['sales_diff'].shift(i)
    supervised_data = supervised_data.dropna().reset_index(drop=True)

    # Split into train and test data
    train_data = supervised_data[:-24]
    test_data = supervised_data[-12:]

    # Scale the data
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler.fit(train_data)
    train_data_scaled = scaler.transform(train_data)
    test_data_scaled = scaler.transform(test_data)

    X_train, y_train = train_data_scaled[:, 1:], train_data_scaled[:, 0]
    X_test, y_test = test_data_scaled[:, 1:], test_data_scaled[:, 0]

    # Reshape input to be 3D [samples, timesteps, features]
    X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
    X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

    # Build LSTM model
    model = Sequential()
    model.add(Input(shape=(X_train.shape[1], 1)))
    model.add(LSTM(200, activation='tanh', return_sequences=True))
    model.add(Dropout(0.3))
    model.add(LSTM(100, activation='tanh'))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mse')

    # Setup callbacks
    early_stop = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

    # Train the model
    history = model.fit(X_train, y_train, epochs=100, batch_size=16, validation_data=(X_test, y_test), callbacks=[early_stop], verbose=1)

    # Save the model architecture to JSON and weights to HDF5
    model_json = model.to_json()
    with open(f'best_model_{category_name}.json', 'w') as json_file:
        json_file.write(model_json)
    model.save_weights(f'best_model_weights_{category_name}.h5')

    # Make predictions
    lstm_pre = model.predict(X_test)

    # Prepare prediction DataFrame
    sales_dates = monthly_sales['date'][-12:].reset_index(drop=True)
    predict_df = pd.DataFrame(sales_dates, columns=['date'])

    act_sales = monthly_sales['sales'][-13:].to_list()
    lstm_pre = lstm_pre.reshape(-1, 1)
    lstm_pre_test_set = np.concatenate([lstm_pre, X_test.reshape((X_test.shape[0], X_test.shape[1]))], axis=1)
    lstm_pre_test_set = scaler.inverse_transform(lstm_pre_test_set)

    result_list = []
    for index in range(0, len(lstm_pre_test_set)):
        result_list.append(lstm_pre_test_set[index][0] + act_sales[index + 1])
    lstm_pre_series = pd.Series(result_list, name="LSTM Prediction")
    predict_df = predict_df.merge(lstm_pre_series, left_index=True, right_index=True)

    # Predict next 12 months
    future_predictions = []
    last_data = supervised_data[-1:].copy()

    for _ in range(12):
        last_data_scaled = scaler.transform(last_data)
        X_last = last_data_scaled[:, 1:].reshape((1, X_train.shape[1], 1))
        next_pred = model.predict(X_last)[0, 0]

        future_pred = np.concatenate([[next_pred], last_data_scaled[0, 1:]])
        future_pred = scaler.inverse_transform([future_pred])

        future_predictions.append(future_pred[0][0] + monthly_sales['sales'].iloc[-1])

        new_row = np.append([next_pred], last_data.values[0, :-1])
        last_data = pd.DataFrame([new_row], columns=supervised_data.columns)

    future_dates = pd.date_range(start=monthly_sales['date'].iloc[-1] + pd.DateOffset(months=1), periods=12, freq='M')
    future_df = pd.DataFrame({'date': future_dates, 'LSTM Prediction': future_predictions})

    return monthly_sales, predict_df, future_df, model

# Process and predict for each category using window size of 12 months
window_size = 12  # Increase window size to consider more historical data

low_sales, low_predict_df, low_future_df, low_model = process_category(store_sales, 'low', window_size)
mid_sales, mid_predict_df, mid_future_df, mid_model = process_category(store_sales, 'mid', window_size)
high_sales, high_predict_df, high_future_df, high_model = process_category(store_sales, 'high', window_size)

# Save all models' architectures and weights
models = {'low': low_model, 'mid': mid_model, 'high': high_model}
for category, model in models.items():
    model_json = model.to_json()
    with open(f'best_model_{category}.json', 'w') as json_file:
        json_file.write(model_json)
    model.save_weights(f'best_model_weights_{category}.h5')
# Out:
# Epoch 1/100
# 2/2 [==============================] - 6s 1s/step - loss: 0.3075 - val_loss: 0.6111
# Epoch 2/100
# 2/2 [==============================] - 0s 121ms/step - loss: 0.2911 - val_loss: 0.6004
# Epoch 3/100
# 2/2 [==============================] - 0s 122ms/step - loss: 0.2801 - val_loss: 0.5984
# Epoch 4/100
# 2/2 [==============================] - 0s 119ms/step - loss: 0.2700 - val_loss: 0.5976
# Epoch 5/100
# 2/2 [==============================] - 0s 111ms/step - loss: 0.2618 - val_loss: 0.6014
# Epoch 6/100
# 2/2 [==============================] - 0s 124ms/step - loss: 0.2538 - val_loss: 0.6019
# Epoch 7/100
# 2/2 [==============================] - 0s 124ms/step - loss: 0.2589 - val_loss: 0.5759
# Epoch 8/100
# 2/2 [==============================] - 0s 120ms/step - loss: 0.2475 - val_loss: 0.5367
# Epoch 9/100
# 2/2 [==============================] - 0s 112ms/step - loss: 0.2361 - val_loss: 0.5137
# Epoch 10/100
# 2/2 [==============================] - 0s 67ms/step - loss: 0.2346 - val_loss: 0.5049
# Epoch 11/100
# 2/2 [==============================] - 0s 66ms/step - loss: 0.2394 - val_loss: 0.4992
# Epoch 12/100
# 2/2 [==============================] - 0s 73ms/step - loss: 0.2502 - val_loss: 0.4800
# Epoch 13/100
# 2/2 [==============================] - 0s 66ms/step - loss: 0.2536 - val_loss: 0.4554
# Epoch 14/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.2383 - val_loss: 0.4282
# Epoch 15/100
# 2/2 [==============================] - 0s 75ms/step - loss: 0.2329 - val_loss: 0.4031
# Epoch 16/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.2313 - val_loss: 0.3915
# Epoch 17/100
# 2/2 [==============================] - 0s 66ms/step - loss: 0.2229 - val_loss: 0.3923
# Epoch 18/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.2219 - val_loss: 0.4114
# Epoch 19/100
# 2/2 [==============================] - 0s 65ms/step - loss: 0.2248 - val_loss: 0.4275
# Epoch 20/100
# 2/2 [==============================] - 0s 72ms/step - loss: 0.2274 - val_loss: 0.4317
# Epoch 21/100
# 2/2 [==============================] - 0s 65ms/step - loss: 0.2252 - val_loss: 0.4062
# Epoch 22/100
# 2/2 [==============================] - 0s 65ms/step - loss: 0.2190 - val_loss: 0.3861
# Epoch 23/100
# 2/2 [==============================] - 0s 65ms/step - loss: 0.2167 - val_loss: 0.3841
# Epoch 24/100
# 2/2 [==============================] - 0s 66ms/step - loss: 0.2235 - val_loss: 0.3923
# Epoch 25/100
# 2/2 [==============================] - 0s 65ms/step - loss: 0.2172 - val_loss: 0.4014
# Epoch 26/100
# 2/2 [==============================] - 0s 65ms/step - loss: 0.2154 - val_loss: 0.4112
# Epoch 27/100
# 2/2 [==============================] - 0s 65ms/step - loss: 0.2130 - val_loss: 0.4218
# Epoch 28/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.2094 - val_loss: 0.4350
# Epoch 29/100
# 2/2 [==============================] - 0s 60ms/step - loss: 0.2118 - val_loss: 0.4497
# Epoch 30/100
# 2/2 [==============================] - 0s 80ms/step - loss: 0.2069 - val_loss: 0.4547
# Epoch 31/100
# 2/2 [==============================] - 0s 70ms/step - loss: 0.2136 - val_loss: 0.4388
# Epoch 32/100
# 2/2 [==============================] - 0s 64ms/step - loss: 0.2103 - val_loss: 0.4185
# Epoch 33/100
# 2/2 [==============================] - 0s 65ms/step - loss: 0.2117 - val_loss: 0.4063
# Epoch 34/100
# 2/2 [==============================] - 0s 73ms/step - loss: 0.2051 - val_loss: 0.3966
# Epoch 35/100
# 2/2 [==============================] - 0s 76ms/step - loss: 0.2060 - val_loss: 0.3900
# Epoch 36/100
# 2/2 [==============================] - 0s 72ms/step - loss: 0.2045 - val_loss: 0.3830
# Epoch 37/100
# 2/2 [==============================] - 0s 73ms/step - loss: 0.2041 - val_loss: 0.3818
# Epoch 38/100
# 2/2 [==============================] - 0s 70ms/step - loss: 0.1994 - val_loss: 0.3842
# Epoch 39/100
# 2/2 [==============================] - 0s 69ms/step - loss: 0.1990 - val_loss: 0.3877
# Epoch 40/100
# 2/2 [==============================] - 0s 76ms/step - loss: 0.2007 - val_loss: 0.3892
# Epoch 41/100
# 2/2 [==============================] - 0s 69ms/step - loss: 0.1999 - val_loss: 0.3843
# Epoch 42/100
# 2/2 [==============================] - 0s 73ms/step - loss: 0.1914 - val_loss: 0.3733
# Epoch 43/100
# 2/2 [==============================] - 0s 72ms/step - loss: 0.1976 - val_loss: 0.3708
# Epoch 44/100
# 2/2 [==============================] - 0s 70ms/step - loss: 0.1952 - val_loss: 0.3725
# Epoch 45/100
# 2/2 [==============================] - 0s 66ms/step - loss: 0.1945 - val_loss: 0.3761
# Epoch 46/100
# 2/2 [==============================] - 0s 64ms/step - loss: 0.1888 - val_loss: 0.3787
# Epoch 47/100
# 2/2 [==============================] - 0s 68ms/step - loss: 0.1853 - val_loss: 0.3756
# Epoch 48/100
# 2/2 [==============================] - 0s 80ms/step - loss: 0.1830 - val_loss: 0.3661
# Epoch 49/100
# 2/2 [==============================] - 0s 73ms/step - loss: 0.1794 - val_loss: 0.3518
# Epoch 50/100
# 2/2 [==============================] - 0s 68ms/step - loss: 0.1792 - val_loss: 0.3345
# Epoch 51/100
# 2/2 [==============================] - 0s 78ms/step - loss: 0.1847 - val_loss: 0.3224
# Epoch 52/100
# 2/2 [==============================] - 0s 84ms/step - loss: 0.1830 - val_loss: 0.3200
# Epoch 53/100
# 2/2 [==============================] - 0s 71ms/step - loss: 0.1783 - val_loss: 0.3237
# Epoch 54/100
# 2/2 [==============================] - 0s 69ms/step - loss: 0.1805 - val_loss: 0.3192
# Epoch 55/100
# 2/2 [==============================] - 0s 69ms/step - loss: 0.1712 - val_loss: 0.3161
# Epoch 56/100
# 2/2 [==============================] - 0s 64ms/step - loss: 0.1732 - val_loss: 0.3274
# Epoch 57/100
# 2/2 [==============================] - 0s 76ms/step - loss: 0.1639 - val_loss: 0.3538
# Epoch 58/100
# 2/2 [==============================] - 0s 66ms/step - loss: 0.1633 - val_loss: 0.3771
# Epoch 59/100
# 2/2 [==============================] - 0s 74ms/step - loss: 0.1727 - val_loss: 0.3666
# Epoch 60/100
# 2/2 [==============================] - 0s 69ms/step - loss: 0.1729 - val_loss: 0.3634
# Epoch 61/100
# 2/2 [==============================] - 0s 73ms/step - loss: 0.1603 - val_loss: 0.3686
# Epoch 62/100
# 2/2 [==============================] - 0s 75ms/step - loss: 0.1517 - val_loss: 0.3928
# Epoch 63/100
# 2/2 [==============================] - 0s 68ms/step - loss: 0.1612 - val_loss: 0.3759
# Epoch 64/100
# 2/2 [==============================] - 0s 64ms/step - loss: 0.1620 - val_loss: 0.3484
# Epoch 65/100
# 2/2 [==============================] - 0s 74ms/step - loss: 0.1583 - val_loss: 0.3284
# Epoch 66/100
# 2/2 [==============================] - 0s 65ms/step - loss: 0.1477 - val_loss: 0.3205
# Epoch 67/100
# 2/2 [==============================] - 0s 68ms/step - loss: 0.1531 - val_loss: 0.3437
# Epoch 68/100
# 2/2 [==============================] - 0s 67ms/step - loss: 0.1432 - val_loss: 0.3847
# Epoch 69/100
# 2/2 [==============================] - 0s 70ms/step - loss: 0.1465 - val_loss: 0.4374
# Epoch 70/100
# 2/2 [==============================] - 0s 69ms/step - loss: 0.1566 - val_loss: 0.4115
# Epoch 71/100
# 2/2 [==============================] - 0s 73ms/step - loss: 0.1352 - val_loss: 0.3841
# Epoch 72/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.1491 - val_loss: 0.3776
# Epoch 73/100
# 2/2 [==============================] - 0s 61ms/step - loss: 0.1472 - val_loss: 0.3811
# Epoch 74/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.1353 - val_loss: 0.3848
# Epoch 75/100
# 2/2 [==============================] - 0s 80ms/step - loss: 0.1498 - val_loss: 0.3970
# 1/1 [==============================] - 1s 834ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# Epoch 1/100
# 2/2 [==============================] - 6s 1s/step - loss: 0.2214 - val_loss: 0.1113
# Epoch 2/100
# 2/2 [==============================] - 0s 70ms/step - loss: 0.1849 - val_loss: 0.0992
# Epoch 3/100
# 2/2 [==============================] - 0s 86ms/step - loss: 0.1591 - val_loss: 0.1116
# Epoch 4/100
# 2/2 [==============================] - 0s 71ms/step - loss: 0.1589 - val_loss: 0.0999
# Epoch 5/100
# 2/2 [==============================] - 0s 74ms/step - loss: 0.1348 - val_loss: 0.0711
# Epoch 6/100
# 2/2 [==============================] - 0s 79ms/step - loss: 0.1154 - val_loss: 0.0663
# Epoch 7/100
# 2/2 [==============================] - 0s 62ms/step - loss: 0.1204 - val_loss: 0.0664
# Epoch 8/100
# 2/2 [==============================] - 0s 75ms/step - loss: 0.1136 - val_loss: 0.0503
# Epoch 9/100
# 2/2 [==============================] - 0s 71ms/step - loss: 0.0977 - val_loss: 0.0424
# Epoch 10/100
# 2/2 [==============================] - 0s 75ms/step - loss: 0.0985 - val_loss: 0.0611
# Epoch 11/100
# 2/2 [==============================] - 0s 79ms/step - loss: 0.1113 - val_loss: 0.0525
# Epoch 12/100
# 2/2 [==============================] - 0s 86ms/step - loss: 0.0999 - val_loss: 0.0427
# Epoch 13/100
# 2/2 [==============================] - 0s 68ms/step - loss: 0.0921 - val_loss: 0.0497
# Epoch 14/100
# 2/2 [==============================] - 0s 67ms/step - loss: 0.0977 - val_loss: 0.0576
# Epoch 15/100
# 2/2 [==============================] - 0s 64ms/step - loss: 0.1016 - val_loss: 0.0594
# Epoch 16/100
# 2/2 [==============================] - 0s 81ms/step - loss: 0.1039 - val_loss: 0.0566
# Epoch 17/100
# 2/2 [==============================] - 0s 76ms/step - loss: 0.0937 - val_loss: 0.0543
# Epoch 18/100
# 2/2 [==============================] - 0s 67ms/step - loss: 0.0910 - val_loss: 0.0555
# Epoch 19/100
# 2/2 [==============================] - 0s 64ms/step - loss: 0.0889 - val_loss: 0.0582
# Epoch 20/100
# 2/2 [==============================] - 0s 69ms/step - loss: 0.0945 - val_loss: 0.0525
# Epoch 21/100
# 2/2 [==============================] - 0s 83ms/step - loss: 0.0914 - val_loss: 0.0388
# Epoch 22/100
# 2/2 [==============================] - 0s 67ms/step - loss: 0.0870 - val_loss: 0.0363
# Epoch 23/100
# 2/2 [==============================] - 0s 71ms/step - loss: 0.0911 - val_loss: 0.0355
# Epoch 24/100
# 2/2 [==============================] - 0s 66ms/step - loss: 0.0886 - val_loss: 0.0360
# Epoch 25/100
# 2/2 [==============================] - 0s 67ms/step - loss: 0.0871 - val_loss: 0.0485
# Epoch 26/100
# 2/2 [==============================] - 0s 77ms/step - loss: 0.0824 - val_loss: 0.0675
# Epoch 27/100
# 2/2 [==============================] - 0s 66ms/step - loss: 0.0858 - val_loss: 0.0716
# Epoch 28/100
# 2/2 [==============================] - 0s 65ms/step - loss: 0.0814 - val_loss: 0.0576
# Epoch 29/100
# 2/2 [==============================] - 0s 73ms/step - loss: 0.0799 - val_loss: 0.0521
# Epoch 30/100
# 2/2 [==============================] - 0s 81ms/step - loss: 0.0804 - val_loss: 0.0483
# Epoch 31/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0834 - val_loss: 0.0513
# Epoch 32/100
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0770 - val_loss: 0.0722
# Epoch 33/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0860 - val_loss: 0.0716
# Epoch 34/100
# 2/2 [==============================] - 0s 61ms/step - loss: 0.0814 - val_loss: 0.0554
# Epoch 35/100
# 2/2 [==============================] - 0s 65ms/step - loss: 0.0820 - val_loss: 0.0609
# Epoch 36/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0785 - val_loss: 0.0644
# Epoch 37/100
# 2/2 [==============================] - 0s 64ms/step - loss: 0.0763 - val_loss: 0.0729
# Epoch 38/100
# 2/2 [==============================] - 0s 66ms/step - loss: 0.0795 - val_loss: 0.0773
# Epoch 39/100
# 2/2 [==============================] - 0s 76ms/step - loss: 0.0744 - val_loss: 0.0573
# Epoch 40/100
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0708 - val_loss: 0.0481
# Epoch 41/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0712 - val_loss: 0.0476
# Epoch 42/100
# 2/2 [==============================] - 0s 65ms/step - loss: 0.0659 - val_loss: 0.0477
# Epoch 43/100
# 2/2 [==============================] - 0s 67ms/step - loss: 0.0723 - val_loss: 0.0510
# 1/1 [==============================] - 1s 836ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# Epoch 1/100
# 2/2 [==============================] - 6s 1s/step - loss: 0.2503 - val_loss: 0.4871
# Epoch 2/100
# 2/2 [==============================] - 0s 67ms/step - loss: 0.2296 - val_loss: 0.4559
# Epoch 3/100
# 2/2 [==============================] - 0s 78ms/step - loss: 0.2154 - val_loss: 0.4209
# Epoch 4/100
# 2/2 [==============================] - 0s 66ms/step - loss: 0.1972 - val_loss: 0.3962
# Epoch 5/100
# 2/2 [==============================] - 0s 66ms/step - loss: 0.1852 - val_loss: 0.3861
# Epoch 6/100
# 2/2 [==============================] - 0s 62ms/step - loss: 0.1718 - val_loss: 0.3868
# Epoch 7/100
# 2/2 [==============================] - 0s 61ms/step - loss: 0.1550 - val_loss: 0.4348
# Epoch 8/100
# 2/2 [==============================] - 0s 68ms/step - loss: 0.1553 - val_loss: 0.4944
# Epoch 9/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.1703 - val_loss: 0.4894
# Epoch 10/100
# 2/2 [==============================] - 0s 81ms/step - loss: 0.1729 - val_loss: 0.4501
# Epoch 11/100
# 2/2 [==============================] - 0s 65ms/step - loss: 0.1675 - val_loss: 0.4227
# Epoch 12/100
# 2/2 [==============================] - 0s 61ms/step - loss: 0.1590 - val_loss: 0.4117
# Epoch 13/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.1578 - val_loss: 0.4075
# Epoch 14/100
# 2/2 [==============================] - 0s 62ms/step - loss: 0.1538 - val_loss: 0.4236
# Epoch 15/100
# 2/2 [==============================] - 0s 65ms/step - loss: 0.1590 - val_loss: 0.4249
# Epoch 16/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.1534 - val_loss: 0.4107
# Epoch 17/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.1512 - val_loss: 0.4064
# Epoch 18/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.1503 - val_loss: 0.4137
# Epoch 19/100
# 2/2 [==============================] - 0s 64ms/step - loss: 0.1449 - val_loss: 0.4185
# Epoch 20/100
# 2/2 [==============================] - 0s 68ms/step - loss: 0.1474 - val_loss: 0.4212
# Epoch 21/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.1461 - val_loss: 0.4250
# Epoch 22/100
# 2/2 [==============================] - 0s 61ms/step - loss: 0.1488 - val_loss: 0.4366
# Epoch 23/100
# 2/2 [==============================] - 0s 61ms/step - loss: 0.1472 - val_loss: 0.4407
# Epoch 24/100
# 2/2 [==============================] - 0s 67ms/step - loss: 0.1403 - val_loss: 0.4407
# Epoch 25/100
# 2/2 [==============================] - 0s 69ms/step - loss: 0.1426 - val_loss: 0.4502
# 1/1 [==============================] - 1s 962ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step

# %% [markdown]
# ## **VISUALISASI DATA**

# %%
# Plot predictions by category
plt.figure(figsize=(15, 15))

# Low category plot
plt.subplot(3, 1, 1)
plt.plot(low_sales['date'], low_sales['sales'], label='Actual Sales')
plt.plot(low_predict_df['date'], low_predict_df['LSTM Prediction'], label='Predicted Sales (Low)')
plt.title("Customer Sales Forecast - Low Category (Window Size: 12)")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.legend()

# Mid category plot
plt.subplot(3, 1, 2)
plt.plot(mid_sales['date'], mid_sales['sales'], label='Actual Sales')
plt.plot(mid_predict_df['date'], mid_predict_df['LSTM Prediction'], label='Predicted Sales (Mid)')
plt.title("Customer Sales Forecast - Mid Category (Window Size: 12)")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.legend()

# High category plot
plt.subplot(3, 1, 3)
plt.plot(high_sales['date'], high_sales['sales'], label='Actual Sales')
plt.plot(high_predict_df['date'], high_predict_df['LSTM Prediction'], label='Predicted Sales (High)')
plt.title("Customer Sales Forecast - High Category (Window Size: 12)")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## **LOAD DATA JSON**

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import model_from_json

# Load models from JSON and weights from HDF5
def load_model_from_json(json_path, weights_path):
    with open(json_path, 'r') as json_file:
        model_json = json_file.read()
    model = model_from_json(model_json)
    model.load_weights(weights_path)
    return model

loaded_model_low = load_model_from_json('best_model_low.json', 'best_model_weights_low.h5')
loaded_model_mid = load_model_from_json('best_model_mid.json', 'best_model_weights_mid.h5')
loaded_model_high = load_model_from_json('best_model_high.json', 'best_model_weights_high.h5')

# Load new data from CSV file
new_data_url = 'https://raw.githubusercontent.com/C4AnN/Models/main/Aku%20Yakin%20Ini%20Terakhir/Dataset/file_gabungan2.csv'
new_data = pd.read_csv(new_data_url)

# Ensure 'date' column is in datetime format
new_data['date'] = pd.to_datetime(new_data['date'])

# Function to categorize price
def categorize_price(price):
    if price <= 8000000:
        return 'low'
    elif 8000000 < price <= 16000000:
        return 'mid'
    else:
        return 'high'

# Apply categorization
new_data['category'] = new_data['price'].apply(categorize_price)

# Function to make prediction for next month
def predict_next_month_sales(data, model, window_size=12):
    data['date'] = pd.to_datetime(data['date'])
    monthly_sales = data.resample('M', on='date').sum()

    # Extract sales data for the previous 11 months
    previous_11_months_sales = monthly_sales['sales'].iloc[-window_size-1:-1].values
    latest_month_sales = monthly_sales['sales'].iloc[-1]

    # Prepare input data for prediction
    input_data = np.array(previous_11_months_sales).reshape((1, window_size, 1))

    # Scale the input data
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler.fit(input_data.reshape(-1, 1))
    input_data_scaled = scaler.transform(input_data.reshape(-1, 1)).reshape((1, window_size, 1))

    # Make prediction
    predicted_sales_scaled = model.predict(input_data_scaled)

    # Inverse transform to get actual sales value
    predicted_sales_actual = scaler.inverse_transform(predicted_sales_scaled.reshape(-1, 1))

    return predicted_sales_actual[0][0]

# Filter data for each category
new_data_low = new_data[new_data['category'] == 'low'].copy()
new_data_mid = new_data[new_data['category'] == 'mid'].copy()
new_data_high = new_data[new_data['category'] == 'high'].copy()

# Predict sales for next month for each category
predicted_sales_low = predict_next_month_sales(new_data_low, loaded_model_low)
predicted_sales_mid = predict_next_month_sales(new_data_mid, loaded_model_mid)
predicted_sales_high = predict_next_month_sales(new_data_high, loaded_model_high)

# Output predictions
print("Prediksi penjualan untuk bulan berikutnya (Low Category):", predicted_sales_low, "units")
print("Prediksi penjualan untuk bulan berikutnya (Mid Category):", predicted_sales_mid, "units")
print("Prediksi penjualan untuk bulan berikutnya (High Category):", predicted_sales_high, "units")

# Prepare data for plotting
def prepare_plot_data(data, predicted_sales, category_name):
    data['date'] = pd.to_datetime(data['date'])
    monthly_sales = data.resample('M', on='date').sum()
    last_date = monthly_sales.index[-1]
    next_month_date = last_date + pd.DateOffset(months=1)

    # Create a DataFrame for plotting
    plot_data = monthly_sales['sales'].copy()
    plot_data[next_month_date] = predicted_sales

    return plot_data

# Prepare data for each category
plot_data_low = prepare_plot_data(new_data_low, predicted_sales_low, 'low')
plot_data_mid = prepare_plot_data(new_data_mid, predicted_sales_mid, 'mid')
plot_data_high = prepare_plot_data(new_data_high, predicted_sales_high, 'high')

# Plot the data
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 8))

# Plot for low category
plt.subplot(3, 1, 1)
plot_data_low.plot(marker='o', color='blue', title=f'Sales Prediction for Low Category: {predicted_sales_low:.2f} units')
plt.axvline(plot_data_low.index[-2], color='red', linestyle='--', label='Prediction Start')
plt.legend()
plt.xlabel('Date')
plt.ylabel('Sales')

# Plot for mid category
plt.subplot(3, 1, 2)
plot_data_mid.plot(marker='o', color='green', title=f'Sales Prediction for Mid Category: {predicted_sales_mid:.2f} units')
plt.axvline(plot_data_mid.index[-2], color='red', linestyle='--', label='Prediction Start')
plt.legend()
plt.xlabel('Date')
plt.ylabel('Sales')

# Plot for high category
plt.subplot(3, 1, 3)
plot_data_high.plot(marker='o', color='orange', title=f'Sales Prediction for High Category: {predicted_sales_high:.2f} units')
plt.axvline(plot_data_high.index[-2], color='red', linestyle='--', label='Prediction Start')
plt.legend()
plt.xlabel('Date')
plt.ylabel('Sales')

plt.tight_layout()
plt.show()
# Out:
# 1/1 [==============================] - 1s 871ms/step
# 1/1 [==============================] - 1s 867ms/step
# 1/1 [==============================] - 1s 838ms/step
# Prediksi penjualan untuk bulan berikutnya (Low Category): 16211.376 units
# Prediksi penjualan untuk bulan berikutnya (Mid Category): 24142.732 units
# Prediksi penjualan untuk bulan berikutnya (High Category): 18968.707 units
