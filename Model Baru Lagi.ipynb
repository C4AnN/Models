# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, LSTM, Dropout, Input
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import Adam

# Load data
url = 'https://raw.githubusercontent.com/C4AnN/Models/data/dataset_processing%20(Model%20LR%202)/file_gabungan2.csv'
store_sales = pd.read_csv(url)

store_sales['date'] = pd.to_datetime(store_sales['date'])

# Categorize data based on price
def categorize_price(price):
    if price <= 8000000:
        return 'low'
    elif 8000000 < price <= 16000000:
        return 'mid'
    else:
        return 'high'

store_sales['category'] = store_sales['price'].apply(categorize_price)

# Drop unnecessary columns
store_sales = store_sales.drop(['name', 'price'], axis=1)

# Function to process and predict for each category
def process_category(data, category_name, window_size):
    data = data[data['category'] == category_name].drop(['category'], axis=1)
    data['date'] = data['date'].dt.to_period("M")
    monthly_sales = data.groupby('date').sum().reset_index()
    monthly_sales['date'] = monthly_sales['date'].dt.to_timestamp()

    # Calculate sales difference
    monthly_sales['sales_diff'] = monthly_sales['sales'].diff()
    monthly_sales = monthly_sales.dropna()

    # Prepare supervised data with a window size
    supervised_data = monthly_sales.drop(['date', 'sales'], axis=1)
    for i in range(1, window_size + 1):
        col_name = 'month_' + str(i)
        supervised_data[col_name] = supervised_data['sales_diff'].shift(i)
    supervised_data = supervised_data.dropna().reset_index(drop=True)

    # Split into train and test data
    train_data = supervised_data[:-12]
    test_data = supervised_data[-12:]

    # Scale the data
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler.fit(train_data)
    train_data_scaled = scaler.transform(train_data)
    test_data_scaled = scaler.transform(test_data)

    X_train, y_train = train_data_scaled[:, 1:], train_data_scaled[:, 0]
    X_test, y_test = test_data_scaled[:, 1:], test_data_scaled[:, 0]

    # Reshape input to be 3D [samples, timesteps, features]
    X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
    X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

    # Build LSTM model
    model = Sequential()
    model.add(Input(shape=(X_train.shape[1], 1)))
    model.add(LSTM(100, activation='swish', return_sequences=True))
    model.add(Dropout(0.5))
    model.add(LSTM(100, activation='swish'))
    model.add(Dense(1))
    optimizer = Adam(learning_rate=0.001)
    model.compile(optimizer=optimizer, loss='mse')

    # Setup callbacks
    early_stop = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
    model_checkpoint = ModelCheckpoint(f'best_model_{category_name}.keras', monitor='val_loss', save_best_only=True)

    # Train the model
    history = model.fit(X_train, y_train, epochs=100, batch_size=16, validation_data=(X_test, y_test), callbacks=[early_stop, model_checkpoint], verbose=1)

    # Save the model
    model.save(f'best_model_{category_name}.keras')

    # Make predictions
    lstm_pre = model.predict(X_test)

    # Prepare prediction DataFrame
    sales_dates = monthly_sales['date'][-12:].reset_index(drop=True)
    predict_df = pd.DataFrame(sales_dates, columns=['date'])

    act_sales = monthly_sales['sales'][-13:].to_list()
    lstm_pre = lstm_pre.reshape(-1, 1)
    lstm_pre_test_set = np.concatenate([lstm_pre, X_test.reshape((X_test.shape[0], X_test.shape[1]))], axis=1)
    lstm_pre_test_set = scaler.inverse_transform(lstm_pre_test_set)

    result_list = []
    for index in range(0, len(lstm_pre_test_set)):
        result_list.append(lstm_pre_test_set[index][0] + act_sales[index + 1])
    lstm_pre_series = pd.Series(result_list, name="LSTM Prediction")
    predict_df = predict_df.merge(lstm_pre_series, left_index=True, right_index=True)

    # Predict next 12 months
    future_predictions = []
    last_data = supervised_data[-1:].copy()

    for _ in range(12):
        last_data_scaled = scaler.transform(last_data)
        X_last = last_data_scaled[:, 1:].reshape((1, X_train.shape[1], 1))
        next_pred = model.predict(X_last)[0, 0]

        future_pred = np.concatenate([[next_pred], last_data_scaled[0, 1:]])
        future_pred = scaler.inverse_transform([future_pred])

        future_predictions.append(future_pred[0][0] + monthly_sales['sales'].iloc[-1])

        new_row = np.append([next_pred], last_data.values[0, :-1])
        last_data = pd.DataFrame([new_row], columns=supervised_data.columns)

    future_dates = pd.date_range(start=monthly_sales['date'].iloc[-1] + pd.DateOffset(months=1), periods=12, freq='M')
    future_df = pd.DataFrame({'date': future_dates, 'LSTM Prediction': future_predictions})

    return monthly_sales, predict_df, future_df

# Process and predict for each category using window size of 12 months
window_size = 12  # Increase window size to consider more historical data

low_sales, low_predict_df, low_future_df = process_category(store_sales, 'low', window_size)
mid_sales, mid_predict_df, mid_future_df = process_category(store_sales, 'mid', window_size)
high_sales, high_predict_df, high_future_df = process_category(store_sales, 'high', window_size)

# Save all models into a single .h5 file
all_models = [f'best_model_{category}.keras' for category in ['low', 'mid', 'high']]
with open('all_models.h5', 'wb') as f_out:
    for model_path in all_models:
        with open(model_path, 'rb') as f_in:
            f_out.write(f_in.read())

# Plot predictions by category
plt.figure(figsize=(15, 15))

# Low category plot
plt.subplot(3, 1, 1)
plt.plot(low_sales['date'], low_sales['sales'], label='Actual Sales')
plt.plot(low_predict_df['date'], low_predict_df['LSTM Prediction'], label='Predicted Sales (Low)')
plt.plot(low_future_df['date'], low_future_df['LSTM Prediction'], label='Future Prediction (Low)', linestyle='--')
plt.title("Customer Sales Forecast - Low Category (Window Size: 12)")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.legend()

# Mid category plot
plt.subplot(3, 1, 2)
plt.plot(mid_sales['date'], mid_sales['sales'], label='Actual Sales')
plt.plot(mid_predict_df['date'], mid_predict_df['LSTM Prediction'], label='Predicted Sales (Mid)')
plt.plot(mid_future_df['date'], mid_future_df['LSTM Prediction'], label='Future Prediction (Mid)', linestyle='--')
plt.title("Customer Sales Forecast - Mid Category (Window Size: 12)")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.legend()

# High category plot
plt.subplot(3, 1, 3)
plt.plot(high_sales['date'], high_sales['sales'], label='Actual Sales')
plt.plot(high_predict_df['date'], high_predict_df['LSTM Prediction'], label='Predicted Sales (High)')
plt.plot(high_future_df['date'], high_future_df['LSTM Prediction'], label='Future Prediction (High)', linestyle='--')
plt.title("Customer Sales Forecast - High Category (Window Size: 12)")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 360ms/step - loss: 0.2758 - val_loss: 0.6301
# Epoch 2/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.2643 - val_loss: 0.6299
# Epoch 3/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.2685 - val_loss: 0.6299
# Epoch 4/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.2394 - val_loss: 0.6301
# Epoch 5/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.2655 - val_loss: 0.6306
# Epoch 6/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.2441 - val_loss: 0.6315
# Epoch 7/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.2736 - val_loss: 0.6331
# Epoch 8/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.2601 - val_loss: 0.6349
# Epoch 9/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.2427 - val_loss: 0.6379
# Epoch 10/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.2388 - val_loss: 0.6397
# Epoch 11/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.2553 - val_loss: 0.6392
# Epoch 12/100
# ...

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, LSTM, Dropout, Input
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import Adam

# Load data
url = 'https://raw.githubusercontent.com/C4AnN/Models/data/dataset_processing%20(Model%20LR%202)/file_gabungan2.csv'
store_sales = pd.read_csv(url)

store_sales['date'] = pd.to_datetime(store_sales['date'])

# Categorize data based on price
def categorize_price(price):
    if price <= 8000000:
        return 'low'
    elif 8000000 < price <= 16000000:
        return 'mid'
    else:
        return 'high'

store_sales['category'] = store_sales['price'].apply(categorize_price)

# Drop unnecessary columns
store_sales = store_sales.drop(['name', 'price'], axis=1)

# Function to process and predict for each category
def process_category(data, category_name, window_size):
    data = data[data['category'] == category_name].drop(['category'], axis=1)
    data['date'] = data['date'].dt.to_period("M")
    monthly_sales = data.groupby('date').sum().reset_index()
    monthly_sales['date'] = monthly_sales['date'].dt.to_timestamp()

    # Calculate sales difference
    monthly_sales['sales_diff'] = monthly_sales['sales'].diff()
    monthly_sales = monthly_sales.dropna()

    # Prepare supervised data with a window size
    supervised_data = monthly_sales.drop(['date', 'sales'], axis=1)
    for i in range(1, window_size + 1):
        col_name = 'month_' + str(i)
        supervised_data[col_name] = supervised_data['sales_diff'].shift(i)
    supervised_data = supervised_data.dropna().reset_index(drop=True)

    # Split into train and test data
    train_data = supervised_data[:-24]
    test_data = supervised_data[-12:]

    # Scale the data
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler.fit(train_data)
    train_data_scaled = scaler.transform(train_data)
    test_data_scaled = scaler.transform(test_data)

    X_train, y_train = train_data_scaled[:, 1:], train_data_scaled[:, 0]
    X_test, y_test = test_data_scaled[:, 1:], test_data_scaled[:, 0]

    # Reshape input to be 3D [samples, timesteps, features]
    X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
    X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

    # Build LSTM model
    model = Sequential()
    model.add(Input(shape=(X_train.shape[1], 1)))
    model.add(LSTM(200, activation='tanh', return_sequences=True))
    model.add(Dropout(0.3))
    model.add(LSTM(100, activation='tanh'))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mse')

    # Setup callbacks
    early_stop = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

    # Train the model
    history = model.fit(X_train, y_train, epochs=100, batch_size=16, validation_data=(X_test, y_test), callbacks=[early_stop], verbose=1)

    # Save the model
    model.save(f'best_model_{category_name}.keras')

    # Make predictions
    lstm_pre = model.predict(X_test)

    # Prepare prediction DataFrame
    sales_dates = monthly_sales['date'][-12:].reset_index(drop=True)
    predict_df = pd.DataFrame(sales_dates, columns=['date'])

    act_sales = monthly_sales['sales'][-13:].to_list()
    lstm_pre = lstm_pre.reshape(-1, 1)
    lstm_pre_test_set = np.concatenate([lstm_pre, X_test.reshape((X_test.shape[0], X_test.shape[1]))], axis=1)
    lstm_pre_test_set = scaler.inverse_transform(lstm_pre_test_set)

    result_list = []
    for index in range(0, len(lstm_pre_test_set)):
        result_list.append(lstm_pre_test_set[index][0] + act_sales[index + 1])
    lstm_pre_series = pd.Series(result_list, name="LSTM Prediction")
    predict_df = predict_df.merge(lstm_pre_series, left_index=True, right_index=True)

    # Predict next 12 months
    future_predictions = []
    last_data = supervised_data[-1:].copy()

    for _ in range(12):
        last_data_scaled = scaler.transform(last_data)
        X_last = last_data_scaled[:, 1:].reshape((1, X_train.shape[1], 1))
        next_pred = model.predict(X_last)[0, 0]

        future_pred = np.concatenate([[next_pred], last_data_scaled[0, 1:]])
        future_pred = scaler.inverse_transform([future_pred])

        future_predictions.append(future_pred[0][0] + monthly_sales['sales'].iloc[-1])

        new_row = np.append([next_pred], last_data.values[0, :-1])
        last_data = pd.DataFrame([new_row], columns=supervised_data.columns)

    future_dates = pd.date_range(start=monthly_sales['date'].iloc[-1] + pd.DateOffset(months=1), periods=12, freq='M')
    future_df = pd.DataFrame({'date': future_dates, 'LSTM Prediction': future_predictions})

    return monthly_sales, predict_df, future_df, model

# Process and predict for each category using window size of 12 months
window_size = 12  # Increase window size to consider more historical data

low_sales, low_predict_df, low_future_df, low_model = process_category(store_sales, 'low', window_size)
mid_sales, mid_predict_df, mid_future_df, mid_model = process_category(store_sales, 'mid', window_size)
high_sales, high_predict_df, high_future_df, high_model = process_category(store_sales, 'high', window_size)
# Out:
# Epoch 1/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 520ms/step - loss: 0.3136 - val_loss: 0.6118
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.2991 - val_loss: 0.5974
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.2812 - val_loss: 0.5838
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.2783 - val_loss: 0.5798
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.2685 - val_loss: 0.5868
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.2534 - val_loss: 0.5942
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.2524 - val_loss: 0.5771
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.2354 - val_loss: 0.5232
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.2426 - val_loss: 0.4818
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.2564 - val_loss: 0.4581
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.2271 - val_loss: 0.4418
# Epoch 12/100
# ...

# %%
# Save all models into a single .h5 file
all_models = [low_model, mid_model, high_model]
model_file_path = 'all_models.h5'
for model in all_models:
    if os.path.exists(model_file_path):
        os.remove(model_file_path)
    model.save(model_file_path)

# Plot predictions by category
plt.figure(figsize=(15, 15))

# Low category plot
plt.subplot(3, 1, 1)
plt.plot(low_sales['date'], low_sales['sales'], label='Actual Sales')
plt.plot(low_predict_df['date'], low_predict_df['LSTM Prediction'], label='Predicted Sales (Low)')
plt.plot(low_future_df['date'], low_future_df['LSTM Prediction'], label='Future Prediction (Low)', linestyle='--')
plt.title("Customer Sales Forecast - Low Category (Window Size: 12)")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.legend()

# Mid category plot
plt.subplot(3, 1, 2)
plt.plot(mid_sales['date'], mid_sales['sales'], label='Actual Sales')
plt.plot(mid_predict_df['date'], mid_predict_df['LSTM Prediction'], label='Predicted Sales (Mid)')
plt.plot(mid_future_df['date'], mid_future_df['LSTM Prediction'], label='Future Prediction (Mid)', linestyle='--')
plt.title("Customer Sales Forecast - Mid Category (Window Size: 12)")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.legend()

# High category plot
plt.subplot(3, 1, 3)
plt.plot(high_sales['date'], high_sales['sales'], label='Actual Sales')
plt.plot(high_predict_df['date'], high_predict_df['LSTM Prediction'], label='Predicted Sales (High)')
plt.plot(high_future_df['date'], high_future_df['LSTM Prediction'], label='Future Prediction (High)', linestyle='--')
plt.title("Customer Sales Forecast - High Category (Window Size: 12)")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from sklearn import metrics


# Load model from the saved file with custom_objects
custom_objects = {'mse': metrics.mean_squared_error}
loaded_model = load_model('all_models.h5', custom_objects=custom_objects)

# Function to predict future sales for a specific category using the loaded model
def predict_future_sales(data, category_name, window_size, model):
    # Process data for the specific category
    data = data[data['category'] == category_name].drop(['category'], axis=1)
    data['date'] = data['date'].dt.to_period("M")
    monthly_sales = data.groupby('date').sum().reset_index()
    monthly_sales['date'] = monthly_sales['date'].dt.to_timestamp()

    # Calculate sales difference
    monthly_sales['sales_diff'] = monthly_sales['sales'].diff()
    monthly_sales = monthly_sales.dropna()

    # Prepare supervised data with a window size
    supervised_data = monthly_sales.drop(['date', 'sales'], axis=1)
    for i in range(1, window_size + 1):
        col_name = 'month_' + str(i)
        supervised_data[col_name] = supervised_data['sales_diff'].shift(i)
    supervised_data = supervised_data.dropna().reset_index(drop=True)

    # Scale the data
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler.fit(supervised_data)
    data_scaled = scaler.transform(supervised_data)

    # Prepare input data for prediction
    X = data_scaled[:, 1:]
    X = X.reshape((X.shape[0], X.shape[1], 1))

    # Predict next 12 months
    future_predictions = []
    last_data = supervised_data[-1:].copy()

    for _ in range(12):
        last_data_scaled = scaler.transform(last_data)
        X_last = last_data_scaled[:, 1:].reshape((1, window_size, 1))
        next_pred = model.predict(X_last)[0, 0]

        future_pred = np.concatenate([[next_pred], last_data_scaled[0, 1:]])
        future_pred = scaler.inverse_transform([future_pred])

        future_predictions.append(future_pred[0][0] + monthly_sales['sales'].iloc[-1])

        new_row = np.append([next_pred], last_data.values[0, :-1])
        last_data = pd.DataFrame([new_row], columns=supervised_data.columns)

    future_dates = pd.date_range(start=monthly_sales['date'].iloc[-1] + pd.DateOffset(months=1), periods=12, freq='M')
    future_df = pd.DataFrame({'date': future_dates, 'LSTM Prediction': future_predictions})

    return future_df

# Predict future sales for each category using the loaded model
low_future_pred = predict_future_sales(store_sales, 'low', window_size, loaded_model)
mid_future_pred = predict_future_sales(store_sales, 'mid', window_size, loaded_model)
high_future_pred = predict_future_sales(store_sales, 'high', window_size, loaded_model)

# Print the predictions
print("Future Sales Predictions for Low Category:")
print(low_future_pred)
print("\nFuture Sales Predictions for Mid Category:")
print(mid_future_pred)
print("\nFuture Sales Predictions for High Category:")
print(high_future_pred)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# C:\Users\MyPC\AppData\Local\Temp\ipykernel_19680\618698185.py:53: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
# ...

# %%
import matplotlib.pyplot as plt

# Function to plot historical sales data and future predictions
def plot_sales_predictions(data, future_predictions, category_name):
    plt.figure(figsize=(12, 6))
    plt.plot(data['date'], data['sales'], label='Historical Sales')
    plt.plot(future_predictions['date'], future_predictions['LSTM Prediction'], label='LSTM Prediction')
    plt.title(f'Historical Sales and LSTM Predictions for {category_name} Category')
    plt.xlabel('Date')
    plt.ylabel('Sales')
    plt.legend()
    plt.grid(True)
    plt.show()

# Plot historical sales and predictions for each category
plot_sales_predictions(low_sales, low_future_pred, 'Low')
plot_sales_predictions(mid_sales, mid_future_pred, 'Mid')
plot_sales_predictions(high_sales, high_future_pred, 'High')

# %%
# Load model from the saved file with custom_objects
custom_objects = {'mse': metrics.mean_squared_error}
loaded_model = load_model('all_models.h5', custom_objects=custom_objects)

# Function to predict future sales for a specific category using the loaded model
def predict_future_sales(data, category_name, window_size, model):
    # Process data for the specific category
    data = data[data['category'] == category_name].drop(['category'], axis=1)
    data['date'] = pd.to_datetime(data['date'])
    data = data.set_index('date').resample('M').sum().reset_index()

    # Prepare input data for prediction
    X = data['sales'].values[-window_size:].reshape(1, window_size, 1)

    # Predict next 12 months
    future_predictions = []
    last_data = X

    for _ in range(12):
        next_pred = model.predict(last_data)[0, 0]
        future_predictions.append(next_pred)

        # Update last_data for next prediction
        last_data = np.roll(last_data, -1)
        last_data[0, -1, 0] = next_pred

    # Create DataFrame for future predictions
    future_dates = pd.date_range(start=data['date'].iloc[-1] + pd.DateOffset(months=1), periods=12, freq='M')
    future_df = pd.DataFrame({'date': future_dates, 'LSTM Prediction': future_predictions})

    # Plot future sales predictions
    plt.figure(figsize=(10, 5))
    plt.plot(data['date'], data['sales'], label='Actual Sales')
    plt.plot(future_df['date'], future_df['LSTM Prediction'], label='Future Prediction', linestyle='--')
    plt.title(f"Future Sales Forecast - {category_name.capitalize()} Category")
    plt.xlabel("Date")
    plt.ylabel("Sales")
    plt.legend()
    plt.show()

# Predict future sales for each category using the loaded model
predict_future_sales(store_sales, 'low', window_size, loaded_model)
predict_future_sales(store_sales, 'mid', window_size, loaded_model)
predict_future_sales(store_sales, 'high', window_size, loaded_model)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# C:\Users\MyPC\AppData\Local\Temp\ipykernel_19680\1655998262.py:10: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   data = data.set_index('date').resample('M').sum().reset_index()
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# ...

# %%
# Plot future sales predictions for each category
plt.figure(figsize=(10, 5))

# Low category
plt.plot(low_future_pred['date'], low_future_pred['LSTM Prediction'], label='Low Category')

# Mid category
plt.plot(mid_future_pred['date'], mid_future_pred['LSTM Prediction'], label='Mid Category')

# High category
plt.plot(high_future_pred['date'], high_future_pred['LSTM Prediction'], label='High Category')

plt.title("Future Sales Predictions for Each Category")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.legend()
plt.show()

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import load_model

# Load models
loaded_model_low = load_model('best_model_low.keras')
loaded_model_mid = load_model('best_model_mid.keras')
loaded_model_high = load_model('best_model_high.keras')

# Function to make prediction for next month
def predict_next_month_sales(new_data_url, loaded_model):
    # Read new CSV file
    new_data = pd.read_csv(new_data_url)
    new_data['date'] = pd.to_datetime(new_data['date'])
    new_data = new_data.set_index('date')

    # Extract sales data for the previous 11 months
    previous_11_months_sales = new_data['sales'].iloc[-12:-1].values

    # Extract sales data for the latest month
    latest_month_sales = new_data['sales'].iloc[-1]

    # Scale the latest month sales
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler.fit(previous_11_months_sales.reshape(-1, 1))
    scaled_latest_month_sales = scaler.transform(np.array([[latest_month_sales]]).reshape(1, -1))

    # Prepare input data for prediction
    input_data = np.array(previous_11_months_sales).reshape(1, 11, 1)
    input_data = np.concatenate([input_data, scaled_latest_month_sales.reshape(1, 1, 1)], axis=1)

    # Make prediction
    predicted_sales = loaded_model.predict(input_data)

    # Inverse transform to get actual sales value
    predicted_sales_actual = scaler.inverse_transform(predicted_sales.reshape(-1, 1))

    return predicted_sales_actual[0][0]

# URLs for new data
new_data_urls = {
    'low': 'https://raw.githubusercontent.com/C4AnN/Models/data/dataset/filtered_store_sales_2016_2017.csv',
    'mid': 'https://raw.githubusercontent.com/C4AnN/Models/data/dataset/filtered_store_sales_2016_2017.csv',
    'high': 'https://raw.githubusercontent.com/C4AnN/Models/data/dataset/filtered_store_sales_2016_2017.csv'
}

# Predict sales for next month for each category
predicted_sales_low = predict_next_month_sales(new_data_urls['low'], loaded_model_low)
predicted_sales_mid = predict_next_month_sales(new_data_urls['mid'], loaded_model_mid)
predicted_sales_high = predict_next_month_sales(new_data_urls['high'], loaded_model_high)

# Output predictions
print("Prediksi penjualan untuk bulan berikutnya (Low Category):", predicted_sales_low)
print("Prediksi penjualan untuk bulan berikutnya (Mid Category):", predicted_sales_mid)
print("Prediksi penjualan untuk bulan berikutnya (High Category):", predicted_sales_high)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step
# Prediksi penjualan untuk bulan berikutnya (Low Category): 16.312672
# Prediksi penjualan untuk bulan berikutnya (Mid Category): 14.090487
# Prediksi penjualan untuk bulan berikutnya (High Category): 1.6376145

# %%
import pandas as pd
import numpy as np
from tensorflow.keras.models import load_model

# Load model
loaded_model = load_model('best_model_low.keras')  # Ganti dengan nama file model yang sesuai

# Baca file CSV baru
new_data_url = 'https://raw.githubusercontent.com/C4AnN/Models/data/dataset/filtered_store_sales_2016_2017.csv'
new_data = pd.read_csv(new_data_url)

# Proses data baru
new_data['date'] = pd.to_datetime(new_data['date'])  # Ubah format tanggal jika perlu
new_data = new_data.set_index('date')  # Atur tanggal sebagai indeks jika perlu

# Misalkan Anda ingin membuat prediksi untuk satu tahun ke depan
# Loop untuk membuat prediksi untuk setiap bulan
predictions = []
for i in range(12):
    # Ambil penjualan bulan terakhir
    latest_month_sales = new_data['sales'].iloc[-1]
    # Ambil penjualan 11 bulan sebelumnya
    previous_11_months_sales = new_data['sales'].iloc[:-1]
    # Pastikan bahwa data sebelumnya memiliki 12 bulan
    if len(previous_11_months_sales) != 11:
        break
    # Buat array input untuk prediksi dengan model
    input_data = np.array(previous_11_months_sales).reshape(1, 11, 1)  # Konversi ke array numpy dan ubah bentuk sesuai dengan window_size
    # Gabungkan data bulan terakhir dengan data 11 bulan sebelumnya
    input_data = np.concatenate([input_data, np.array([[latest_month_sales]])], axis=1)
    # Lakukan prediksi dengan model
    predicted_sales = loaded_model.predict(input_data)
    # Simpan prediksi
    predictions.append(predicted_sales[0][0])
    # Update data baru dengan prediksi untuk bulan berikutnya
    new_data = new_data.append(pd.DataFrame({'date': [new_data.index[-1] + pd.DateOffset(months=1)], 'sales': [predicted_sales[0][0]]}), ignore_index=True)

# Output prediksi
print("Prediksi penjualan untuk satu tahun ke depan:", predictions)
# Out:
# Prediksi penjualan untuk satu tahun ke depan: []
